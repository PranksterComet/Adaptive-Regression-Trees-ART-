# %%
import numpy as np
import random
from numpy.linalg import solve, norm
from dataclasses import dataclass
from typing import Callable, Optional, Dict, Any, Union
import matplotlib.pyplot as plt

# %%
def sigmoid(x: np.ndarray) -> np.ndarray:
    # numerically safer sigmoid
    x = np.clip(x, -50.0, 50.0)
    return 1.0 / (1.0 + np.exp(-x))


def augment_X(X: np.ndarray) -> np.ndarray:
    """
    Append a column of ones for affine models.
    X: (n, d)
    returns: (n, d+1)
    """
    n = X.shape[0]
    return np.hstack([X, np.ones((n, 1))])


def sample_uniform_simplex(vertices: np.ndarray, n_samples: int, rng=None) -> np.ndarray:
    """
    Uniformly sample points from a d-simplex in R^d given by d+1 vertices.

    vertices: shape (d+1, d)
    returns: shape (n_samples, d)
    """
    if rng is None:
        rng = np.random.default_rng()

    m, d = vertices.shape
    if m != d + 1:
        raise ValueError(
            f"For simplex sampling, expected vertices.shape = (d+1, d), got {vertices.shape}."
        )

    # Dirichlet(1,...,1) gives uniform barycentric coordinates
    bary = rng.dirichlet(alpha=np.ones(m), size=n_samples)  # (n_samples, d+1)
    return bary @ vertices

# %%
def evaluate_error(
    f_true,
    f_pred,
    bounds: np.ndarray,
    n_samples: int,
    random_state: int = 0,
    rel_floor: float = 1e-12,
):
    """
    Compare two scalar-valued functions on random points sampled uniformly
    from a hypercube / hyper-rectangle.

    Parameters
    ----------
    f_true : callable
        Ground-truth function, takes x and returns scalar.
    f_pred : callable
        Surrogate/prediction function, takes x and returns scalar.
    bounds : np.ndarray
        Array of shape (d, 2), where bounds[i] = [low_i, high_i].
    n_samples : int
        Number of random evaluation points.
    random_state : int
        RNG seed.
    rel_floor : float
        Stabilizer for pointwise relative error near zero.

    Returns
    -------
    dict with aggregate error metrics and sampled values.
    """
    bounds = np.asarray(bounds, dtype=float)
    if bounds.ndim != 2 or bounds.shape[1] != 2:
        raise ValueError(f"bounds must have shape (d, 2), got {bounds.shape}")

    lows = bounds[:, 0]
    highs = bounds[:, 1]
    if np.any(lows >= highs):
        raise ValueError("Each bound must satisfy low < high.")

    rng = np.random.default_rng(random_state)
    X = rng.uniform(lows, highs, size=(n_samples, bounds.shape[0]))
    print("Data shape:", X.shape)

    y_true = np.array([f_true(x) for x in X], dtype=float)
    y_pred = np.array([f_pred(x) for x in X], dtype=float)

    abs_err = np.abs(y_true - y_pred)
    sq_err = (y_true - y_pred) ** 2
    pointwise_rel_err = abs_err / np.maximum(np.abs(y_true), rel_floor)

    rel_l2 = np.linalg.norm(y_true - y_pred) / max(np.linalg.norm(y_true), rel_floor)
    rmse = float(np.sqrt(np.mean(sq_err)))
    mae = float(np.mean(abs_err))
    median_rel = float(np.median(pointwise_rel_err))
    max_rel = float(np.max(pointwise_rel_err))

    return {
        "relative_l2_error": float(rel_l2),
        "median_pointwise_relative_error": median_rel,
        "max_pointwise_relative_error": max_rel,
        "abs_err": abs_err,
        "pointwise_relative_error": pointwise_rel_err,
        "L2 norm": float(np.linalg.norm(y_true / np.sqrt(len(y_true)))),
    }

# %% [markdown]
# ## Tree Setup

# %%
@dataclass
class PolytopeRegion:
    """
    Polyhedral region represented as A x <= b.
    """
    A: np.ndarray
    b: np.ndarray
    depth: int = 0
    tag: Optional[str] = None


@dataclass
class AffineLeaf:
    beta: np.ndarray
    parent: Optional[Any] = None
    region: Optional[PolytopeRegion] = None
    depth: int = 0
    node_id: Optional[str] = None

    def predict_one(self, x: np.ndarray) -> float:
        x = np.asarray(x, dtype=float)
        x_aug = np.append(x, 1.0)
        return float(x_aug @ self.beta)


@dataclass
class SplitNode:
    w: np.ndarray
    z: float
    left: Any
    right: Any
    parent: Optional[Any] = None
    region: Optional[PolytopeRegion] = None
    depth: int = 0
    node_id: Optional[str] = None
    fit_result: Optional[Any] = None

    def route(self, x: np.ndarray):
        x = np.asarray(x, dtype=float)
        if float(self.w @ x - self.z) >= 0.0:
            return self.right
        return self.left


TreeNode = Union[AffineLeaf, SplitNode]


class PiecewiseLinearTree:
    def __init__(self, root: Optional[TreeNode] = None):
        self.root = root

    def predict_one(self, x: np.ndarray) -> float:
        if self.root is None:
            raise ValueError("Tree has no root node.")

        node = self.root
        while isinstance(node, SplitNode):
            node = node.route(x)

        return node.predict_one(x)

    def predict(self, X: np.ndarray) -> np.ndarray:
        X = np.asarray(X, dtype=float)
        return np.array([self.predict_one(x) for x in X], dtype=float)

    def leaf_for_point(self, x: np.ndarray) -> AffineLeaf:
        if self.root is None:
            raise ValueError("Tree has no root node.")

        node = self.root
        while isinstance(node, SplitNode):
            node = node.route(x)

        return node
    
    def num_leaves(self) -> int:
        def _count(node) -> int:
            if isinstance(node, AffineLeaf):
                return 1
            return _count(node.left) + _count(node.right)

        if self.root is None:
            return 
        return _count(self.root)


    def max_depth(self) -> int:
        def _depth(node):
            if isinstance(node, AffineLeaf):
                return 0
            return 1 + max(_depth(node.left), _depth(node.right))

        if self.root is None:
            return 0
        return _depth(self.root)
    
    def t_range(self):
        vals = []

        def _walk(node):
            if node is None:
                return
            t = getattr(node, "t_cell", None)
            if t is not None:
                vals.append(float(t))
            if isinstance(node, SplitNode):
                _walk(node.left)
                _walk(node.right)

        _walk(self.root)

        if not vals:
            return None
        return min(vals), max(vals)

    def get_node(self, node_id) -> TreeNode:
        if self.root is None:
            raise ValueError("Tree has no root node.")

        if node_id in ("root", "", None):
            return self.root

        parts = node_id.split("/")
        if parts[0] != "root":
            raise ValueError(f"node_id must start with 'root', got {node_id!r}")

        node = self.root
        for step in parts[1:]:
            if isinstance(node, AffineLeaf):
                raise ValueError(f"Path {node_id!r} goes past a leaf at {node.node_id!r}")
            if step == "L":
                node = node.left
            elif step == "R":
                node = node.right
            else:
                raise ValueError(f"Invalid step {step!r} in {node_id!r}")

        return node

# %%
@dataclass
class FitResult:
    w: np.ndarray
    z: float
    beta0: np.ndarray
    beta1: np.ndarray
    loss_history: list
    grad_norm_history: list
    n_iters: int
    converged: bool
    w_norm_penalty: float
    X: np.ndarray
    y: np.ndarray
    pi: np.ndarray


class biLinear_fit:
    """
    Soft hyperplane-gated two-affine-model fit:
        pi_i = sigmoid((w^T x_i - z)/t)

    Objective:
        sum_i (1-pi_i) (y_i - <beta0, x~_i>)^2
      + sum_i pi_i     (y_i - <beta1, x~_i>)^2

    where x~_i = [x_i; 1].
    """

    def __init__(
        self,
        oracle: Optional[Callable[[np.ndarray], float]] = None,
        vertices: Optional[np.ndarray] = None,
        t: float = 1.0,
        n_samples: int = 500,
        ridge: float = 1e-8,
        w_norm_penalty: float = 0.5,
        random_state: Optional[int] = None,
        X: Optional[np.ndarray] = None,
        y: Optional[np.ndarray] = None,
    ):

        """
        oracle: function f: R^d -> R
        vertices: simplex vertices, shape (d+1, d)
        t: fixed sigmoid sharpness parameter
        n_samples: number of queried points
        ridge: ridge regularization for weighted LS
        """
        self.oracle = oracle
        self.vertices = None if vertices is None else np.asarray(vertices, dtype=float)
        self.t = float(t)
        self.n_samples = int(n_samples)
        self.ridge = float(ridge)
        self.w_norm_penalty = float(w_norm_penalty)
        self.rng = np.random.default_rng(random_state)

        self.X = None
        self.y = None

        if X is not None or y is not None:
            if X is None or y is None:
                raise ValueError("If providing data directly, both X and y must be given.")

            X = np.asarray(X, dtype=float)
            y = np.asarray(y, dtype=float).reshape(-1)

            if X.ndim != 2:
                raise ValueError(f"X must have shape (n, d), got {X.shape}.")
            if y.ndim != 1:
                raise ValueError(f"y must have shape (n,), got {y.shape}.")
            if X.shape[0] != y.shape[0]:
                raise ValueError(
                    f"X and y must have the same number of samples, got {X.shape[0]} and {y.shape[0]}."
                )

            self.X = X.copy()
            self.y = y.copy()
            self.d = X.shape[1]
            self.data_provided = True

        else:
            if oracle is None:
                raise ValueError("oracle must be provided when X, y are not given.")
            if self.vertices is None:
                raise ValueError("vertices must be provided when X, y are not given.")

            m, d = self.vertices.shape
            if m != d + 1:
                raise ValueError(
                    "Current implementation assumes domain is a simplex with shape (d+1, d)."
                )

            self.d = d
            self.data_provided = False

        self.w = None
        self.z = None
        self.beta0 = None
        self.beta1 = None

        self.loss_history = []
        self.grad_norm_history = []

    # ----------------------------
    # Sampling / data generation
    # ----------------------------
    def sample_domain(self) -> np.ndarray:
        return sample_uniform_simplex(self.vertices, self.n_samples, rng=self.rng)

    def query_oracle(self, X: np.ndarray) -> np.ndarray:
        y = np.array([self.oracle(x) for x in X], dtype=float)
        return y

    def generate_data(self):
        if self.data_provided:
            return
        self.X = self.sample_domain()
        self.y = self.query_oracle(self.X)
    # ----------------------------
    # Initialization
    # ----------------------------
    def initialize_params(self, beta_sep: float = 1e-3):
        """
        Simple initialization:
        - random unit w
        - z = median(w^T x)
        - beta0, beta1 initialized as small perturbations of a global affine fit

        This avoids the degenerate beta0 == beta1 case without doing
        additional split-dependent least-squares solves.
        """
        w = self.rng.normal(size=self.d)
        w /= max(norm(w), 1e-12)

        proj = self.X @ w
        z = float(np.median(proj))

        X_aug = augment_X(self.X)
        A = X_aug.T @ X_aug + self.ridge * np.eye(self.d + 1)
        b = X_aug.T @ self.y
        beta_global = solve(A, b)

        delta = self.rng.normal(size=self.d + 1)
        delta /= max(norm(delta), 1e-12)
        delta *= beta_sep * max(1.0, norm(beta_global))

        self.w = w
        self.z = z
        self.beta0 = beta_global - delta
        self.beta1 = beta_global + delta

    # ----------------------------
    # Core model pieces
    # ----------------------------
    def compute_pi(self, w: np.ndarray, z: float) -> np.ndarray:
        s = (self.X @ w - z) / self.t
        return sigmoid(s)

    def solve_weighted_ls(self, pi: np.ndarray):
        """
        Solve for beta0, beta1 exactly, given fixed pi.
        """
        X_aug = augment_X(self.X)
        I = np.eye(self.d + 1)

        w0 = 1.0 - pi
        w1 = pi

        # Weighted normal equations
        # X^T W X = X^T (diag(w)) X = (X * w[:,None])^T X
        A0 = X_aug.T @ (X_aug * w0[:, None]) + self.ridge * I
        b0 = X_aug.T @ (self.y * w0)

        A1 = X_aug.T @ (X_aug * w1[:, None]) + self.ridge * I
        b1 = X_aug.T @ (self.y * w1)

        beta0 = solve(A0, b0)
        beta1 = solve(A1, b1)

        return beta0, beta1

    def objective(self, w: np.ndarray, z: float, beta0: np.ndarray, beta1: np.ndarray) -> float:
        pi = self.compute_pi(w, z)
        X_aug = augment_X(self.X)

        r0 = self.y - X_aug @ beta0
        r1 = self.y - X_aug @ beta1

        val = np.sum((1.0 - pi) * (r0 ** 2) + pi * (r1 ** 2))
        wpenalty = 0.5 * self.w_norm_penalty * ((np.dot(w, w) - 1.0) ** 2)
        return 0.5 * float(val) + wpenalty

    def reduced_objective(self, w: np.ndarray, z: float):
        """
        E(w,z) = min_{beta0,beta1} J(beta0,beta1,w,z)
        """
        pi = self.compute_pi(w, z)
        beta0, beta1 = self.solve_weighted_ls(pi)
        val = self.objective(w, z, beta0, beta1)
        return val, pi, beta0, beta1

    def gradient_wz_given_betas(
        self, w: np.ndarray, z: float, beta0: np.ndarray, beta1: np.ndarray
    ):
        """
        Gradient wrt (w,z), holding beta0,beta1 fixed.

        J = 1/2 sum_i [ (1-pi_i) r0_i^2 + pi_i r1_i^2 ]

        dJ/dpi_i = 1/2 (r1_i^2 - r0_i^2)
        dpi_i/ds_i = pi_i(1-pi_i)
        s_i = (w^T x_i - z)/t
        """
        pi = self.compute_pi(w, z)
        X_aug = augment_X(self.X)

        r0 = self.y - X_aug @ beta0
        r1 = self.y - X_aug @ beta1

        coeff = 0.5 * (r1**2 - r0**2) * pi * (1.0 - pi)  # shape (n,)

        grad_w = (self.X.T @ coeff) / self.t
        grad_w += 2 * self.w_norm_penalty * (np.dot(w, w) - 1.0) * w
        grad_z = -np.sum(coeff) / self.t

        return grad_w, float(grad_z)

    # ----------------------------
    # Backtracking GD on (w, z)
    # ----------------------------
    def backtracking_step(
        self,
        w: np.ndarray,
        z: float,
        beta0: np.ndarray,
        beta1: np.ndarray,
        grad_w: np.ndarray,
        grad_z: float,
        alpha0: float = 1.0,
        rho: float = 0.5, #0.5
        c: float = 1e-4,
        max_backtracks: int = 25, #25
    ):
        """
        Backtracking line search on reduced objective.
        After proposing (w_new,z_new), we re-solve weighted LS.
        """
        curr_val = self.objective(w, z, beta0, beta1)

        grad_vec = np.concatenate([grad_w, np.array([grad_z])])
        grad_sq = np.dot(grad_vec, grad_vec)

        alpha = alpha0
        for _ in range(max_backtracks):
            w_new = w - alpha * grad_w
            w_norm = norm(w_new)
            if w_norm < 1e-12:
                alpha *= rho
                continue
            
            # w_new = w_new / w_norm
            z_new = z - alpha * grad_z
            # z_new = z_new / w_norm

            new_val = self.objective(w_new, z_new, beta0, beta1)

            # Armijo condition on frozen-beta objective
            if new_val <= curr_val - c * alpha * grad_sq:
                # print("succesful stepsize:", alpha)
                pi_new = self.compute_pi(w_new, z_new)
                return w_new, z_new, pi_new, beta0, beta1, new_val, alpha

            alpha *= rho

        # fallback: no successful step
        pi_curr = self.compute_pi(w, z)
        return w, z, pi_curr, beta0, beta1, curr_val, 0.0

    # ----------------------------
    # Main fit loop
    # ----------------------------
    def fit(
        self,
        max_iters: int = 100,
        tol: float = 1e-6,
        alpha0: float = 1.0,
        verbose: bool = True,
        regenerate_data: bool = True,
        use_optimizer: bool = True,
    ) -> FitResult:

        if self.data_provided:
            regenerate_data = False

        if regenerate_data or self.X is None or self.y is None:
            self.generate_data()

        self.initialize_params()

        converged = False
        if not use_optimizer:
            converged = True
            pi = self.compute_pi(self.w, self.z)
            self.beta0, self.beta1 = self.solve_weighted_ls(pi)
            curr_loss = self.objective(self.w, self.z, self.beta0, self.beta1)
            grad_w, grad_z = self.gradient_wz_given_betas(
                self.w, self.z, self.beta0, self.beta1
            )
            grad_norm = np.sqrt(np.dot(grad_w, grad_w) + grad_z**2)

            self.loss_history.append(curr_loss)
            self.grad_norm_history.append(grad_norm)

            if verbose:
                print(
                    f"iter=0 | loss={curr_loss:.6e} | grad_norm={grad_norm:.6e}"
                )

        for k in range(max_iters):
            if not use_optimizer:
                break
            # exact beta update for current (w,z)
            pi = self.compute_pi(self.w, self.z)
            self.beta0, self.beta1 = self.solve_weighted_ls(pi)

            # evaluate reduced objective
            curr_loss = self.objective(self.w, self.z, self.beta0, self.beta1)

            # gradient wrt (w,z), holding betas fixed
            grad_w, grad_z = self.gradient_wz_given_betas(
                self.w, self.z, self.beta0, self.beta1
            )
            grad_norm = np.sqrt(np.dot(grad_w, grad_w) + grad_z**2)

            self.loss_history.append(curr_loss)
            self.grad_norm_history.append(grad_norm)

            if verbose and (k % 10 == 0 or k == max_iters - 1):
                print(
                    f"iter={k:3d} | loss={curr_loss:.6e} | grad_norm={grad_norm:.6e}"
                )

            if grad_norm < tol:
                converged = True
                break

            # backtracking update on (w,z), betas are frozen here 
            self.w, self.z, pi, self.beta0, self.beta1, new_loss, step = self.backtracking_step(
                self.w,
                self.z,
                self.beta0,
                self.beta1,
                grad_w,
                grad_z,
                alpha0=alpha0,
            )

            # Control w, z sizes
            # w_norm = norm(self.w)
            # self.w = self.w / w_norm
            # self.z = self.z / w_norm

            # re-fit betas after accepting the (w,z) step
            pi = self.compute_pi(self.w, self.z)
            self.beta0, self.beta1 = self.solve_weighted_ls(pi)
            new_loss = self.objective(self.w, self.z, self.beta0, self.beta1)

            if step == 0.0:
                print("Backtracking failed to find a descent step.")
                break

            if abs(curr_loss - new_loss) < tol * max(1.0, abs(curr_loss)):
                converged = True
                self.loss_history.append(new_loss)
                self.grad_norm_history.append(grad_norm)
                break

        final_pi = self.compute_pi(self.w, self.z)

        return FitResult(
            w=self.w.copy(),
            z=float(self.z),
            beta0=self.beta0.copy(),
            beta1=self.beta1.copy(),
            loss_history=self.loss_history.copy(),
            grad_norm_history=self.grad_norm_history.copy(),
            n_iters=len(self.loss_history),
            converged=converged,
            w_norm_penalty=self.w_norm_penalty,
            X=self.X.copy(),
            y=self.y.copy(),
            pi=final_pi.copy(),
        )

    # ----------------------------
    # Prediction helpers
    # ----------------------------
    def predict_soft(self, X_new: np.ndarray) -> np.ndarray:
        X_new = np.asarray(X_new, dtype=float)
        X_aug = augment_X(X_new)
        pi = sigmoid((X_new @ self.w - self.z) / self.t)
        y0 = X_aug @ self.beta0
        y1 = X_aug @ self.beta1

        # soft blended prediction; useful for visualization only
        return (1.0 - pi) * y0 + pi * y1

    def predict_hard(self, X_new: np.ndarray) -> np.ndarray:
        X_new = np.asarray(X_new, dtype=float)
        X_aug = augment_X(X_new)
        side = (X_new @ self.w - self.z) >= 0.0
        y0 = X_aug @ self.beta0
        y1 = X_aug @ self.beta1
        return np.where(side, y1, y0)

# %%
# 2D simplex (triangle)
vertices = np.array([
    [0.0, 0.0],
    [1.0, 0.0],
    [0.2, 1.0],
])

true_w = np.array([1, -1])
true_z = 0.0


def oracle(x):
    # true split: x0 + x1 = 0.75
    if true_w[0]*x[0] + true_w[1]*x[1] < true_z:
        return 2.0 * x[0] - 1.0 * x[1] + 0.3
    else:
        return -1.5 * x[0] + 2.5 * x[1] - 0.2

model = biLinear_fit(
    oracle=oracle,
    vertices=vertices,
    t=0.02, #0.01
    n_samples=10, #250
    ridge=1e-8,
    random_state=3,
)

result = model.fit(max_iters=250, tol=1e-5, alpha0=1.0, verbose=True, use_optimizer=False)

print("converged:", result.converged)
print("w =", result.w)
print("z =", result.z)
print("beta0 =", result.beta0)
print("beta1 =", result.beta1)

# Plot loss history
plt.figure(figsize=(6, 4))
plt.plot(result.loss_history, linewidth=2)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# iter=0 | loss=5.610102e-01 | grad_norm=4.791052e-01
# converged: True
# w = [-0.94988712 -0.31259313]
# z = -0.42485139172021547
# beta0 = [-2.27532273 -0.46280356  1.17078907]
# beta1 = [-0.22475387  0.63442898 -0.22895758]

# %%
# Plot loss history
plt.figure(figsize=(6, 4))
plt.plot(result.grad_norm_history, linewidth=2)
plt.xlabel("Iteration")
plt.ylabel("Grad Norm")
plt.title("Grad Norm Hist")
plt.grid(True, alpha=0.3)
plt.show()

# %%
def plot_two_partition_lines(vertices, true_w, true_z, pred_w, pred_z, X=None):
    vertices = np.asarray(vertices, dtype=float)
    if vertices.shape != (3, 2):
        raise ValueError("This function expects a 2D simplex with shape (3, 2).")

    def clipped_line_in_triangle(w, z, verts, tol=1e-10):
        pts = []
        edges = [(0, 1), (1, 2), (2, 0)]

        for i, j in edges:
            a = verts[i]
            b = verts[j]
            d = b - a

            denom = np.dot(w, d)
            numer = z - np.dot(w, a)

            if abs(denom) < tol:
                continue

            t = numer / denom
            if -tol <= t <= 1 + tol:
                p = a + t * d
                pts.append(p)

        uniq = []
        for p in pts:
            if not any(np.linalg.norm(p - q) < 1e-8 for q in uniq):
                uniq.append(p)

        if len(uniq) >= 2:
            return np.array(uniq[:2])
        return None

    fig, ax = plt.subplots(figsize=(6, 6))

    # simplex
    closed = np.vstack([vertices, vertices[0]])
    ax.plot(closed[:, 0], closed[:, 1], color="black", lw=2, label="Simplex")

    # sampled points colored by true side
    if X is not None:
        X = np.asarray(X, dtype=float)
        true_side = (X @ true_w - true_z) >= 0.0

        ax.scatter(
            X[~true_side, 0], X[~true_side, 1],
            color="tab:blue", s=20, alpha=0.8, label="True side < 0"
        )
        ax.scatter(
            X[true_side, 0], X[true_side, 1],
            color="tab:orange", s=20, alpha=0.8, label="True side >= 0"
        )

    # lines
    true_seg = clipped_line_in_triangle(true_w, true_z, vertices)
    pred_seg = clipped_line_in_triangle(pred_w, pred_z, vertices)

    if true_seg is not None:
        ax.plot(true_seg[:, 0], true_seg[:, 1], color="blue", lw=2.5, label="True line")

    if pred_seg is not None:
        ax.plot(pred_seg[:, 0], pred_seg[:, 1], color="red", lw=2.5, ls="--", label="Predicted line")

    ax.set_aspect("equal")
    ax.set_xlabel("x1")
    ax.set_ylabel("x2")
    ax.set_title("True vs Predicted Partition Line")
    ax.legend()
    plt.show()

# %%
plot_two_partition_lines(
    vertices=model.vertices,
    true_w=true_w,
    true_z=true_z,
    pred_w=result.w,
    pred_z=result.z,
    X=result.X,
)

# %% [markdown]
# ## Uniform Sampling Convex Polyhedra

# %%
def find_feasible_point(A, b, max_tries=20000, seed=0):
    rng = np.random.default_rng(seed)
    d = A.shape[1]
    for _ in range(max_tries):
        x = rng.uniform(-1.0, 1.0, size=d)
        if np.all(A @ x <= b):
            return x
    raise RuntimeError("Could not find a feasible starting point.")

# Mixing time scales as O(d^3) verify this
def hit_and_run_sample(A, b, n_samples, burn_in=1000, thinning=10, x0=None, seed=0):
    rng = np.random.default_rng(seed)
    m, d = A.shape

    if x0 is None:
        x = find_feasible_point(A, b, seed=seed)
    else:
        x = np.array(x0, dtype=float)
        if not np.all(A @ x <= b):
            raise ValueError("x0 is not feasible.")
    
    samples = []
    total_steps = burn_in + n_samples * thinning

    for step in range(total_steps):
        u = rng.normal(size=d)
        u /= np.linalg.norm(u)

        Au = A @ u
        Ax = A @ x

        t_low = -np.inf
        t_high = np.inf

        for i in range(m):
            if abs(Au[i]) < 1e-14:
                if Ax[i] > b[i]:
                    raise RuntimeError("Current point became infeasible.")
                continue

            t = (b[i] - Ax[i]) / Au[i]
            if Au[i] > 0:
                t_high = min(t_high, t)
            else:
                t_low = max(t_low, t)

        if t_low > t_high:
            raise RuntimeError("Empty step interval encountered.")

        t_new = rng.uniform(t_low, t_high)
        x = x + t_new * u

        if step >= burn_in and (step - burn_in) % thinning == 0:
            samples.append(x.copy())

    return np.array(samples)

# %%
A = np.array([
    [ 0.0,  1.0],
    [ 0.95,  0.31],
    [ 0.59, -0.81],
    [-0.59, -0.81],
    [-0.95,  0.31],
])
b = np.ones(5)


pts = hit_and_run_sample(A, b, n_samples=2000, burn_in=1000, thinning=5, seed=1)

print(pts.shape)
print(np.all(A @ pts.T <= b[:, None] + 1e-10))

plt.figure(figsize=(5, 5))
plt.scatter(pts[:, 0], pts[:, 1], s=6, alpha=0.5)
plt.plot([0, 1, 0, 0], [0, 0, 1, 0], "r-")
plt.gca().set_aspect("equal")
plt.show()
# Out:
# (2000, 2)
# True

# %% [markdown]
# ## Recursive Partitioning

# %%
@dataclass
class SurrogateBuildResult:
    tree: PiecewiseLinearTree
    oracle_queries: int
    root_diameter: float


def hypercube_to_region(bounds: np.ndarray, depth: int = 0, tag: Optional[str] = None) -> PolytopeRegion:
    bounds = np.asarray(bounds, dtype=float)
    if bounds.ndim != 2 or bounds.shape[1] != 2:
        raise ValueError(f"bounds must have shape (d, 2), got {bounds.shape}")

    lows = bounds[:, 0]
    highs = bounds[:, 1]
    if np.any(lows >= highs):
        raise ValueError("Each bound must satisfy low < high.")

    d = bounds.shape[0]
    A = np.vstack([np.eye(d), -np.eye(d)])
    b = np.concatenate([highs, -lows])
    return PolytopeRegion(A=A, b=b, depth=depth, tag=tag)


def split_region(region: PolytopeRegion, w: np.ndarray, z: float, depth: int):
    # left:  w^T x - z < 0  ->  w^T x <= z
    A_left = np.vstack([region.A, w.reshape(1, -1)])
    b_left = np.concatenate([region.b, np.array([z])])

    # right: w^T x - z >= 0 -> -w^T x <= -z
    A_right = np.vstack([region.A, (-w).reshape(1, -1)])
    b_right = np.concatenate([region.b, np.array([-z])])

    left_region = PolytopeRegion(A=A_left, b=b_left, depth=depth, tag="left")
    right_region = PolytopeRegion(A=A_right, b=b_right, depth=depth, tag="right")
    return left_region, right_region


def fit_affine_ridge(X: np.ndarray, y: np.ndarray, ridge: float = 1e-8):
    X = np.asarray(X, dtype=float)
    y = np.asarray(y, dtype=float).reshape(-1)
    X_aug = augment_X(X)
    d_aug = X_aug.shape[1]
    beta = solve(X_aug.T @ X_aug + ridge * np.eye(d_aug), X_aug.T @ y)
    y_hat = X_aug @ beta
    return beta, y_hat


def relative_l2_error(y_true: np.ndarray, y_pred: np.ndarray, floor: float = 1e-12) -> float:
    y_true = np.asarray(y_true, dtype=float).reshape(-1)
    y_pred = np.asarray(y_pred, dtype=float).reshape(-1)
    denom = max(np.linalg.norm(y_true), floor)
    return float(np.linalg.norm(y_true - y_pred) / denom)


def sampled_diameter(X: np.ndarray) -> float: # median pairwise distance
    X = np.asarray(X, dtype=float)
    n = X.shape[0]
    if n < 2:
        return 0.0

    dvals = []
    for i in range(n - 1):
        dists = np.linalg.norm(X[i + 1:] - X[i], axis=1)
        if dists.size:
            dvals.append(dists)

    return float(np.median(np.concatenate(dvals)))


class RecursiveSurrogateBuilder:
    def __init__(
        self,
        bounds: np.ndarray,
        oracle: Callable[[np.ndarray], float],
        t0: float,
        max_depth: int,
        eps: float,
        n_samples: int,
        ridge: float = 1e-8,
        w_norm_penalty: float = 0.5,
        t_min: float = 1e-3,
        fit_max_iters: int = 100,
        fit_tol: float = 1e-6,
        fit_alpha0: float = 1.0,
        burn_in: int = 500,
        thinning: int = 10,
        min_side_points: Optional[int] = None,
        random_state: Optional[int] = None,
        fit_verbose: bool = False,
        use_optimizer: bool = True,
    ):
        self.bounds = np.asarray(bounds, dtype=float)
        self.oracle = oracle
        self.t0 = float(t0)
        self.max_depth = int(max_depth)
        self.eps = float(eps)
        self.n_samples = int(n_samples)

        self.ridge = float(ridge)
        self.w_norm_penalty = float(w_norm_penalty)
        self.t_min = float(t_min)

        self.fit_max_iters = int(fit_max_iters)
        self.fit_tol = float(fit_tol)
        self.fit_alpha0 = float(fit_alpha0)

        self.burn_in = int(burn_in)
        self.thinning = int(thinning)
        self.fit_verbose = bool(fit_verbose)
        self.use_optimizer = bool(use_optimizer)
        self.rng = np.random.default_rng(random_state)
        self.oracle_queries = 0

        self.d = self.bounds.shape[0]
        self.min_side_points = max(self.d + 1, 5) if min_side_points is None else int(min_side_points)

        self.root_region = hypercube_to_region(self.bounds, depth=0, tag="root")
        self.root_diameter = None

        self.og_loss = None

    def _next_seed(self) -> int:
        return int(self.rng.integers(0, 2**31 - 1))

    def query_oracle(self, X: np.ndarray) -> np.ndarray:
        X = np.asarray(X, dtype=float)
        y = np.array([self.oracle(x) for x in X], dtype=float)
        self.oracle_queries += X.shape[0]
        return y

    def sample_region(self, region: PolytopeRegion, n_samples: int, x0: Optional[np.ndarray] = None) -> np.ndarray:
        return hit_and_run_sample(
            region.A,
            region.b,
            n_samples=n_samples,
            burn_in=self.burn_in,
            thinning=self.thinning,
            x0=x0,
            seed=self._next_seed(),
        )

    def fit_bilinear(self, X: np.ndarray, y: np.ndarray, t_cell: float, w_reg: Optional[float] = None, use_optimizer: bool = True) -> FitResult:
        
        if w_reg is None:
            w_reg = self.w_norm_penalty

        model = biLinear_fit(
            oracle=None,
            vertices=None,
            t=t_cell,
            n_samples=X.shape[0],
            ridge=self.ridge,
            w_norm_penalty= w_reg,
            random_state=self._next_seed(),
            X=X,
            y=y,
        )
        return model.fit(
            max_iters=self.fit_max_iters,
            tol=self.fit_tol,
            alpha0=self.fit_alpha0,
            verbose=self.fit_verbose,
            regenerate_data=False,
            use_optimizer=use_optimizer,
        )

    def make_leaf(
        self,
        X: np.ndarray,
        y: np.ndarray,
        region: PolytopeRegion,
        depth: int,
        parent,
        node_id: str,
    ) -> AffineLeaf:
        beta, y_hat = fit_affine_ridge(X, y, ridge=self.ridge)
        leaf = AffineLeaf(
            beta=beta,
            parent=parent,
            region=region,
            depth=depth,
            node_id=node_id,
        )
        leaf.rel_error = relative_l2_error(y, y_hat)
        leaf.n_points = int(X.shape[0])
        return leaf

    def build(self) -> SurrogateBuildResult:
        X_root = self.sample_region(self.root_region, self.n_samples, x0=None)
        y_root = self.query_oracle(X_root)

        self.root_diameter = max(sampled_diameter(X_root), 1e-12)

        root = self._build_node(
            region=self.root_region,
            X=X_root,
            y=y_root,
            depth=0,
            t_cell=self.t0,
            w_reg=self.w_norm_penalty,
            parent=None,
            node_id="root",
        )

        tree = PiecewiseLinearTree(root=root)
        tree.oracle_queries = self.oracle_queries           
        tree.root_diameter = self.root_diameter
        tree.bounds = self.bounds.copy()

        return SurrogateBuildResult(
            tree=tree,
            oracle_queries=self.oracle_queries,
            root_diameter=self.root_diameter,
        )

    def _build_node(
        self,
        region: PolytopeRegion,
        X: np.ndarray,
        y: np.ndarray,
        depth: int,
        t_cell: float,
        w_reg: float,
        parent,
        node_id: str,
    ):
        # If we've reached the maximum allowed depth, terminate with a leaf.
        if depth >= self.max_depth:
            return self.make_leaf(X, y, region, depth, parent, node_id)

        # Fit a bilinear split on the current cell samples.
        fit_result = self.fit_bilinear(X, y, t_cell=t_cell, w_reg=w_reg, use_optimizer=self.use_optimizer)
        side = (X @ fit_result.w - fit_result.z) >= 0.0
        n_right = int(np.sum(side))
        n_left = int(X.shape[0] - n_right)

        # For root record initial loss for w_reg scaling
        if depth == 0:
            self.og_loss = fit_result.loss_history[0]

        # Guard against degenerate splits.
        if n_left < self.min_side_points or n_right < self.min_side_points:
            print("Degenerate Split!")
            return self.make_leaf(X, y, region, depth, parent, node_id)

        node = SplitNode(
            w=fit_result.w.copy(),
            z=float(fit_result.z),
            left=None,
            right=None,
            parent=parent,
            region=region,
            depth=depth,
            node_id=node_id,
            fit_result=fit_result,
        )
        node.t_cell = float(t_cell)
        node.n_points = int(X.shape[0])

        left_region, right_region = split_region(region, fit_result.w, fit_result.z, depth=depth + 1)
        left_region.tag = f"{node_id}/L"
        right_region.tag = f"{node_id}/R"

        X_left_parent = X[~side]
        y_left_parent = y[~side]
        X_right_parent = X[side]
        y_right_parent = y[side]

        node.left = self._build_child(
            child_region=left_region,
            x0=X_left_parent[0],
            fallback_X=X_left_parent,
            fallback_y=y_left_parent,
            depth=depth + 1,
            parent=node,
            node_id=f"{node_id}/L",
        )

        node.right = self._build_child(
            child_region=right_region,
            x0=X_right_parent[0],
            fallback_X=X_right_parent,
            fallback_y=y_right_parent,
            depth=depth + 1,
            parent=node,
            node_id=f"{node_id}/R",
        )

        return node

    def _build_child(
        self,
        child_region: PolytopeRegion,
        x0: np.ndarray,
        fallback_X: np.ndarray,
        fallback_y: np.ndarray,
        depth: int,
        parent,
        node_id: str,
    ):
        # Sample the child cell using a feasible point inherited from the parent.
        try:
            X_child = self.sample_region(child_region, self.n_samples, x0=x0)
            y_child = self.query_oracle(X_child)
        except Exception:
            print("H&R failed using fallback from parent")
            # If child sampling fails, fall back to a leaf built from parent-side data.
            return self.make_leaf(fallback_X, fallback_y, child_region, depth, parent, node_id)

        # First check whether a single affine model is already good enough.
        beta_child, y_hat_child = fit_affine_ridge(X_child, y_child, ridge=self.ridge)
        rel_err = relative_l2_error(y_child, y_hat_child)

        if rel_err <= self.eps or depth >= self.max_depth:
            leaf = AffineLeaf(
                beta=beta_child,
                parent=parent,
                region=child_region,
                depth=depth,
                node_id=node_id,
            )
            leaf.rel_error = rel_err
            leaf.n_points = int(X_child.shape[0])
            return leaf

        # Otherwise recurse with cell-adaptive softness.
        D_child = sampled_diameter(X_child)
        t_child = max(self.t_min, self.t0 * D_child / self.root_diameter)
        w_child = max(1e-5, self.w_norm_penalty * (parent.fit_result.loss_history[0] / self.og_loss))

        return self._build_node(
            region=child_region,
            X=X_child,
            y=y_child,
            depth=depth,
            t_cell=t_child,
            w_reg=w_child,
            parent=parent,
            node_id=node_id,
        )

# %% [markdown]
# ## Tests

# %%
from scipy.integrate import solve_ivp


def lorenz96_rhs(_, z, F):
    """
    d-dimensional Lorenz-96 with periodic indexing:
        dz_i/dt = (z_{i+1} - z_{i-2}) z_{i-1} - z_i + F
    valid for d >= 3
    """
    z = np.asarray(z, dtype=float)
    d = z.size

    if d < 3:
        raise ValueError("Lorenz-96 requires d >= 3.")

    dz = np.zeros_like(z)
    for i in range(d):
        dz[i] = (z[(i + 1) % d] - z[(i - 2) % d]) * z[(i - 1) % d] - z[i] + F
    return dz


def make_lorenz96_oracle(t, F, rtol=1e-10, atol=1e-12, method="DOP853"):
    """
    Returns an oracle f: R^d -> R
    Input: z0 in R^d, d >= 3
    Output: first component of z(t), where z solves Lorenz-96

    Parameters
    ----------
    t : float
        Final time
    F : float
        Forcing parameter in Lorenz-96
    rtol, atol : float
        ODE solver tolerances
    method : str
        High-accuracy solve_ivp method, e.g. "DOP853" or "RK45"
    """
    t = float(t)
    F = float(F)

    def oracle(z0):
        z0 = np.asarray(z0, dtype=float).reshape(-1)

        if z0.size < 3:
            raise ValueError("Lorenz-96 oracle requires input dimension d >= 3.")

        sol = solve_ivp(
            fun=lambda tau, z: lorenz96_rhs(tau, z, F),
            t_span=(0.0, t),
            y0=z0,
            method=method,
            rtol=rtol,
            atol=atol,
        )

        if not sol.success:
            raise RuntimeError(f"ODE solve failed: {sol.message}")

        return float(sol.y[0, -1])

    return oracle

# %%
# 2D square: [-1, 1] x [-1, 1]
bounds = np.array([
    [-2.0, 3.0],
    [-2.0, 3.0],
])

def f1_HRT(X):
    X = np.asarray(X, dtype=float)
    x1 = X[0]
    x2 = X[1]

    return (
        0.5 * x1**3
        - 2.0 * x1 * x2**2
        + 3.0 * np.sin(4.0 * x1) * np.cos(2.0 * x2)
        + 0.1 * np.exp(-(x1**2 + x2**2))
    )



# True partition line: w_true . x - z_true = 0
true_w = np.array([1, -1])
true_z = 0.0

# Two affine pieces
beta_left = np.array([1.5, -0.8, 0.2])   # y = 1.5 x1 - 0.8 x2 + 0.2
beta_right = np.array([-0.7, 1.2, -0.1]) # y = -0.7 x1 + 1.2 x2 - 0.1

def rosenbrock_oracle(x, a=1.0, b=100.0):
    x = np.asarray(x, dtype=float).reshape(-1)
    return np.sum((a - x[:-1])**2 + b * (x[1:] - x[:-1]**2)**2)


lorenz_oracle = make_lorenz96_oracle(t=0.1, F=1.0)

z0 = np.array([2.5, 0.5, -0.2, 0.1, 0.0])
val = lorenz_oracle(z0)
print(f"Lorenz-96 value: {val}")


def oracle(x):
    x = np.asarray(x, dtype=float)
    # x_aug = np.append(x, 1.0)
    # if true_w @ x - true_z >= 0.0:
    #     return float(x_aug @ beta_right)
    # return float(x_aug @ beta_left)
    return rosenbrock_oracle(x)
# Out:
# Lorenz-96 value: 2.3593353111303252

# %%
builder = RecursiveSurrogateBuilder(
    bounds=bounds,
    oracle=oracle,
    t0=0.1,
    t_min=1e-5,
    max_depth=12,
    eps=1e-3,
    n_samples=200,
    ridge=1e-8,
    w_norm_penalty=1e3,
    fit_max_iters=200,
    fit_tol=1e-5,
    fit_alpha0=1e-3,
    burn_in=0,
    thinning=10,
    random_state=0,
    min_side_points=1,
    fit_verbose= False,
    use_optimizer=True
)


result = builder.build()
tree = result.tree

# %%
print("oracle queries:", builder.oracle_queries)
print("median root diameter:", builder.root_diameter)
print("tree max depth:", tree.max_depth())
print("Num Leaves:", tree.num_leaves())
print("T range: ", tree.t_range())
# Out:
# oracle queries: 633000
# median root diameter: 2.5360621562075183
# tree max depth: 12
# Num Leaves: 1583
# T range:  (0.0007780508489808394, 0.1)

# %%
metrics = evaluate_error(
    f_true=oracle,
    f_pred=tree.predict_one,
    bounds=bounds,
    n_samples=50000,
    random_state=1,
)

print("relative L2:", metrics["relative_l2_error"])

print("median pointwise rel err:", metrics["median_pointwise_relative_error"])
print("max pointwise rel err:", metrics["max_pointwise_relative_error"])
print("sqrt(E[f^2]) norm:", metrics["L2 norm"])
# Out:
# Data shape: (50000, 2)
# relative L2: 0.0007518901057214866
# median pointwise rel err: 0.0012224533625635622
# max pointwise rel err: 114.69397215440877
# sqrt(E[f^2]) norm: 2112.1916168631437

# %%
print(norm(tree.root.w), norm(tree.root.left.w), norm(tree.root.right.w))
# Out:
# 2.386288088890698 2.3684824300956513 3.1453522095340314

# %%
import numpy as np
import matplotlib.pyplot as plt


def plot_log_contours_2d(predict_fn, bounds, n_grid=200, levels=30, title="Log-Contour Plot"):
    bounds = np.asarray(bounds, dtype=float)
    if bounds.shape != (2, 2):
        raise ValueError("bounds must have shape (2, 2) for a 2D plot.")

    x1_min, x1_max = bounds[0]
    x2_min, x2_max = bounds[1]

    x1 = np.linspace(x1_min, x1_max, n_grid)
    x2 = np.linspace(x2_min, x2_max, n_grid)
    X1, X2 = np.meshgrid(x1, x2)

    Z = np.zeros_like(X1, dtype=float)
    for i in range(n_grid):
        for j in range(n_grid):
            x = np.array([X1[i, j], X2[i, j]])
            Z[i, j] = predict_fn(x)

    # safe log transform
    Z_log = np.log10(np.maximum(np.abs(Z), 1e-12))

    plt.figure(figsize=(6, 5))
    contour = plt.contourf(X1, X2, Z_log, levels=levels, cmap="viridis")
    plt.colorbar(contour, label=r"$\log_{10}(|f(x)|)$")
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(title)
    plt.axis("equal")
    plt.show()

# %%
def collect_fit_info(tree):
    rows = []

    def _walk(node):
        if node is None or isinstance(node, AffineLeaf):
            return

        fr = node.fit_result
        rows.append({
            "node_id": node.node_id,
            "depth": node.depth,
            "t_cell": getattr(node, "t_cell", None),
            "converged": None if fr is None else fr.converged,
            "w": None if fr is None else fr.w,
            "n_iters": None if fr is None else fr.n_iters,
            "final_loss": None if fr is None or len(fr.loss_history) == 0 else fr.loss_history[-1],
            "final_grad_norm": None if fr is None or len(fr.grad_norm_history) == 0 else fr.grad_norm_history[-1],
            "loss_history": None if fr is None else fr.loss_history,
            "grad_norm_history": None if fr is None else fr.grad_norm_history,
            "w_norm_penalty": None if fr is None else fr.w_norm_penalty
        })

        _walk(node.left)
        _walk(node.right)

    _walk(tree.root)
    return rows

# %%
def print_split_fit_summary(tree):
    rows = collect_fit_info(tree)
    failed_rows = [r for r in rows if r["converged"] is False]
    succ_rows = [r for r in rows if r["converged"] is True]

    total = len(rows)
    not_converged = len(failed_rows)

    print(f"split nodes not converged: {not_converged}/{total}")

    for r in rows:
        t_cell = r["t_cell"]
        final_loss = r["final_loss"]
        final_grad = r["final_grad_norm"]
        w_norm = None if r["w"] is None else norm(r["w"])
        w_norm_penalty = r["w_norm_penalty"]

        t_str = "None" if t_cell is None else f"{t_cell:.4e}"
        w_str = "None" if w_norm is None else f"{w_norm:.4e}"
        loss_str = "None" if final_loss is None else f"{final_loss:.4e}"
        grad_str = "None" if final_grad is None else f"{final_grad:.4e}"
        w_norm_penalty_str = "None" if w_norm_penalty is None else f"{w_norm_penalty:.4e}"

        print(
            f"id={r['node_id']}, depth={r['depth']}, t={t_str}, ||w||={w_str}, "
            f"converged={r['converged']}, n_iters={r['n_iters']}, "
            f"final_loss={loss_str}, final_grad_norm={grad_str}, w_norm_penalty={w_norm_penalty_str}"
        )

# %%
from collections import defaultdict

def relative_loss_decrease_summary_by_depth(tree, only_converged=False):
    depth_to_values = defaultdict(list)

    def _walk(node):
        if node is None or isinstance(node, AffineLeaf):
            return

        fr = node.fit_result
        if fr is not None and len(fr.loss_history) >= 2:
            if (not only_converged) or fr.converged:
                loss0 = fr.loss_history[0]
                lossf = fr.loss_history[-1]

                if loss0 != 0:
                    rel_dec = (loss0 - lossf) / loss0
                    depth_to_values[node.depth].append(rel_dec)

        _walk(node.left)
        _walk(node.right)

    _walk(tree.root)

    summary = {}
    for depth, vals in sorted(depth_to_values.items()):
        vals = np.asarray(vals, dtype=float)
        summary[depth] = {
            "n_nodes": len(vals),
            "avg_rel_decrease": float(np.mean(vals)),
            "median_rel_decrease": float(np.median(vals)),
            "min_rel_decrease": float(np.min(vals)),
            "max_rel_decrease": float(np.max(vals)),
        }

    return summary

# %%
from collections import defaultdict

def plot_relative_loss_improvement_histograms_by_depth(
    tree,
    only_converged=False,
    bins=30,
    depth_range=None,
    figsize_per_row=(12, 3.5),
):
    depth_to_values = defaultdict(list)

    def _walk(node):
        if node is None or isinstance(node, AffineLeaf):
            return

        fr = node.fit_result
        if fr is not None and len(fr.loss_history) >= 2:
            if (not only_converged) or fr.converged:
                loss0 = fr.loss_history[0]
                lossf = fr.loss_history[-1]

                if loss0 != 0:
                    rel_improvement = (loss0 - lossf) / loss0
                    depth_to_values[node.depth].append(rel_improvement)

        _walk(node.left)
        _walk(node.right)

    _walk(tree.root)

    if not depth_to_values:
        print("No valid split-node loss histories found.")
        return

    depths = sorted(depth_to_values.keys())
    if depth_range is not None:
        dmin, dmax = depth_range
        depths = [d for d in depths if dmin <= d <= dmax]

    if not depths:
        print("No depths in the requested range.")
        return

    n_depths = len(depths)
    ncols = 3
    nrows = int(np.ceil(n_depths / ncols))

    fig, axes = plt.subplots(
        nrows,
        ncols,
        figsize=(figsize_per_row[0], figsize_per_row[1] * nrows),
        squeeze=False,
    )

    axes_flat = axes.ravel()

    for ax, depth in zip(axes_flat, depths):
        vals = np.asarray(depth_to_values[depth], dtype=float)

        ax.hist(vals, bins=bins, edgecolor="black", alpha=0.8)
        ax.axvline(np.mean(vals), color="red", linestyle="--", linewidth=2, label=f"mean={np.mean(vals):.3f}")
        ax.axvline(np.median(vals), color="green", linestyle=":", linewidth=2, label=f"median={np.median(vals):.3f}")

        ax.set_title(f"Depth {depth} (n={len(vals)})")
        ax.set_xlabel(r"$(L_0 - L_f)/L_0$")
        ax.set_ylabel("Count")
        ax.legend()

    for ax in axes_flat[n_depths:]:
        ax.axis("off")

    fig.suptitle("Relative Loss Improvement by Depth", fontsize=14)
    fig.tight_layout(rect=[0, 0, 1, 0.97])
    plt.show()

# %%
print_split_fit_summary(tree)

# summary = relative_loss_decrease_summary_by_depth(tree)
# for depth, stats in summary.items():
#     print(
#         f"depth={depth}, n={stats['n_nodes']}, "
#         f"avg={stats['avg_rel_decrease']:.6f}, "
#         f"median={stats['median_rel_decrease']:.6f}, "
#         f"min={stats['min_rel_decrease']:.6f}, "
#         f"max={stats['max_rel_decrease']:.6f}"
#     )


# plot_relative_loss_improvement_histograms_by_depth(tree)
# Out:
# split nodes not converged: 1052/1582
# id=root, depth=0, t=1.0000e-01, ||w||=2.3863e+00, converged=False, n_iters=200, final_loss=1.8063e+07, final_grad_norm=2.3305e+05, w_norm_penalty=1.0000e+03
# id=root/L, depth=1, t=8.8382e-02, ||w||=2.3685e+00, converged=False, n_iters=200, final_loss=4.8496e+06, final_grad_norm=4.9072e+04, w_norm_penalty=1.0000e+03
# id=root/L/L, depth=2, t=3.8989e-02, ||w||=2.0499e+00, converged=False, n_iters=200, final_loss=2.5874e+05, final_grad_norm=9.3443e+03, w_norm_penalty=1.0483e+02
# id=root/L/L/L, depth=3, t=2.4044e-02, ||w||=1.1358e+00, converged=False, n_iters=200, final_loss=3.8773e+04, final_grad_norm=9.7935e+03, w_norm_penalty=1.2960e+01
# id=root/L/L/L/L, depth=4, t=2.5662e-02, ||w||=2.4870e+00, converged=True, n_iters=25, final_loss=1.0163e+04, final_grad_norm=1.2267e+02, w_norm_penalty=1.1390e+00
# id=root/L/L/L/L/L, depth=5, t=1.9004e-02, ||w||=1.0971e+00, converged=False, n_iters=200, final_loss=7.0120e+03, final_grad_norm=1.3105e+03, w_norm_penalty=1.2533e-01
# id=root/L/L/L/L/R/R/L, depth=7, t=5.7176e-03, ||w||=9.6578e-01, converged=False, n_iters=200, final_loss=1.1564e+02, final_grad_norm=5.3474e+01, w_norm_penalty=6.1196e-03
# id=root/L/L/L/L/R/R/R, depth=7, t=4.8343e-03, ||w||=9.9734e-01, converged=True, n_iters=193, final_loss=6.4300e+01, final_grad_norm=2.1083e+01, w_norm_penalty=6.1196e-03
# id=root/L/L/L/R, depth=4, t=1.6187e-02, ||w||=2.2741e+00, converged=False, n_iters=200, final_loss=8.9045e+03, final_grad_norm=6.9625e+02, w_norm_penalty=1.1390e+00
# id=root/L/L/L/R/L, depth=5, t=8.7140e-03, ||w||=9.2322e-01, converged=False, n_iters=200, final_loss=5.9952e+02, final_grad_norm=9.9476e+02, w_norm_penalty=1.1370e-01
# id=root/L/L/L/R/L/L, depth=6, t=8.3439e-03, ||w||=1.0853e+00, converged=True, n_iters=132, final_loss=2.8572e+02, final_grad_norm=2.8036e+01, w_norm_penalty=1.6303e-02
# id=root/L/L/L/R/R, depth=5, t=9.2468e-03, ||w||=1.1308e+00, converged=False, n_iters=200, final_loss=2.4680e+03, final_grad_norm=3.7463e+02, w_norm_penalty=1.1370e-01
# id=root/L/L/L/R/R/L, depth=6, t=8.1507e-03, ||w||=1.0624e+00, converged=False, n_iters=200, final_loss=4.2279e+02, final_grad_norm=3.0658e+02, w_norm_penalty=8.7070e-02
# id=root/L/L/L/R/R/R, depth=6, t=9.1533e-03, ||w||=1.0065e+00, converged=True, n_iters=12, final_loss=1.2106e+03, final_grad_norm=8.7493e+01, w_norm_penalty=8.7070e-02
# id=root/L/L/L/R/R/R/L, depth=7, t=5.8425e-03, ||w||=8.7580e-01, converged=False, n_iters=200, final_loss=1.6130e+02, final_grad_norm=1.2553e+02, w_norm_penalty=1.2298e-02
# id=root/L/L/L/R/R/R/R, depth=7, t=4.0797e-03, ||w||=1.0499e+00, converged=False, n_iters=200, final_loss=2.0785e+02, final_grad_norm=7.0362e+02, w_norm_penalty=1.2298e-02
# id=root/L/L/R, depth=3, t=4.2776e-02, ||w||=1.7412e+00, converged=True, n_iters=99, final_loss=5.7596e+04, final_grad_norm=5.5413e+02, w_norm_penalty=1.2960e+01
# id=root/L/L/R/L, depth=4, t=2.8873e-02, ||w||=1.2614e+00, converged=False, n_iters=200, final_loss=1.9232e+04, final_grad_norm=3.6487e+03, w_norm_penalty=6.2573e-01
# id=root/L/L/R/L/L, depth=5, t=2.7610e-02, ||w||=1.9286e+00, converged=False, n_iters=200, final_loss=3.8405e+03, final_grad_norm=9.4704e+02, w_norm_penalty=4.0792e-01
# id=root/L/L/R/L/L/L, depth=6, t=1.4203e-02, ||w||=9.7587e-01, converged=True, n_iters=78, final_loss=2.4483e+03, final_grad_norm=9.3128e+01, w_norm_penalty=5.9945e-02
# id=root/L/L/R/L/L/L/L, depth=7, t=9.5645e-03, ||w||=1.1078e+00, converged=False, n_iters=200, final_loss=1.3522e+03, final_grad_norm=3.2634e+02, w_norm_penalty=2.6431e-02
# id=root/L/L/R/L/L/R/R/L/L/L/L, depth=11, t=1.0955e-03, ||w||=9.9159e-01, converged=False, n_iters=200, final_loss=3.3581e+00, final_grad_norm=7.1669e+00, w_norm_penalty=2.2593e-04
# id=root/L/L/R/L/L/R/R/L/L/R, depth=10, t=2.5347e-03, ||w||=9.5179e-01, converged=False, n_iters=200, final_loss=5.1820e+01, final_grad_norm=6.5514e+01, w_norm_penalty=8.6425e-04
# id=root/L/L/R/L/L/R/R/L/L/R/L, depth=11, t=1.1435e-03, ||w||=9.9925e-01, converged=True, n_iters=4, final_loss=1.7404e+01, final_grad_norm=1.0755e+01, w_norm_penalty=6.0609e-04
# id=root/L/L/R/L/L/R/R/L/L/R/R, depth=11, t=2.1404e-03, ||w||=1.0029e+00, converged=True, n_iters=24, final_loss=6.0036e+01, final_grad_norm=2.1737e+01, w_norm_penalty=6.0609e-04
# id=root/L/L/R/L/L/R/R/L/R, depth=9, t=2.8105e-03, ||w||=1.0494e+00, converged=False, n_iters=200, final_loss=3.0967e+01, final_grad_norm=2.1105e+02, w_norm_penalty=1.3914e-03
# id=root/L/L/R/L/L/R/R/L/R/L, depth=10, t=1.9944e-03, ||w||=1.0009e+00, converged=False, n_iters=200, final_loss=1.5072e+01, final_grad_norm=2.2739e+01, w_norm_penalty=7.8573e-04
# id=root/L/L/R/L/L/R/R/L/R/L/L, depth=11, t=1.6217e-03, ||w||=1.0093e+00, converged=False, n_iters=200, final_loss=9.3693e+00, final_grad_norm=8.0548e+00, w_norm_penalty=1.8399e-04
# id=root/L/L/R/L/L/R/R/L/R/R, depth=10, t=2.1936e-03, ||w||=1.0323e+00, converged=False, n_iters=200, final_loss=2.9674e+00, final_grad_norm=7.6251e+00, w_norm_penalty=7.8573e-04
# id=root/L/L/R/L/L/R/R/R, depth=8, t=5.3204e-03, ||w||=9.9992e-01, converged=True, n_iters=3, final_loss=1.6333e+02, final_grad_norm=1.8914e+01, w_norm_penalty=1.2169e-02
# id=root/L/L/R/L/L/R/R/R/L, depth=9, t=2.7403e-03, ||w||=1.0070e+00, converged=False, n_iters=200, final_loss=1.0833e+01, final_grad_norm=7.7802e+00, w_norm_penalty=1.6316e-03
# id=root/L/L/R/L/L/R/R/R/R, depth=9, t=3.4162e-03, ||w||=1.1077e+00, converged=False, n_iters=200, final_loss=2.1620e+01, final_grad_norm=2.8066e+01, w_norm_penalty=1.6316e-03
# id=root/L/L/R/L/R, depth=5, t=2.7663e-02, ||w||=1.2236e+00, converged=False, n_iters=200, final_loss=4.0694e+03, final_grad_norm=3.1422e+02, w_norm_penalty=4.0792e-01
# id=root/L/L/R/L/R/L, depth=6, t=1.1939e-02, ||w||=1.0539e+00, converged=True, n_iters=25, final_loss=3.6585e+03, final_grad_norm=8.2867e+01, w_norm_penalty=4.2152e-02
# id=root/L/L/R/L/R/L/L, depth=7, t=8.1691e-03, ||w||=7.6299e-01, converged=False, n_iters=200, final_loss=1.8949e+03, final_grad_norm=3.1437e+03, w_norm_penalty=3.6885e-02
# id=root/L/L/R/L/R/R/L/R/L, depth=9, t=5.4069e-03, ||w||=9.8016e-01, converged=False, n_iters=200, final_loss=1.3985e+02, final_grad_norm=1.1211e+02, w_norm_penalty=8.2051e-03
# id=root/L/L/R/L/R/R/L/R/L/L, depth=10, t=4.9841e-03, ||w||=1.0382e+00, converged=False, n_iters=200, final_loss=6.9089e+01, final_grad_norm=9.1391e+00, w_norm_penalty=3.4967e-03
# id=root/L/L/R/L/R/R/L/R/L/L/L, depth=11, t=2.7494e-03, ||w||=9.9784e-01, converged=True, n_iters=4, final_loss=1.0602e+02, final_grad_norm=8.9742e+00, w_norm_penalty=7.0195e-04
# id=root/L/L/R/L/R/R/L/R/R, depth=9, t=6.6597e-03, ||w||=1.0229e+00, converged=True, n_iters=11, final_loss=3.5511e+02, final_grad_norm=2.1068e+01, w_norm_penalty=8.2051e-03
# id=root/L/L/R/L/R/R/L/R/R/L, depth=10, t=3.7346e-03, ||w||=1.0572e+00, converged=False, n_iters=200, final_loss=2.0729e+02, final_grad_norm=1.7054e+02, w_norm_penalty=3.7696e-03
# id=root/L/L/R/L/R/R/L/R/R/L/L, depth=11, t=2.5609e-03, ||w||=9.2019e-01, converged=False, n_iters=200, final_loss=1.1424e+01, final_grad_norm=9.0387e+01, w_norm_penalty=2.2869e-03
# id=root/L/L/R/L/R/R/L/R/R/L/R, depth=11, t=2.2409e-03, ||w||=1.1402e+00, converged=False, n_iters=200, final_loss=1.5991e+02, final_grad_norm=8.0949e+01, w_norm_penalty=2.2869e-03
# id=root/L/L/R/L/R/R/L/R/R/R, depth=10, t=3.9508e-03, ||w||=9.8948e-01, converged=True, n_iters=7, final_loss=3.1352e+02, final_grad_norm=5.5160e+01, w_norm_penalty=3.7696e-03
# id=root/L/L/R/L/R/R/L/R/R/R/R, depth=11, t=3.3491e-03, ||w||=1.0071e+00, converged=False, n_iters=200, final_loss=8.9272e+01, final_grad_norm=3.1367e+02, w_norm_penalty=3.2877e-03
# id=root/L/L/R/L/R/R/R, depth=7, t=9.2299e-03, ||w||=1.0057e+00, converged=True, n_iters=7, final_loss=1.0356e+02, final_grad_norm=5.7125e+00, w_norm_penalty=2.7208e-02
# id=root/L/L/R/L/R/R/R/L, depth=8, t=5.5529e-03, ||w||=1.0076e+00, converged=True, n_iters=8, final_loss=3.4792e+01, final_grad_norm=2.0696e+00, w_norm_penalty=1.0517e-03
# id=root/L/L/R/L/R/R/R/R, depth=8, t=3.9985e-03, ||w||=1.0109e+00, converged=True, n_iters=177, final_loss=3.3796e+01, final_grad_norm=1.3815e+01, w_norm_penalty=1.0517e-03
# id=root/L/L/R/R, depth=4, t=1.8790e-02, ||w||=2.7538e+00, converged=True, n_iters=49, final_loss=1.1439e+04, final_grad_norm=3.8561e+02, w_norm_penalty=6.2573e-01
# id=root/L/L/R/R/L, depth=5, t=1.4389e-02, ||w||=1.0180e+00, converged=True, n_iters=6, final_loss=7.8705e+03, final_grad_norm=1.5997e+02, w_norm_penalty=2.1251e-01
# id=root/L/L/R/R/L/L, depth=6, t=8.7626e-03, ||w||=1.0362e+00, converged=False, n_iters=200, final_loss=9.1410e+02, final_grad_norm=3.5789e+02, w_norm_penalty=7.9089e-02
# id=root/L/L/R/R/L/L/L, depth=7, t=8.7402e-03, ||w||=1.0511e+00, converged=True, n_iters=38, final_loss=3.8623e+02, final_grad_norm=1.7731e+01, w_norm_penalty=1.4404e-02
# id=root/L/L/R/R/L/L/L/L, depth=8, t=5.2161e-03, ||w||=1.0523e+00, converged=False, n_iters=200, final_loss=2.5163e+02, final_grad_norm=4.9583e+01, w_norm_penalty=3.9130e-03
# id=root/L/L/R/R/L/L/L/L/L, depth=9, t=2.1793e-03, ||w||=1.0907e+00, converged=False, n_iters=200, final_loss=1.1242e+01, final_grad_norm=5.9441e+01, w_norm_penalty=3.1078e-03
# id=root/L/L/R/R/L/L/L/L/R, depth=9, t=4.5243e-03, ||w||=9.9541e-01, converged=True, n_iters=6, final_loss=3.4327e+02, final_grad_norm=2.1189e+01, w_norm_penalty=3.1078e-03
# id=root/L/L/R/R/L/L/L/L/R/L, depth=10, t=2.8089e-03, ||w||=1.0269e+00, converged=False, n_iters=200, final_loss=3.0895e+01, final_grad_norm=4.1640e+01, w_norm_penalty=3.4805e-03
# id=root/L/L/R/R/L/L/L/L/R/R, depth=10, t=3.2133e-03, ||w||=9.1970e-01, converged=False, n_iters=200, final_loss=2.8769e+01, final_grad_norm=2.0761e+01, w_norm_penalty=3.4805e-03
# id=root/L/L/R/R/L/L/L/R, depth=8, t=4.6476e-03, ||w||=1.0126e+00, converged=False, n_iters=200, final_loss=2.1395e+02, final_grad_norm=3.6669e+01, w_norm_penalty=3.9130e-03
# id=root/L/L/R/R/L/L/L/R/L, depth=9, t=3.9564e-03, ||w||=9.8501e-01, converged=False, n_iters=200, final_loss=2.8631e+01, final_grad_norm=9.5480e+00, w_norm_penalty=2.4937e-03
# id=root/L/L/R/R/L/L/L/R/R, depth=9, t=1.7207e-03, ||w||=9.8232e-01, converged=False, n_iters=200, final_loss=6.5680e+00, final_grad_norm=2.9888e+01, w_norm_penalty=2.4937e-03
# id=root/L/L/R/R/L/L/R, depth=7, t=5.5214e-03, ||w||=8.2403e-01, converged=False, n_iters=200, final_loss=1.3789e+02, final_grad_norm=6.8299e+01, w_norm_penalty=1.4404e-02
# id=root/L/L/R/R/L/R, depth=6, t=9.0052e-03, ||w||=8.7955e-01, converged=False, n_iters=200, final_loss=1.0305e+03, final_grad_norm=5.4950e+02, w_norm_penalty=7.9089e-02
# id=root/L/L/R/R/L/R/L, depth=7, t=8.4770e-03, ||w||=1.0104e+00, converged=True, n_iters=76, final_loss=7.2568e+02, final_grad_norm=5.6687e+01, w_norm_penalty=2.4123e-02
# id=root/L/L/R/R/L/R/L/L, depth=8, t=4.2986e-03, ||w||=7.8308e-01, converged=False, n_iters=200, final_loss=6.9292e+01, final_grad_norm=2.2534e+02, w_norm_penalty=7.3426e-03
# id=root/L/L/R/R/L/R/L/R, depth=8, t=5.3360e-03, ||w||=9.8340e-01, converged=False, n_iters=200, final_loss=6.7171e+02, final_grad_norm=3.5327e+02, w_norm_penalty=7.3426e-03
# id=root/L/L/R/R/L/R/L/R/L, depth=9, t=3.8209e-03, ||w||=1.2211e+00, converged=True, n_iters=85, final_loss=6.7163e+01, final_grad_norm=2.3303e+01, w_norm_penalty=7.8274e-03
# id=root/L/L/R/R/L/R/L/R/R, depth=9, t=3.7860e-03, ||w||=8.5941e-01, converged=False, n_iters=200, final_loss=1.2857e+02, final_grad_norm=3.0720e+03, w_norm_penalty=7.8274e-03
# id=root/L/L/R/R/L/R/R, depth=7, t=6.6777e-03, ||w||=9.7341e-01, converged=False, n_iters=200, final_loss=1.5377e+02, final_grad_norm=3.7430e+01, w_norm_penalty=2.4123e-02
# id=root/L/L/R/R/L/R/R/L, depth=8, t=6.4417e-03, ||w||=1.0043e+00, converged=True, n_iters=5, final_loss=4.9848e+01, final_grad_norm=6.6644e+00, w_norm_penalty=1.9442e-03
# id=root/L/L/R/R/L/R/R/R, depth=8, t=5.4027e-03, ||w||=1.0124e+00, converged=False, n_iters=200, final_loss=2.6801e+01, final_grad_norm=5.7522e+00, w_norm_penalty=1.9442e-03
# id=root/L/L/R/R/R, depth=5, t=1.8720e-02, ||w||=1.7186e+00, converged=False, n_iters=200, final_loss=2.8322e+03, final_grad_norm=1.5038e+02, w_norm_penalty=2.1251e-01
# id=root/L/L/R/R/R/L, depth=6, t=1.1476e-02, ||w||=1.5787e+00, converged=False, n_iters=200, final_loss=1.5867e+03, final_grad_norm=5.8862e+01, w_norm_penalty=3.2440e-02
# id=root/L/L/R/R/R/L/L, depth=7, t=5.6072e-03, ||w||=1.1530e+00, converged=True, n_iters=182, final_loss=1.8071e+02, final_grad_norm=4.4532e+01, w_norm_penalty=1.8783e-02
# id=root/L/L/R/R/R/L/L/L, depth=8, t=4.0945e-03, ||w||=1.0542e+00, converged=True, n_iters=112, final_loss=1.5104e+02, final_grad_norm=1.7958e+01, w_norm_penalty=1.9810e-02
# id=root/L/L/R/R/R/L/L/L/L, depth=9, t=2.6635e-03, ||w||=9.2583e-01, converged=False, n_iters=200, final_loss=9.8399e+00, final_grad_norm=1.0530e+01, w_norm_penalty=1.5257e-03
# id=root/L/L/R/R/R/L/L/L/R, depth=9, t=2.7526e-03, ||w||=1.0818e+00, converged=False, n_iters=200, final_loss=9.7551e+00, final_grad_norm=1.0173e+01, w_norm_penalty=1.5257e-03
# id=root/L/L/R/R/R/L/L/R, depth=8, t=4.3824e-03, ||w||=1.0607e+00, converged=True, n_iters=102, final_loss=3.0572e+01, final_grad_norm=9.0348e+00, w_norm_penalty=1.9810e-02
# id=root/L/L/R/R/R/L/R, depth=7, t=8.2196e-03, ||w||=1.0234e+00, converged=True, n_iters=86, final_loss=1.2712e+03, final_grad_norm=1.1259e+02, w_norm_penalty=1.8783e-02
# id=root/L/L/R/R/R/L/R/L, depth=8, t=6.9387e-03, ||w||=1.1075e+00, converged=False, n_iters=200, final_loss=1.4580e+03, final_grad_norm=2.4350e+02, w_norm_penalty=1.3749e-02
# id=root/L/L/R/R/R/L/R/L/L, depth=9, t=5.3834e-03, ||w||=1.0677e+00, converged=False, n_iters=200, final_loss=1.3685e+02, final_grad_norm=6.6308e+01, w_norm_penalty=1.6060e-02
# id=root/L/L/R/R/R/L/R/L/L/L, depth=10, t=4.4999e-03, ||w||=1.0528e+00, converged=False, n_iters=200, final_loss=1.0939e+02, final_grad_norm=1.9560e+01, w_norm_penalty=3.0111e-03
# id=root/L/L/R/R/R/L/R/L/L/L/L, depth=11, t=2.6852e-03, ||w||=1.1242e+00, converged=True, n_iters=170, final_loss=9.5318e+01, final_grad_norm=2.4013e+01, w_norm_penalty=1.1134e-03
# id=root/L/L/R/R/R/L/R/L/L/L/R, depth=11, t=2.7759e-03, ||w||=1.0001e+00, converged=True, n_iters=3, final_loss=1.2002e+02, final_grad_norm=3.7261e+00, w_norm_penalty=1.1134e-03
# id=root/L/L/R/R/R/L/R/L/L/R, depth=10, t=4.4626e-03, ||w||=9.9936e-01, converged=True, n_iters=4, final_loss=6.7584e+01, final_grad_norm=4.8175e+00, w_norm_penalty=3.0111e-03
# id=root/L/L/R/R/R/L/R/L/L/R/L, depth=11, t=2.9287e-03, ||w||=1.0612e+00, converged=False, n_iters=200, final_loss=7.8437e+00, final_grad_norm=1.8271e+01, w_norm_penalty=6.7517e-04
# id=root/L/L/R/R/R/L/R/L/L/R/R, depth=11, t=2.7305e-03, ||w||=9.9169e-01, converged=True, n_iters=8, final_loss=6.1292e+01, final_grad_norm=4.6590e+00, w_norm_penalty=6.7517e-04
# id=root/L/L/R/R/R/L/R/L/R, depth=9, t=3.3454e-03, ||w||=9.9966e-01, converged=False, n_iters=200, final_loss=1.6065e+02, final_grad_norm=2.4070e+02, w_norm_penalty=1.6060e-02
# id=root/L/L/R/R/R/L/R/L/R/L, depth=10, t=2.4155e-03, ||w||=9.1067e-01, converged=False, n_iters=200, final_loss=1.1216e+01, final_grad_norm=1.3477e+01, w_norm_penalty=2.3278e-03
# id=root/L/L/R/R/R/L/R/L/R/R, depth=10, t=2.3313e-03, ||w||=9.6755e-01, converged=False, n_iters=200, final_loss=3.1910e+01, final_grad_norm=1.1823e+02, w_norm_penalty=2.3278e-03
# id=root/L/L/R/R/R/L/R/R, depth=8, t=3.4863e-03, ||w||=9.9297e-01, converged=False, n_iters=200, final_loss=4.0222e+02, final_grad_norm=2.0030e+02, w_norm_penalty=1.3749e-02
# id=root/L/L/R/R/R/L/R/R/L, depth=9, t=2.5575e-03, ||w||=9.8510e-01, converged=False, n_iters=200, final_loss=6.4707e+01, final_grad_norm=8.2015e+01, w_norm_penalty=4.1008e-03
# id=root/L/L/R/R/R/L/R/R/L/L, depth=10, t=1.3542e-03, ||w||=9.8581e-01, converged=False, n_iters=200, final_loss=3.4121e+01, final_grad_norm=1.8319e+01, w_norm_penalty=7.7188e-04
# id=root/L/L/R/R/R/L/R/R/L/L/L, depth=11, t=1.2250e-03, ||w||=9.9776e-01, converged=True, n_iters=17, final_loss=3.3826e+00, final_grad_norm=1.6893e+00, w_norm_penalty=3.7539e-04
# id=root/L/L/R/R/R/L/R/R/L/R, depth=10, t=1.9719e-03, ||w||=9.5466e-01, converged=False, n_iters=200, final_loss=1.3846e+01, final_grad_norm=5.4818e+01, w_norm_penalty=7.7188e-04
# id=root/L/L/R/R/R/L/R/R/R, depth=9, t=2.8430e-03, ||w||=9.5575e-01, converged=False, n_iters=200, final_loss=2.5225e+01, final_grad_norm=8.0597e+01, w_norm_penalty=4.1008e-03
# id=root/L/L/R/R/R/L/R/R/R/L, depth=10, t=1.4658e-03, ||w||=9.9945e-01, converged=True, n_iters=8, final_loss=3.2081e+01, final_grad_norm=1.0271e+01, w_norm_penalty=8.9663e-04
# id=root/L/L/R/R/R/L/R/R/R/L/R, depth=11, t=1.0911e-03, ||w||=1.0034e+00, converged=True, n_iters=7, final_loss=3.1089e+00, final_grad_norm=2.4938e+00, w_norm_penalty=3.2428e-04
# id=root/L/L/R/R/R/R, depth=6, t=8.8891e-03, ||w||=1.2844e+00, converged=True, n_iters=93, final_loss=5.6970e+02, final_grad_norm=8.6359e+01, w_norm_penalty=3.2440e-02
# id=root/L/L/R/R/R/R/L, depth=7, t=7.6186e-03, ||w||=1.1993e+00, converged=False, n_iters=200, final_loss=1.5968e+02, final_grad_norm=2.3851e+01, w_norm_penalty=3.2661e-02
# id=root/L/L/R/R/R/R/L/L, depth=8, t=4.5243e-03, ||w||=9.9308e-01, converged=True, n_iters=4, final_loss=1.6601e+02, final_grad_norm=3.0770e+00, w_norm_penalty=1.8908e-03
# id=root/L/L/R/R/R/R/L/L/L, depth=9, t=3.8502e-03, ||w||=9.9239e-01, converged=False, n_iters=200, final_loss=1.0568e+02, final_grad_norm=6.0140e+01, w_norm_penalty=1.7103e-03
# id=root/L/L/R/R/R/R/L/L/L/R, depth=10, t=3.1949e-03, ||w||=1.1217e+00, converged=False, n_iters=200, final_loss=1.5900e+01, final_grad_norm=5.9281e+01, w_norm_penalty=1.2169e-03
# id=root/L/L/R/R/R/R/L/L/R, depth=9, t=2.2997e-03, ||w||=1.0333e+00, converged=False, n_iters=200, final_loss=2.1323e+01, final_grad_norm=2.8553e+01, w_norm_penalty=1.7103e-03
# id=root/L/L/R/R/R/R/L/R, depth=8, t=4.8758e-03, ||w||=1.0863e+00, converged=False, n_iters=200, final_loss=1.1202e+02, final_grad_norm=2.1676e+01, w_norm_penalty=1.8908e-03
# id=root/L/L/R/R/R/R/L/R/L, depth=9, t=3.4489e-03, ||w||=8.6468e-01, converged=False, n_iters=200, final_loss=7.1876e+01, final_grad_norm=4.8924e+01, w_norm_penalty=1.1804e-03
# id=root/L/L/R/R/R/R/L/R/L/L, depth=10, t=2.0147e-03, ||w||=9.9303e-01, converged=False, n_iters=200, final_loss=6.9575e+00, final_grad_norm=1.4553e+01, w_norm_penalty=8.1085e-04
# id=root/L/L/R/R/R/R/L/R/L/R, depth=10, t=2.5841e-03, ||w||=1.0001e+00, converged=False, n_iters=200, final_loss=9.5207e+00, final_grad_norm=1.0158e+01, w_norm_penalty=8.1085e-04
# id=root/L/L/R/R/R/R/L/R/R, depth=9, t=3.1026e-03, ||w||=1.0010e+00, converged=False, n_iters=200, final_loss=2.3368e+01, final_grad_norm=9.1655e+00, w_norm_penalty=1.1804e-03
# id=root/L/L/R/R/R/R/L/R/R/L, depth=10, t=2.0480e-03, ||w||=9.1388e-01, converged=False, n_iters=200, final_loss=5.6949e+00, final_grad_norm=1.1370e+01, w_norm_penalty=2.4744e-04
# id=root/L/L/R/R/R/R/R, depth=7, t=6.9984e-03, ||w||=1.0358e+00, converged=False, n_iters=200, final_loss=2.9334e+02, final_grad_norm=6.1289e+01, w_norm_penalty=3.2661e-02
# id=root/L/L/R/R/R/R/R/L, depth=8, t=4.9874e-03, ||w||=9.3964e-01, converged=False, n_iters=200, final_loss=2.1982e+02, final_grad_norm=1.3788e+02, w_norm_penalty=3.1675e-03
# id=root/L/L/R/R/R/R/R/L/L, depth=9, t=3.8346e-03, ||w||=1.0071e+00, converged=False, n_iters=200, final_loss=2.3311e+02, final_grad_norm=1.1384e+02, w_norm_penalty=2.7338e-03
# id=root/L/L/R/R/R/R/R/L/L/L, depth=10, t=3.3439e-03, ||w||=7.8289e-01, converged=False, n_iters=200, final_loss=2.9153e+01, final_grad_norm=2.4265e+01, w_norm_penalty=2.5504e-03
# id=root/L/L/R/R/R/R/R/L/L/R, depth=10, t=2.1107e-03, ||w||=1.0173e+00, converged=False, n_iters=200, final_loss=8.1652e+00, final_grad_norm=4.1030e+00, w_norm_penalty=2.5504e-03
# id=root/L/L/R/R/R/R/R/R, depth=8, t=3.8570e-03, ||w||=8.2638e-01, converged=False, n_iters=200, final_loss=4.3338e+01, final_grad_norm=1.0350e+02, w_norm_penalty=3.1675e-03
# id=root/L/R, depth=2, t=8.3385e-02, ||w||=4.2581e+00, converged=True, n_iters=33, final_loss=3.5005e+06, final_grad_norm=1.7594e+04, w_norm_penalty=1.0483e+02
# id=root/L/R/L, depth=3, t=7.1761e-02, ||w||=3.4622e+00, converged=True, n_iters=108, final_loss=1.3925e+06, final_grad_norm=4.7300e+03, w_norm_penalty=5.9263e+01
# id=root/L/R/L/L, depth=4, t=5.0321e-02, ||w||=3.4727e+00, converged=True, n_iters=43, final_loss=2.1140e+05, final_grad_norm=1.3935e+03, w_norm_penalty=2.1295e+01
# id=root/L/R/L/L/L, depth=5, t=4.0611e-02, ||w||=1.9238e+00, converged=True, n_iters=94, final_loss=4.4294e+04, final_grad_norm=3.6194e+02, w_norm_penalty=3.1775e+00
# id=root/L/R/L/L/L/L, depth=6, t=2.2844e-02, ||w||=1.9409e+00, converged=False, n_iters=200, final_loss=4.9126e+03, final_grad_norm=1.5684e+02, w_norm_penalty=5.8650e-01
# id=root/L/R/L/L/L/L/L, depth=7, t=1.7380e-02, ||w||=1.6264e+00, converged=False, n_iters=200, final_loss=1.5710e+03, final_grad_norm=4.5833e+01, w_norm_penalty=5.2898e-02
# id=root/L/R/L/L/L/L/L/R/R/R, depth=10, t=5.2210e-03, ||w||=1.0431e+00, converged=False, n_iters=200, final_loss=1.8062e+01, final_grad_norm=6.5547e+00, w_norm_penalty=7.8421e-04
# id=root/L/R/L/L/L/L/L/R/R/R/L, depth=11, t=3.5105e-03, ||w||=1.0339e+00, converged=False, n_iters=200, final_loss=5.0713e+00, final_grad_norm=1.5415e+00, w_norm_penalty=2.4345e-04
# id=root/L/R/L/L/L/L/L/R/R/R/R, depth=11, t=4.4154e-03, ||w||=9.9016e-01, converged=False, n_iters=200, final_loss=6.9901e+00, final_grad_norm=1.8087e+00, w_norm_penalty=2.4345e-04
# ...
# id=root/R/R/L/R/R/L, depth=6, t=9.6903e-03, ||w||=1.0441e+00, converged=False, n_iters=200, final_loss=2.1362e+04, final_grad_norm=1.6421e+04, w_norm_penalty=2.5273e+00
# id=root/R/R/L/R/R/L/L, depth=7, t=7.0203e-03, ||w||=1.0020e+00, converged=True, n_iters=3, final_loss=2.4377e+04, final_grad_norm=7.4182e+02, w_norm_penalty=4.4711e-01
# id=root/R/R/L/R/R/L/L/L, depth=8, t=3.8798e-03, ||w||=1.0040e+00, converged=True, n_iters=6, final_loss=1.1359e+04, final_grad_norm=2.3295e+03, w_norm_penalty=2.4533e-01
# id=root/R/R/L/R/R/L/L/L/L, depth=9, t=3.7179e-03, ||w||=9.8840e-01, converged=False, n_iters=200, final_loss=2.8619e+03, final_grad_norm=6.1955e+03, w_norm_penalty=1.3261e-01
# id=root/R/R/L/R/R/L/L/R, depth=8, t=5.0801e-03, ||w||=9.9844e-01, converged=True, n_iters=9, final_loss=2.1086e+04, final_grad_norm=4.2441e+03, w_norm_penalty=2.4533e-01
# id=root/R/R/L/R/R/L/L/R/L, depth=9, t=4.7694e-03, ||w||=1.0188e+00, converged=False, n_iters=200, final_loss=2.1990e+03, final_grad_norm=4.6494e+03, w_norm_penalty=2.3479e-01
# id=root/R/R/L/R/R/L/R, depth=7, t=8.2393e-03, ||w||=1.0886e+00, converged=True, n_iters=94, final_loss=1.7430e+03, final_grad_norm=8.2091e+02, w_norm_penalty=4.4711e-01
# id=root/R/R/L/R/R/R, depth=6, t=1.0823e-02, ||w||=6.3617e-01, converged=False, n_iters=200, final_loss=2.5995e+04, final_grad_norm=7.7753e+04, w_norm_penalty=2.5273e+00
# id=root/R/R/L/R/R/R/L, depth=7, t=8.8769e-03, ||w||=9.9793e-01, converged=True, n_iters=8, final_loss=9.1656e+03, final_grad_norm=1.1364e+03, w_norm_penalty=1.2768e+00
# id=root/R/R/L/R/R/R/L/L, depth=8, t=4.7187e-03, ||w||=1.0049e+00, converged=True, n_iters=84, final_loss=8.3619e+02, final_grad_norm=5.3361e+02, w_norm_penalty=9.1902e-02
# id=root/R/R/L/R/R/R/L/R, depth=8, t=5.4585e-03, ||w||=1.0313e+00, converged=False, n_iters=200, final_loss=7.9813e+02, final_grad_norm=4.7472e+02, w_norm_penalty=9.1902e-02
# id=root/R/R/L/R/R/R/R, depth=7, t=9.6419e-03, ||w||=9.9847e-01, converged=True, n_iters=7, final_loss=1.0886e+04, final_grad_norm=5.4546e+02, w_norm_penalty=1.2768e+00
# id=root/R/R/L/R/R/R/R/L, depth=8, t=5.4575e-03, ||w||=9.8248e-01, converged=True, n_iters=192, final_loss=1.3810e+03, final_grad_norm=7.9134e+02, w_norm_penalty=1.1099e-01
# id=root/R/R/R, depth=3, t=2.9699e-02, ||w||=1.0813e+00, converged=False, n_iters=200, final_loss=1.4328e+05, final_grad_norm=4.1400e+04, w_norm_penalty=2.3896e+02
# id=root/R/R/R/L, depth=4, t=2.7574e-02, ||w||=1.0604e+00, converged=True, n_iters=8, final_loss=8.0303e+04, final_grad_norm=2.7048e+02, w_norm_penalty=1.4588e+01
# id=root/R/R/R/L/L, depth=5, t=1.6450e-02, ||w||=9.3498e-01, converged=False, n_iters=200, final_loss=7.2456e+04, final_grad_norm=8.1666e+03, w_norm_penalty=8.1217e-01
# id=root/R/R/R/L/L/L, depth=6, t=1.4023e-02, ||w||=8.2316e-01, converged=False, n_iters=200, final_loss=1.1670e+04, final_grad_norm=7.0245e+03, w_norm_penalty=8.7433e-01
# id=root/R/R/R/L/L/L/L, depth=7, t=1.1937e-02, ||w||=1.0107e+00, converged=False, n_iters=200, final_loss=1.7741e+03, final_grad_norm=7.2323e+02, w_norm_penalty=6.9435e-01
# id=root/R/R/R/L/L/L/L/L, depth=8, t=1.2061e-02, ||w||=2.3572e+00, converged=False, n_iters=200, final_loss=3.3760e+02, final_grad_norm=1.6211e+01, w_norm_penalty=1.8211e-02
# id=root/R/R/R/L/L/L/L/R, depth=8, t=1.1315e-02, ||w||=9.9938e-01, converged=True, n_iters=3, final_loss=3.9244e+02, final_grad_norm=1.5066e+01, w_norm_penalty=1.8211e-02
# id=root/R/R/R/L/L/L/R, depth=7, t=1.2466e-02, ||w||=1.0105e+00, converged=False, n_iters=200, final_loss=2.3906e+03, final_grad_norm=1.0635e+03, w_norm_penalty=6.9435e-01
# id=root/R/R/R/L/L/L/R/L, depth=8, t=1.3993e-02, ||w||=1.0046e+00, converged=True, n_iters=4, final_loss=4.1072e+02, final_grad_norm=1.6496e+01, w_norm_penalty=3.4791e-02
# id=root/R/R/R/L/L/R, depth=6, t=7.0648e-03, ||w||=8.9510e-01, converged=False, n_iters=200, final_loss=1.1957e+03, final_grad_norm=1.7390e+03, w_norm_penalty=8.7433e-01
# id=root/R/R/R/L/L/R/L, depth=7, t=6.7666e-03, ||w||=1.0026e+00, converged=True, n_iters=4, final_loss=7.0649e+02, final_grad_norm=5.2076e+01, w_norm_penalty=8.1982e-02
# id=root/R/R/R/L/L/R/L/R, depth=8, t=3.8008e-03, ||w||=9.9365e-01, converged=True, n_iters=4, final_loss=6.0631e+02, final_grad_norm=1.8404e+01, w_norm_penalty=7.0607e-03
# id=root/R/R/R/L/L/R/L/R/L, depth=9, t=3.3302e-03, ||w||=9.9459e-01, converged=True, n_iters=4, final_loss=6.6860e+02, final_grad_norm=5.7943e+01, w_norm_penalty=7.0678e-03
# id=root/R/R/R/L/L/R/R, depth=7, t=3.7413e-03, ||w||=9.2278e-01, converged=False, n_iters=200, final_loss=1.6010e+02, final_grad_norm=5.6775e+02, w_norm_penalty=8.1982e-02
# id=root/R/R/R/L/R, depth=5, t=1.3906e-02, ||w||=1.4822e+00, converged=False, n_iters=200, final_loss=7.4459e+04, final_grad_norm=9.5887e+03, w_norm_penalty=8.1217e-01
# id=root/R/R/R/L/R/L, depth=6, t=5.5536e-03, ||w||=8.2727e-01, converged=False, n_iters=200, final_loss=2.6167e+03, final_grad_norm=5.0199e+03, w_norm_penalty=8.2394e-01
# id=root/R/R/R/L/R/L/L, depth=7, t=2.8645e-03, ||w||=1.0254e+00, converged=False, n_iters=200, final_loss=2.5186e+03, final_grad_norm=7.7839e+02, w_norm_penalty=9.4892e-02
# id=root/R/R/R/L/R/L/L/L, depth=8, t=2.4961e-03, ||w||=1.0028e+00, converged=True, n_iters=98, final_loss=3.0459e+02, final_grad_norm=1.9414e+02, w_norm_penalty=2.6361e-02
# id=root/R/R/R/L/R/R, depth=6, t=1.1985e-02, ||w||=1.0045e+00, converged=False, n_iters=200, final_loss=8.4248e+03, final_grad_norm=2.2983e+03, w_norm_penalty=8.2394e-01
# id=root/R/R/R/L/R/R/L, depth=7, t=1.0054e-02, ||w||=9.5277e-01, converged=False, n_iters=200, final_loss=1.3493e+03, final_grad_norm=1.6009e+03, w_norm_penalty=5.7291e-01
# id=root/R/R/R/L/R/R/L/L, depth=8, t=1.0152e-02, ||w||=1.7245e+00, converged=True, n_iters=8, final_loss=3.4370e+02, final_grad_norm=4.8766e+00, w_norm_penalty=5.7197e-02
# id=root/R/R/R/L/R/R/R, depth=7, t=1.0530e-02, ||w||=8.2053e-01, converged=False, n_iters=200, final_loss=1.6599e+03, final_grad_norm=1.6840e+03, w_norm_penalty=5.7291e-01
# id=root/R/R/R/R, depth=4, t=2.8490e-02, ||w||=1.2510e+00, converged=False, n_iters=200, final_loss=3.4851e+04, final_grad_norm=6.7413e+03, w_norm_penalty=1.4588e+01
# id=root/R/R/R/R/L, depth=5, t=2.6817e-02, ||w||=1.5653e+00, converged=True, n_iters=149, final_loss=7.4205e+03, final_grad_norm=7.6163e+01, w_norm_penalty=6.7485e-01
# id=root/R/R/R/R/L/L, depth=6, t=1.2051e-02, ||w||=1.0132e+00, converged=True, n_iters=12, final_loss=5.0516e+03, final_grad_norm=1.3590e+02, w_norm_penalty=7.6264e-02
# id=root/R/R/R/R/L/L/L, depth=7, t=8.4057e-03, ||w||=9.8601e-01, converged=True, n_iters=12, final_loss=2.9864e+03, final_grad_norm=2.2911e+02, w_norm_penalty=5.0949e-02
# id=root/R/R/R/R/L/L/L/L, depth=8, t=6.6073e-03, ||w||=1.1197e+00, converged=True, n_iters=52, final_loss=3.6023e+03, final_grad_norm=1.9448e+02, w_norm_penalty=3.7237e-02
# id=root/R/R/R/R/L/L/L/L/L, depth=9, t=5.4066e-03, ||w||=8.7210e-01, converged=False, n_iters=200, final_loss=3.9055e+02, final_grad_norm=1.7183e+02, w_norm_penalty=3.7241e-02
# id=root/R/R/R/R/L/L/L/L/R, depth=9, t=3.1430e-03, ||w||=9.3396e-01, converged=False, n_iters=200, final_loss=7.5386e+02, final_grad_norm=1.7862e+03, w_norm_penalty=3.7241e-02
# id=root/R/R/R/R/L/L/L/L/R/L, depth=10, t=1.9447e-03, ||w||=9.3929e-01, converged=False, n_iters=200, final_loss=5.5403e+01, final_grad_norm=2.2765e+02, w_norm_penalty=1.0216e-02
# id=root/R/R/R/R/L/L/L/L/R/R, depth=10, t=2.5969e-03, ||w||=9.9959e-01, converged=True, n_iters=5, final_loss=8.8244e+02, final_grad_norm=3.1122e+02, w_norm_penalty=1.0216e-02
# id=root/R/R/R/R/L/L/L/L/R/R/L, depth=11, t=2.0514e-03, ||w||=9.9780e-01, converged=False, n_iters=200, final_loss=7.2060e+01, final_grad_norm=1.0443e+02, w_norm_penalty=1.0123e-02
# id=root/R/R/R/R/L/L/L/R, depth=8, t=3.2479e-03, ||w||=9.6804e-01, converged=False, n_iters=200, final_loss=8.5664e+02, final_grad_norm=4.9867e+03, w_norm_penalty=3.7237e-02
# id=root/R/R/R/R/L/L/L/R/L, depth=9, t=2.8906e-03, ||w||=1.0033e+00, converged=False, n_iters=200, final_loss=1.8837e+02, final_grad_norm=1.0545e+02, w_norm_penalty=9.7045e-03
# id=root/R/R/R/R/L/L/R, depth=7, t=6.3750e-03, ||w||=9.4760e-01, converged=False, n_iters=200, final_loss=3.5738e+03, final_grad_norm=1.9487e+03, w_norm_penalty=5.0949e-02
# id=root/R/R/R/R/L/L/R/L, depth=8, t=4.5908e-03, ||w||=9.9991e-01, converged=True, n_iters=12, final_loss=4.6235e+03, final_grad_norm=3.5471e+02, w_norm_penalty=3.9895e-02
# id=root/R/R/R/R/L/L/R/L/L, depth=9, t=2.0411e-03, ||w||=9.7020e-01, converged=False, n_iters=200, final_loss=2.5435e+02, final_grad_norm=9.5312e+02, w_norm_penalty=5.0628e-02
# id=root/R/R/R/R/L/L/R/L/R, depth=9, t=3.8671e-03, ||w||=9.5591e-01, converged=True, n_iters=102, final_loss=4.0277e+02, final_grad_norm=1.7277e+02, w_norm_penalty=5.0628e-02
# id=root/R/R/R/R/L/L/R/L/R/R, depth=10, t=2.8170e-03, ||w||=9.3365e-01, converged=False, n_iters=200, final_loss=7.5643e+01, final_grad_norm=3.3411e+02, w_norm_penalty=1.6612e-02
# id=root/R/R/R/R/L/L/R/R, depth=8, t=4.7003e-03, ||w||=1.1748e+00, converged=False, n_iters=200, final_loss=1.4614e+03, final_grad_norm=1.1066e+02, w_norm_penalty=3.9895e-02
# id=root/R/R/R/R/L/L/R/R/L, depth=9, t=3.9443e-03, ||w||=9.9774e-01, converged=True, n_iters=177, final_loss=2.2958e+02, final_grad_norm=8.2094e+01, w_norm_penalty=1.6797e-02
# id=root/R/R/R/R/L/R, depth=6, t=1.5138e-02, ||w||=1.0410e+00, converged=False, n_iters=200, final_loss=3.6613e+03, final_grad_norm=1.3114e+03, w_norm_penalty=7.6264e-02
# id=root/R/R/R/R/L/R/L, depth=7, t=1.3698e-02, ||w||=9.8934e-01, converged=True, n_iters=6, final_loss=5.1210e+02, final_grad_norm=1.3534e+01, w_norm_penalty=3.8575e-02
# id=root/R/R/R/R/L/R/L/R, depth=8, t=7.1765e-03, ||w||=1.0067e+00, converged=True, n_iters=4, final_loss=6.4394e+02, final_grad_norm=5.3505e+00, w_norm_penalty=5.2420e-03
# id=root/R/R/R/R/L/R/R, depth=7, t=1.6025e-02, ||w||=1.2974e+00, converged=False, n_iters=200, final_loss=5.5041e+02, final_grad_norm=2.7842e+01, w_norm_penalty=3.8575e-02
# id=root/R/R/R/R/L/R/R/L, depth=8, t=8.0866e-03, ||w||=9.9595e-01, converged=True, n_iters=6, final_loss=4.7685e+02, final_grad_norm=1.7643e+01, w_norm_penalty=2.4300e-02
# id=root/R/R/R/R/L/R/R/L/L, depth=9, t=4.5137e-03, ||w||=1.0004e+00, converged=True, n_iters=3, final_loss=3.7217e+02, final_grad_norm=1.1115e+01, w_norm_penalty=4.8253e-03
# id=root/R/R/R/R/L/R/R/L/L/L, depth=10, t=2.8224e-03, ||w||=8.9561e-01, converged=True, n_iters=193, final_loss=3.4643e+01, final_grad_norm=2.0544e+01, w_norm_penalty=3.7211e-03
# id=root/R/R/R/R/L/R/R/L/L/R, depth=10, t=2.9674e-03, ||w||=9.1165e-01, converged=False, n_iters=200, final_loss=1.4689e+02, final_grad_norm=1.4016e+03, w_norm_penalty=3.7211e-03
# id=root/R/R/R/R/L/R/R/R, depth=8, t=7.7829e-03, ||w||=1.0582e+00, converged=True, n_iters=45, final_loss=4.4436e+02, final_grad_norm=3.3835e+01, w_norm_penalty=2.4300e-02
# id=root/R/R/R/R/R, depth=5, t=2.9288e-02, ||w||=1.5084e+00, converged=True, n_iters=172, final_loss=4.2892e+03, final_grad_norm=3.6455e+01, w_norm_penalty=6.7485e-01
# id=root/R/R/R/R/R/L, depth=6, t=1.5178e-02, ||w||=1.2623e+00, converged=False, n_iters=200, final_loss=3.4562e+03, final_grad_norm=2.0517e+02, w_norm_penalty=4.5254e-02
# id=root/R/R/R/R/R/L/L, depth=7, t=1.0699e-02, ||w||=1.1753e+00, converged=False, n_iters=200, final_loss=8.0801e+02, final_grad_norm=2.2555e+02, w_norm_penalty=3.7892e-02
# id=root/R/R/R/R/R/L/L/L, depth=8, t=9.6272e-03, ||w||=1.0068e+00, converged=True, n_iters=5, final_loss=2.4421e+02, final_grad_norm=5.7019e+00, w_norm_penalty=3.1417e-02
# id=root/R/R/R/R/R/L/L/L/L, depth=9, t=4.2769e-03, ||w||=1.0000e+00, converged=True, n_iters=6, final_loss=2.1392e+02, final_grad_norm=1.8705e+01, w_norm_penalty=2.4830e-03
# id=root/R/R/R/R/R/L/L/R, depth=8, t=9.9046e-03, ||w||=1.0004e+00, converged=True, n_iters=4, final_loss=2.2290e+02, final_grad_norm=6.1183e+00, w_norm_penalty=3.1417e-02
# id=root/R/R/R/R/R/L/L/R/L, depth=9, t=5.2537e-03, ||w||=8.5920e-01, converged=False, n_iters=200, final_loss=6.6818e+01, final_grad_norm=1.4334e+02, w_norm_penalty=2.3360e-03
# id=root/R/R/R/R/R/L/L/R/R, depth=9, t=5.4171e-03, ||w||=1.0013e+00, converged=False, n_iters=200, final_loss=5.7356e+01, final_grad_norm=1.8771e+01, w_norm_penalty=2.3360e-03
# id=root/R/R/R/R/R/L/R, depth=7, t=6.8532e-03, ||w||=9.4641e-01, converged=False, n_iters=200, final_loss=4.5137e+02, final_grad_norm=1.7580e+02, w_norm_penalty=3.7892e-02
# id=root/R/R/R/R/R/L/R/L, depth=8, t=6.9332e-03, ||w||=9.8630e-01, converged=True, n_iters=18, final_loss=2.1005e+02, final_grad_norm=1.3068e+01, w_norm_penalty=1.6806e-02
# id=root/R/R/R/R/R/L/R/L/L, depth=9, t=3.1602e-03, ||w||=9.9815e-01, converged=True, n_iters=4, final_loss=2.0952e+02, final_grad_norm=3.3302e+01, w_norm_penalty=2.1637e-03
# id=root/R/R/R/R/R/L/R/L/L/L, depth=10, t=2.4231e-03, ||w||=9.9643e-01, converged=False, n_iters=200, final_loss=1.0960e+02, final_grad_norm=1.4739e+02, w_norm_penalty=2.1326e-03
# id=root/R/R/R/R/R/L/R/L/L/L/L, depth=11, t=1.7995e-03, ||w||=9.7215e-01, converged=False, n_iters=200, final_loss=1.3051e+02, final_grad_norm=6.8352e+01, w_norm_penalty=1.1777e-03
# id=root/R/R/R/R/R/L/R/L/L/R, depth=10, t=1.8216e-03, ||w||=9.8733e-01, converged=False, n_iters=200, final_loss=1.3843e+02, final_grad_norm=1.7697e+02, w_norm_penalty=2.1326e-03
# id=root/R/R/R/R/R/L/R/L/L/R/R, depth=11, t=1.4131e-03, ||w||=9.7599e-01, converged=False, n_iters=200, final_loss=3.9904e+01, final_grad_norm=9.7478e+01, w_norm_penalty=1.4491e-03
# id=root/R/R/R/R/R/L/R/L/R, depth=9, t=4.0364e-03, ||w||=9.9473e-01, converged=True, n_iters=8, final_loss=1.9814e+02, final_grad_norm=4.6932e+00, w_norm_penalty=2.1637e-03
# id=root/R/R/R/R/R/L/R/L/R/L, depth=10, t=2.3634e-03, ||w||=9.9932e-01, converged=True, n_iters=18, final_loss=2.0784e+02, final_grad_norm=2.4982e+01, w_norm_penalty=1.9849e-03
# id=root/R/R/R/R/R/L/R/R, depth=8, t=5.7688e-03, ||w||=9.9735e-01, converged=True, n_iters=6, final_loss=3.5774e+02, final_grad_norm=2.4206e+01, w_norm_penalty=1.6806e-02
# id=root/R/R/R/R/R/L/R/R/L, depth=9, t=3.0652e-03, ||w||=9.9935e-01, converged=True, n_iters=4, final_loss=3.2023e+02, final_grad_norm=2.5058e+01, w_norm_penalty=3.6965e-03
# id=root/R/R/R/R/R/L/R/R/L/L, depth=10, t=2.1102e-03, ||w||=1.0020e+00, converged=True, n_iters=6, final_loss=2.3930e+01, final_grad_norm=1.8218e+01, w_norm_penalty=3.2017e-03
# id=root/R/R/R/R/R/L/R/R/L/R, depth=10, t=2.2828e-03, ||w||=9.9808e-01, converged=False, n_iters=200, final_loss=3.1790e+01, final_grad_norm=1.0317e+02, w_norm_penalty=3.2017e-03
# id=root/R/R/R/R/R/L/R/R/R, depth=9, t=3.6219e-03, ||w||=1.0003e+00, converged=True, n_iters=3, final_loss=3.4454e+02, final_grad_norm=2.8636e+01, w_norm_penalty=3.6965e-03
# id=root/R/R/R/R/R/L/R/R/R/L, depth=10, t=2.3308e-03, ||w||=1.0219e+00, converged=True, n_iters=35, final_loss=3.2334e+01, final_grad_norm=2.0209e+01, w_norm_penalty=3.4443e-03
# id=root/R/R/R/R/R/L/R/R/R/R, depth=10, t=2.4393e-03, ||w||=1.0029e+00, converged=True, n_iters=6, final_loss=3.3221e+02, final_grad_norm=7.5044e+01, w_norm_penalty=3.4443e-03
# id=root/R/R/R/R/R/L/R/R/R/R/R, depth=11, t=2.4711e-03, ||w||=9.7514e-01, converged=False, n_iters=200, final_loss=3.1951e+02, final_grad_norm=7.4830e+01, w_norm_penalty=3.6040e-03
# id=root/R/R/R/R/R/R, depth=6, t=1.2407e-02, ||w||=1.1102e+00, converged=True, n_iters=185, final_loss=2.4008e+03, final_grad_norm=1.5893e+02, w_norm_penalty=4.5254e-02
# id=root/R/R/R/R/R/R/L, depth=7, t=7.4784e-03, ||w||=1.1330e+00, converged=False, n_iters=200, final_loss=3.8091e+02, final_grad_norm=1.9609e+02, w_norm_penalty=2.4789e-02
# id=root/R/R/R/R/R/R/L/L, depth=8, t=7.3567e-03, ||w||=9.6119e-01, converged=False, n_iters=200, final_loss=1.8802e+02, final_grad_norm=4.0241e+01, w_norm_penalty=1.4422e-02
# id=root/R/R/R/R/R/R/L/R, depth=8, t=5.9797e-03, ||w||=1.0510e+00, converged=False, n_iters=200, final_loss=9.1855e+01, final_grad_norm=2.2447e+01, w_norm_penalty=1.4422e-02
# id=root/R/R/R/R/R/R/R, depth=7, t=6.4295e-03, ||w||=7.3491e-01, converged=False, n_iters=200, final_loss=3.6663e+02, final_grad_norm=6.3582e+02, w_norm_penalty=2.4789e-02

# %%
# /L/L/L/L/L/R/R
v = tree.get_node("root")
plt.plot(v.fit_result.loss_history)
# plt.plot(v.fit_result.grad_norm_history)
# plt.plot(tree.root.right.right.right.right.right.right.right.right.right.fit_result))
print(v.fit_result.w_norm_penalty)
# Out:
# 1000.0

# %%
nood = tree.root.right.right.right.right.right.right.left.right.right.left.left
plt.plot(nood.fit_result.loss_history)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 nood = tree.root.right.right.right.right.right.right.left.right.right.left.left
#       2 plt.plot(nood.fit_result.loss_history)
#
# AttributeError: 'AffineLeaf' object has no attribute 'left'

# %%
print(norm(nood.w))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [81], in <module>
# ----> 1 print(norm(nood.w))
#
# NameError: name 'nood' is not defined

# %%
from matplotlib.colors import ListedColormap


def plot_leaf_regions_with_contours_2d(tree, bounds, oracle, n_grid=300, n_contours=20,
                                       title="Leaf Regions with Oracle Contours"):
    bounds = np.asarray(bounds, dtype=float)
    if bounds.shape != (2, 2):
        raise ValueError("bounds must have shape (2, 2)")

    x1_min, x1_max = bounds[0]
    x2_min, x2_max = bounds[1]

    x1 = np.linspace(x1_min, x1_max, n_grid)
    x2 = np.linspace(x2_min, x2_max, n_grid)
    X1, X2 = np.meshgrid(x1, x2)
    Xg = np.column_stack([X1.ravel(), X2.ravel()])

    # Leaf assignment
    leaf_objs = [tree.leaf_for_point(x) for x in Xg]
    leaf_ids = [id(leaf) for leaf in leaf_objs]
    unique_leaf_ids = sorted(set(leaf_ids))
    leaf_to_label = {leaf_id: k for k, leaf_id in enumerate(unique_leaf_ids)}
    Z = np.array([leaf_to_label[leaf_id] for leaf_id in leaf_ids], dtype=int).reshape(n_grid, n_grid)

    n_leaves = len(unique_leaf_ids)

    # Adjacency graph for contrasting colors
    adjacency = {k: set() for k in range(n_leaves)}

    for i in range(n_grid - 1):
        for j in range(n_grid):
            a, b = Z[i, j], Z[i + 1, j]
            if a != b:
                adjacency[a].add(b)
                adjacency[b].add(a)

    for i in range(n_grid):
        for j in range(n_grid - 1):
            a, b = Z[i, j], Z[i, j + 1]
            if a != b:
                adjacency[a].add(b)
                adjacency[b].add(a)

    palette = [
        "#e41a1c", "#377eb8", "#4daf4a", "#984ea3", "#ff7f00",
        "#ffff33", "#a65628", "#f781bf", "#17becf", "#7f7f7f",
        "#1b9e77", "#d95f02", "#7570b3", "#66a61e", "#e6ab02",
        "#a6761d", "#666666"
    ]

    order = sorted(range(n_leaves), key=lambda k: len(adjacency[k]), reverse=True)
    color_idx = {}

    for node in order:
        used = {color_idx[nbr] for nbr in adjacency[node] if nbr in color_idx}
        for c in range(len(palette)):
            if c not in used:
                color_idx[node] = c
                break
        else:
            color_idx[node] = node % len(palette)

    Z_color = np.vectorize(lambda z: color_idx[z])(Z)
    cmap = ListedColormap(palette)

    # Oracle values and log contours
    # F = np.array([oracle(x) for x in Xg], dtype=float).reshape(n_grid, n_grid)
    # F_log = np.log10(np.maximum(np.abs(F), 1e-12))

    plt.figure(figsize=(6, 6))
    plt.pcolormesh(X1, X2, Z_color, shading="auto", cmap=cmap, alpha=1.0)

    # cs = plt.contour(X1, X2, F_log, levels=n_contours, colors="black", linewidths=1.0)
    # plt.clabel(cs, inline=True, fontsize=8, fmt="%.2f")

    rect = np.array([
        [x1_min, x2_min],
        [x1_max, x2_min],
        [x1_max, x2_max],
        [x1_min, x2_max],
        [x1_min, x2_min],
    ])
    plt.plot(rect[:, 0], rect[:, 1], color="black", lw=2)

    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(title)
    plt.gca().set_aspect("equal")
    plt.show()

# %%
plot_leaf_regions_with_contours_2d(
    tree=tree,
    bounds=bounds,
    oracle=oracle,
    n_grid=300,
    n_contours=20,
    title="Leaf Regions - Rosenbrock"
)

# %%
plot_log_contours_2d(
    predict_fn=tree.predict_one,
    bounds=bounds,
    n_grid=250,
    title="Tree Surrogate Log-Contours"
)
