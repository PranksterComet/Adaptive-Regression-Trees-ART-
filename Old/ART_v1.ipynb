# %%
import numpy as np
import random
from numpy.linalg import solve, norm
from dataclasses import dataclass
from typing import Callable, Optional, Dict, Any, Union
import matplotlib.pyplot as plt

# %%
def sigmoid(x: np.ndarray) -> np.ndarray:
    # numerically safer sigmoid
    x = np.clip(x, -50.0, 50.0)
    return 1.0 / (1.0 + np.exp(-x))


def augment_X(X: np.ndarray) -> np.ndarray:
    """
    Append a column of ones for affine models.
    X: (n, d)
    returns: (n, d+1)
    """
    n = X.shape[0]
    return np.hstack([X, np.ones((n, 1))])


def sample_uniform_simplex(vertices: np.ndarray, n_samples: int, rng=None) -> np.ndarray:
    """
    Uniformly sample points from a d-simplex in R^d given by d+1 vertices.

    vertices: shape (d+1, d)
    returns: shape (n_samples, d)
    """
    if rng is None:
        rng = np.random.default_rng()

    m, d = vertices.shape
    if m != d + 1:
        raise ValueError(
            f"For simplex sampling, expected vertices.shape = (d+1, d), got {vertices.shape}."
        )

    # Dirichlet(1,...,1) gives uniform barycentric coordinates
    bary = rng.dirichlet(alpha=np.ones(m), size=n_samples)  # (n_samples, d+1)
    return bary @ vertices

# %%
def evaluate_error(
    f_true,
    f_pred,
    bounds: np.ndarray,
    n_samples: int,
    random_state: int = 0,
    rel_floor: float = 1e-12,
):
    """
    Compare two scalar-valued functions on random points sampled uniformly
    from a hypercube / hyper-rectangle.

    Parameters
    ----------
    f_true : callable
        Ground-truth function, takes x and returns scalar.
    f_pred : callable
        Surrogate/prediction function, takes x and returns scalar.
    bounds : np.ndarray
        Array of shape (d, 2), where bounds[i] = [low_i, high_i].
    n_samples : int
        Number of random evaluation points.
    random_state : int
        RNG seed.
    rel_floor : float
        Stabilizer for pointwise relative error near zero.

    Returns
    -------
    dict with aggregate error metrics and sampled values.
    """
    bounds = np.asarray(bounds, dtype=float)
    if bounds.ndim != 2 or bounds.shape[1] != 2:
        raise ValueError(f"bounds must have shape (d, 2), got {bounds.shape}")

    lows = bounds[:, 0]
    highs = bounds[:, 1]
    if np.any(lows >= highs):
        raise ValueError("Each bound must satisfy low < high.")

    rng = np.random.default_rng(random_state)
    X = rng.uniform(lows, highs, size=(n_samples, bounds.shape[0]))
    print("Data shape:", X.shape)

    y_true = np.array([f_true(x) for x in X], dtype=float)
    y_pred = np.array([f_pred(x) for x in X], dtype=float)

    abs_err = np.abs(y_true - y_pred)
    sq_err = (y_true - y_pred) ** 2
    pointwise_rel_err = abs_err / np.maximum(np.abs(y_true), rel_floor)

    rel_l2 = np.linalg.norm(y_true - y_pred) / max(np.linalg.norm(y_true), rel_floor)
    rmse = float(np.sqrt(np.mean(sq_err)))
    mae = float(np.mean(abs_err))
    median_rel = float(np.median(pointwise_rel_err))
    max_rel = float(np.max(pointwise_rel_err))

    return {
        "relative_l2_error": float(rel_l2),
        "median_pointwise_relative_error": median_rel,
        "max_pointwise_relative_error": max_rel,
        "abs_err": abs_err,
        "pointwise_relative_error": pointwise_rel_err,
        "L2 norm": float(np.linalg.norm(y_true / np.sqrt(len(y_true)))),
    }

# %% [markdown]
# ## Tree Setup

# %%
@dataclass
class PolytopeRegion:
    """
    Polyhedral region represented as A x <= b.
    """
    A: np.ndarray
    b: np.ndarray
    depth: int = 0
    tag: Optional[str] = None


@dataclass
class AffineLeaf:
    beta: np.ndarray
    parent: Optional[Any] = None
    region: Optional[PolytopeRegion] = None
    depth: int = 0
    node_id: Optional[str] = None

    def predict_one(self, x: np.ndarray) -> float:
        x = np.asarray(x, dtype=float)
        x_aug = np.append(x, 1.0)
        return float(x_aug @ self.beta)


@dataclass
class SplitNode:
    w: np.ndarray
    z: float
    left: Any
    right: Any
    parent: Optional[Any] = None
    region: Optional[PolytopeRegion] = None
    depth: int = 0
    node_id: Optional[str] = None
    fit_result: Optional[Any] = None

    def route(self, x: np.ndarray):
        x = np.asarray(x, dtype=float)
        if float(self.w @ x - self.z) >= 0.0:
            return self.right
        return self.left


TreeNode = Union[AffineLeaf, SplitNode]


class PiecewiseLinearTree:
    def __init__(self, root: Optional[TreeNode] = None):
        self.root = root

    def predict_one(self, x: np.ndarray) -> float:
        if self.root is None:
            raise ValueError("Tree has no root node.")

        node = self.root
        while isinstance(node, SplitNode):
            node = node.route(x)

        return node.predict_one(x)

    def predict(self, X: np.ndarray) -> np.ndarray:
        X = np.asarray(X, dtype=float)
        return np.array([self.predict_one(x) for x in X], dtype=float)

    def leaf_for_point(self, x: np.ndarray) -> AffineLeaf:
        if self.root is None:
            raise ValueError("Tree has no root node.")

        node = self.root
        while isinstance(node, SplitNode):
            node = node.route(x)

        return node
    
    def num_leaves(self) -> int:
        def _count(node) -> int:
            if isinstance(node, AffineLeaf):
                return 1
            return _count(node.left) + _count(node.right)

        if self.root is None:
            return 
        return _count(self.root)


    def max_depth(self) -> int:
        def _depth(node):
            if isinstance(node, AffineLeaf):
                return 0
            return 1 + max(_depth(node.left), _depth(node.right))

        if self.root is None:
            return 0
        return _depth(self.root)
    
    def t_range(self):
        vals = []

        def _walk(node):
            if node is None:
                return
            t = getattr(node, "t_cell", None)
            if t is not None:
                vals.append(float(t))
            if isinstance(node, SplitNode):
                _walk(node.left)
                _walk(node.right)

        _walk(self.root)

        if not vals:
            return None
        return min(vals), max(vals)

    def get_node(self, node_id) -> TreeNode:
        if self.root is None:
            raise ValueError("Tree has no root node.")

        if node_id in ("root", "", None):
            return self.root

        parts = node_id.split("/")
        if parts[0] != "root":
            raise ValueError(f"node_id must start with 'root', got {node_id!r}")

        node = self.root
        for step in parts[1:]:
            if isinstance(node, AffineLeaf):
                raise ValueError(f"Path {node_id!r} goes past a leaf at {node.node_id!r}")
            if step == "L":
                node = node.left
            elif step == "R":
                node = node.right
            else:
                raise ValueError(f"Invalid step {step!r} in {node_id!r}")

        return node

# %%
@dataclass
class FitResult:
    w: np.ndarray
    z: float
    beta0: np.ndarray
    beta1: np.ndarray
    loss_history: list
    grad_norm_history: list
    n_iters: int
    converged: bool
    w_norm_penalty: float
    X: np.ndarray
    y: np.ndarray
    pi: np.ndarray


class biLinear_fit:
    """
    Soft hyperplane-gated two-affine-model fit:
        pi_i = sigmoid((w^T x_i - z)/t)

    Objective:
        sum_i (1-pi_i) (y_i - <beta0, x~_i>)^2
      + sum_i pi_i     (y_i - <beta1, x~_i>)^2

    where x~_i = [x_i; 1].
    """

    def __init__(
        self,
        oracle: Optional[Callable[[np.ndarray], float]] = None,
        vertices: Optional[np.ndarray] = None,
        t: float = 1.0,
        n_samples: int = 500,
        ridge: float = 1e-8,
        w_norm_penalty: float = 0.5,
        random_state: Optional[int] = None,
        X: Optional[np.ndarray] = None,
        y: Optional[np.ndarray] = None,
    ):

        """
        oracle: function f: R^d -> R
        vertices: simplex vertices, shape (d+1, d)
        t: fixed sigmoid sharpness parameter
        n_samples: number of queried points
        ridge: ridge regularization for weighted LS
        """
        self.oracle = oracle
        self.vertices = None if vertices is None else np.asarray(vertices, dtype=float)
        self.t = float(t)
        self.n_samples = int(n_samples)
        self.ridge = float(ridge)
        self.w_norm_penalty = float(w_norm_penalty)
        self.rng = np.random.default_rng(random_state)

        self.X = None
        self.y = None

        if X is not None or y is not None:
            if X is None or y is None:
                raise ValueError("If providing data directly, both X and y must be given.")

            X = np.asarray(X, dtype=float)
            y = np.asarray(y, dtype=float).reshape(-1)

            if X.ndim != 2:
                raise ValueError(f"X must have shape (n, d), got {X.shape}.")
            if y.ndim != 1:
                raise ValueError(f"y must have shape (n,), got {y.shape}.")
            if X.shape[0] != y.shape[0]:
                raise ValueError(
                    f"X and y must have the same number of samples, got {X.shape[0]} and {y.shape[0]}."
                )

            self.X = X.copy()
            self.y = y.copy()
            self.d = X.shape[1]
            self.data_provided = True

        else:
            if oracle is None:
                raise ValueError("oracle must be provided when X, y are not given.")
            if self.vertices is None:
                raise ValueError("vertices must be provided when X, y are not given.")

            m, d = self.vertices.shape
            if m != d + 1:
                raise ValueError(
                    "Current implementation assumes domain is a simplex with shape (d+1, d)."
                )

            self.d = d
            self.data_provided = False

        self.w = None
        self.z = None
        self.beta0 = None
        self.beta1 = None

        self.loss_history = []
        self.grad_norm_history = []

    # ----------------------------
    # Sampling / data generation
    # ----------------------------
    def sample_domain(self) -> np.ndarray:
        return sample_uniform_simplex(self.vertices, self.n_samples, rng=self.rng)

    def query_oracle(self, X: np.ndarray) -> np.ndarray:
        y = np.array([self.oracle(x) for x in X], dtype=float)
        return y

    def generate_data(self):
        if self.data_provided:
            return
        self.X = self.sample_domain()
        self.y = self.query_oracle(self.X)
    # ----------------------------
    # Initialization
    # ----------------------------
    def initialize_params(self, beta_sep: float = 1e-3):
        """
        Simple initialization:
        - random unit w
        - z = median(w^T x)
        - beta0, beta1 initialized as small perturbations of a global affine fit

        This avoids the degenerate beta0 == beta1 case without doing
        additional split-dependent least-squares solves.
        """
        w = self.rng.normal(size=self.d)
        w /= max(norm(w), 1e-12)

        proj = self.X @ w
        z = float(np.median(proj))

        X_aug = augment_X(self.X)
        A = X_aug.T @ X_aug + self.ridge * np.eye(self.d + 1)
        b = X_aug.T @ self.y
        beta_global = solve(A, b)

        delta = self.rng.normal(size=self.d + 1)
        delta /= max(norm(delta), 1e-12)
        delta *= beta_sep * max(1.0, norm(beta_global))

        self.w = w
        self.z = z
        self.beta0 = beta_global - delta
        self.beta1 = beta_global + delta

    # ----------------------------
    # Core model pieces
    # ----------------------------
    def compute_pi(self, w: np.ndarray, z: float) -> np.ndarray:
        s = (self.X @ w - z) / self.t
        return sigmoid(s)

    def solve_weighted_ls(self, pi: np.ndarray):
        """
        Solve for beta0, beta1 exactly, given fixed pi.
        """
        X_aug = augment_X(self.X)
        I = np.eye(self.d + 1)

        w0 = 1.0 - pi
        w1 = pi

        # Weighted normal equations
        # X^T W X = X^T (diag(w)) X = (X * w[:,None])^T X
        A0 = X_aug.T @ (X_aug * w0[:, None]) + self.ridge * I
        b0 = X_aug.T @ (self.y * w0)

        A1 = X_aug.T @ (X_aug * w1[:, None]) + self.ridge * I
        b1 = X_aug.T @ (self.y * w1)

        beta0 = solve(A0, b0)
        beta1 = solve(A1, b1)

        return beta0, beta1

    def objective(self, w: np.ndarray, z: float, beta0: np.ndarray, beta1: np.ndarray) -> float:
        pi = self.compute_pi(w, z)
        X_aug = augment_X(self.X)

        r0 = self.y - X_aug @ beta0
        r1 = self.y - X_aug @ beta1

        val = np.sum((1.0 - pi) * (r0 ** 2) + pi * (r1 ** 2))
        wpenalty = 0.5 * self.w_norm_penalty * ((np.dot(w, w) - 1.0) ** 2)
        return 0.5 * float(val) + wpenalty

    def reduced_objective(self, w: np.ndarray, z: float):
        """
        E(w,z) = min_{beta0,beta1} J(beta0,beta1,w,z)
        """
        pi = self.compute_pi(w, z)
        beta0, beta1 = self.solve_weighted_ls(pi)
        val = self.objective(w, z, beta0, beta1)
        return val, pi, beta0, beta1

    def gradient_wz_given_betas(
        self, w: np.ndarray, z: float, beta0: np.ndarray, beta1: np.ndarray
    ):
        """
        Gradient wrt (w,z), holding beta0,beta1 fixed.

        J = 1/2 sum_i [ (1-pi_i) r0_i^2 + pi_i r1_i^2 ]

        dJ/dpi_i = 1/2 (r1_i^2 - r0_i^2)
        dpi_i/ds_i = pi_i(1-pi_i)
        s_i = (w^T x_i - z)/t
        """
        pi = self.compute_pi(w, z)
        X_aug = augment_X(self.X)

        r0 = self.y - X_aug @ beta0
        r1 = self.y - X_aug @ beta1

        coeff = 0.5 * (r1**2 - r0**2) * pi * (1.0 - pi)  # shape (n,)

        grad_w = (self.X.T @ coeff) / self.t
        grad_w += 2 * self.w_norm_penalty * (np.dot(w, w) - 1.0) * w
        grad_z = -np.sum(coeff) / self.t

        return grad_w, float(grad_z)

    # ----------------------------
    # Backtracking GD on (w, z)
    # ----------------------------
    def backtracking_step(
        self,
        w: np.ndarray,
        z: float,
        beta0: np.ndarray,
        beta1: np.ndarray,
        grad_w: np.ndarray,
        grad_z: float,
        alpha0: float = 1.0,
        rho: float = 0.5, #0.5
        c: float = 1e-4,
        max_backtracks: int = 25, #25
    ):
        """
        Backtracking line search on reduced objective.
        After proposing (w_new,z_new), we re-solve weighted LS.
        """
        curr_val = self.objective(w, z, beta0, beta1)

        grad_vec = np.concatenate([grad_w, np.array([grad_z])])
        grad_sq = np.dot(grad_vec, grad_vec)

        alpha = alpha0
        for _ in range(max_backtracks):
            w_new = w - alpha * grad_w
            w_norm = norm(w_new)
            if w_norm < 1e-12:
                alpha *= rho
                continue
            
            # w_new = w_new / w_norm
            z_new = z - alpha * grad_z
            # z_new = z_new / w_norm

            new_val = self.objective(w_new, z_new, beta0, beta1)

            # Armijo condition on frozen-beta objective
            if new_val <= curr_val - c * alpha * grad_sq:
                # print("succesful stepsize:", alpha)
                pi_new = self.compute_pi(w_new, z_new)
                return w_new, z_new, pi_new, beta0, beta1, new_val, alpha

            alpha *= rho

        # fallback: no successful step
        pi_curr = self.compute_pi(w, z)
        return w, z, pi_curr, beta0, beta1, curr_val, 0.0

    # ----------------------------
    # Main fit loop
    # ----------------------------
    def fit(
        self,
        max_iters: int = 100,
        tol: float = 1e-6,
        alpha0: float = 1.0,
        verbose: bool = True,
        regenerate_data: bool = True,
        use_optimizer: bool = True,
    ) -> FitResult:

        if self.data_provided:
            regenerate_data = False

        if regenerate_data or self.X is None or self.y is None:
            self.generate_data()

        self.initialize_params()

        converged = False
        if not use_optimizer:
            converged = True
            pi = self.compute_pi(self.w, self.z)
            self.beta0, self.beta1 = self.solve_weighted_ls(pi)
            curr_loss = self.objective(self.w, self.z, self.beta0, self.beta1)
            grad_w, grad_z = self.gradient_wz_given_betas(
                self.w, self.z, self.beta0, self.beta1
            )
            grad_norm = np.sqrt(np.dot(grad_w, grad_w) + grad_z**2)

            self.loss_history.append(curr_loss)
            self.grad_norm_history.append(grad_norm)

            if verbose:
                print(
                    f"iter=0 | loss={curr_loss:.6e} | grad_norm={grad_norm:.6e}"
                )

        for k in range(max_iters):
            if not use_optimizer:
                break
            # exact beta update for current (w,z)
            pi = self.compute_pi(self.w, self.z)
            self.beta0, self.beta1 = self.solve_weighted_ls(pi)

            # evaluate reduced objective
            curr_loss = self.objective(self.w, self.z, self.beta0, self.beta1)

            # gradient wrt (w,z), holding betas fixed
            grad_w, grad_z = self.gradient_wz_given_betas(
                self.w, self.z, self.beta0, self.beta1
            )
            grad_norm = np.sqrt(np.dot(grad_w, grad_w) + grad_z**2)

            self.loss_history.append(curr_loss)
            self.grad_norm_history.append(grad_norm)

            if verbose and (k % 10 == 0 or k == max_iters - 1):
                print(
                    f"iter={k:3d} | loss={curr_loss:.6e} | grad_norm={grad_norm:.6e}"
                )

            if grad_norm < tol:
                converged = True
                break

            # backtracking update on (w,z), betas are frozen here 
            self.w, self.z, pi, self.beta0, self.beta1, new_loss, step = self.backtracking_step(
                self.w,
                self.z,
                self.beta0,
                self.beta1,
                grad_w,
                grad_z,
                alpha0=alpha0,
            )

            # Control w, z sizes
            # w_norm = norm(self.w)
            # self.w = self.w / w_norm
            # self.z = self.z / w_norm

            # re-fit betas after accepting the (w,z) step
            pi = self.compute_pi(self.w, self.z)
            self.beta0, self.beta1 = self.solve_weighted_ls(pi)
            new_loss = self.objective(self.w, self.z, self.beta0, self.beta1)

            if step == 0.0:
                print("Backtracking failed to find a descent step.")
                break

            if abs(curr_loss - new_loss) < tol * max(1.0, abs(curr_loss)):
                converged = True
                self.loss_history.append(new_loss)
                self.grad_norm_history.append(grad_norm)
                break

        final_pi = self.compute_pi(self.w, self.z)

        return FitResult(
            w=self.w.copy(),
            z=float(self.z),
            beta0=self.beta0.copy(),
            beta1=self.beta1.copy(),
            loss_history=self.loss_history.copy(),
            grad_norm_history=self.grad_norm_history.copy(),
            n_iters=len(self.loss_history),
            converged=converged,
            w_norm_penalty=self.w_norm_penalty,
            X=self.X.copy(),
            y=self.y.copy(),
            pi=final_pi.copy(),
        )

    # ----------------------------
    # Prediction helpers
    # ----------------------------
    def predict_soft(self, X_new: np.ndarray) -> np.ndarray:
        X_new = np.asarray(X_new, dtype=float)
        X_aug = augment_X(X_new)
        pi = sigmoid((X_new @ self.w - self.z) / self.t)
        y0 = X_aug @ self.beta0
        y1 = X_aug @ self.beta1

        # soft blended prediction; useful for visualization only
        return (1.0 - pi) * y0 + pi * y1

    def predict_hard(self, X_new: np.ndarray) -> np.ndarray:
        X_new = np.asarray(X_new, dtype=float)
        X_aug = augment_X(X_new)
        side = (X_new @ self.w - self.z) >= 0.0
        y0 = X_aug @ self.beta0
        y1 = X_aug @ self.beta1
        return np.where(side, y1, y0)

# %%
# 2D simplex (triangle)
vertices = np.array([
    [0.0, 0.0],
    [1.0, 0.0],
    [0.2, 1.0],
])

true_w = np.array([1, -1])
true_z = 0.0


def oracle(x):
    # true split: x0 + x1 = 0.75
    if true_w[0]*x[0] + true_w[1]*x[1] < true_z:
        return 2.0 * x[0] - 1.0 * x[1] + 0.3
    else:
        return -1.5 * x[0] + 2.5 * x[1] - 0.2

model = biLinear_fit(
    oracle=oracle,
    vertices=vertices,
    t=0.02, #0.01
    n_samples=10, #250
    ridge=1e-8,
    random_state=3,
)

result = model.fit(max_iters=250, tol=1e-5, alpha0=1.0, verbose=True, use_optimizer=False)

print("converged:", result.converged)
print("w =", result.w)
print("z =", result.z)
print("beta0 =", result.beta0)
print("beta1 =", result.beta1)

# Plot loss history
plt.figure(figsize=(6, 4))
plt.plot(result.loss_history, linewidth=2)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# iter=0 | loss=5.610102e-01 | grad_norm=4.791052e-01
# converged: True
# w = [-0.94988712 -0.31259313]
# z = -0.42485139172021547
# beta0 = [-2.27532273 -0.46280356  1.17078907]
# beta1 = [-0.22475387  0.63442898 -0.22895758]

# %%
# Plot loss history
plt.figure(figsize=(6, 4))
plt.plot(result.grad_norm_history, linewidth=2)
plt.xlabel("Iteration")
plt.ylabel("Grad Norm")
plt.title("Grad Norm Hist")
plt.grid(True, alpha=0.3)
plt.show()

# %%
def plot_two_partition_lines(vertices, true_w, true_z, pred_w, pred_z, X=None):
    vertices = np.asarray(vertices, dtype=float)
    if vertices.shape != (3, 2):
        raise ValueError("This function expects a 2D simplex with shape (3, 2).")

    def clipped_line_in_triangle(w, z, verts, tol=1e-10):
        pts = []
        edges = [(0, 1), (1, 2), (2, 0)]

        for i, j in edges:
            a = verts[i]
            b = verts[j]
            d = b - a

            denom = np.dot(w, d)
            numer = z - np.dot(w, a)

            if abs(denom) < tol:
                continue

            t = numer / denom
            if -tol <= t <= 1 + tol:
                p = a + t * d
                pts.append(p)

        uniq = []
        for p in pts:
            if not any(np.linalg.norm(p - q) < 1e-8 for q in uniq):
                uniq.append(p)

        if len(uniq) >= 2:
            return np.array(uniq[:2])
        return None

    fig, ax = plt.subplots(figsize=(6, 6))

    # simplex
    closed = np.vstack([vertices, vertices[0]])
    ax.plot(closed[:, 0], closed[:, 1], color="black", lw=2, label="Simplex")

    # sampled points colored by true side
    if X is not None:
        X = np.asarray(X, dtype=float)
        true_side = (X @ true_w - true_z) >= 0.0

        ax.scatter(
            X[~true_side, 0], X[~true_side, 1],
            color="tab:blue", s=20, alpha=0.8, label="True side < 0"
        )
        ax.scatter(
            X[true_side, 0], X[true_side, 1],
            color="tab:orange", s=20, alpha=0.8, label="True side >= 0"
        )

    # lines
    true_seg = clipped_line_in_triangle(true_w, true_z, vertices)
    pred_seg = clipped_line_in_triangle(pred_w, pred_z, vertices)

    if true_seg is not None:
        ax.plot(true_seg[:, 0], true_seg[:, 1], color="blue", lw=2.5, label="True line")

    if pred_seg is not None:
        ax.plot(pred_seg[:, 0], pred_seg[:, 1], color="red", lw=2.5, ls="--", label="Predicted line")

    ax.set_aspect("equal")
    ax.set_xlabel("x1")
    ax.set_ylabel("x2")
    ax.set_title("True vs Predicted Partition Line")
    ax.legend()
    plt.show()

# %%
plot_two_partition_lines(
    vertices=model.vertices,
    true_w=true_w,
    true_z=true_z,
    pred_w=result.w,
    pred_z=result.z,
    X=result.X,
)

# %% [markdown]
# ## Uniform Sampling Convex Polyhedra

# %%
def find_feasible_point(A, b, max_tries=20000, seed=0):
    rng = np.random.default_rng(seed)
    d = A.shape[1]
    for _ in range(max_tries):
        x = rng.uniform(-1.0, 1.0, size=d)
        if np.all(A @ x <= b):
            return x
    raise RuntimeError("Could not find a feasible starting point.")

# Mixing time scales as O(d^3) verify this
def hit_and_run_sample(A, b, n_samples, burn_in=1000, thinning=10, x0=None, seed=0):
    rng = np.random.default_rng(seed)
    m, d = A.shape

    if x0 is None:
        x = find_feasible_point(A, b, seed=seed)
    else:
        x = np.array(x0, dtype=float)
        if not np.all(A @ x <= b):
            raise ValueError("x0 is not feasible.")
    
    samples = []
    total_steps = burn_in + n_samples * thinning

    for step in range(total_steps):
        u = rng.normal(size=d)
        u /= np.linalg.norm(u)

        Au = A @ u
        Ax = A @ x

        t_low = -np.inf
        t_high = np.inf

        for i in range(m):
            if abs(Au[i]) < 1e-14:
                if Ax[i] > b[i]:
                    raise RuntimeError("Current point became infeasible.")
                continue

            t = (b[i] - Ax[i]) / Au[i]
            if Au[i] > 0:
                t_high = min(t_high, t)
            else:
                t_low = max(t_low, t)

        if t_low > t_high:
            raise RuntimeError("Empty step interval encountered.")

        t_new = rng.uniform(t_low, t_high)
        x = x + t_new * u

        if step >= burn_in and (step - burn_in) % thinning == 0:
            samples.append(x.copy())

    return np.array(samples)

# %%
A = np.array([
    [ 0.0,  1.0],
    [ 0.95,  0.31],
    [ 0.59, -0.81],
    [-0.59, -0.81],
    [-0.95,  0.31],
])
b = np.ones(5)


pts = hit_and_run_sample(A, b, n_samples=2000, burn_in=1000, thinning=5, seed=1)

print(pts.shape)
print(np.all(A @ pts.T <= b[:, None] + 1e-10))

plt.figure(figsize=(5, 5))
plt.scatter(pts[:, 0], pts[:, 1], s=6, alpha=0.5)
plt.plot([0, 1, 0, 0], [0, 0, 1, 0], "r-")
plt.gca().set_aspect("equal")
plt.show()
# Out:
# (2000, 2)
# True

# %% [markdown]
# ## Recursive Partitioning

# %%
@dataclass
class SurrogateBuildResult:
    tree: PiecewiseLinearTree
    oracle_queries: int
    root_diameter: float


def hypercube_to_region(bounds: np.ndarray, depth: int = 0, tag: Optional[str] = None) -> PolytopeRegion:
    bounds = np.asarray(bounds, dtype=float)
    if bounds.ndim != 2 or bounds.shape[1] != 2:
        raise ValueError(f"bounds must have shape (d, 2), got {bounds.shape}")

    lows = bounds[:, 0]
    highs = bounds[:, 1]
    if np.any(lows >= highs):
        raise ValueError("Each bound must satisfy low < high.")

    d = bounds.shape[0]
    A = np.vstack([np.eye(d), -np.eye(d)])
    b = np.concatenate([highs, -lows])
    return PolytopeRegion(A=A, b=b, depth=depth, tag=tag)


def split_region(region: PolytopeRegion, w: np.ndarray, z: float, depth: int):
    # left:  w^T x - z < 0  ->  w^T x <= z
    A_left = np.vstack([region.A, w.reshape(1, -1)])
    b_left = np.concatenate([region.b, np.array([z])])

    # right: w^T x - z >= 0 -> -w^T x <= -z
    A_right = np.vstack([region.A, (-w).reshape(1, -1)])
    b_right = np.concatenate([region.b, np.array([-z])])

    left_region = PolytopeRegion(A=A_left, b=b_left, depth=depth, tag="left")
    right_region = PolytopeRegion(A=A_right, b=b_right, depth=depth, tag="right")
    return left_region, right_region


def fit_affine_ridge(X: np.ndarray, y: np.ndarray, ridge: float = 1e-8):
    X = np.asarray(X, dtype=float)
    y = np.asarray(y, dtype=float).reshape(-1)
    X_aug = augment_X(X)
    d_aug = X_aug.shape[1]
    beta = solve(X_aug.T @ X_aug + ridge * np.eye(d_aug), X_aug.T @ y)
    y_hat = X_aug @ beta
    return beta, y_hat


def relative_l2_error(y_true: np.ndarray, y_pred: np.ndarray, floor: float = 1e-12) -> float:
    y_true = np.asarray(y_true, dtype=float).reshape(-1)
    y_pred = np.asarray(y_pred, dtype=float).reshape(-1)
    denom = max(np.linalg.norm(y_true), floor)
    return float(np.linalg.norm(y_true - y_pred) / denom)


def sampled_diameter(X: np.ndarray) -> float: # median pairwise distance
    X = np.asarray(X, dtype=float)
    n = X.shape[0]
    if n < 2:
        return 0.0

    dvals = []
    for i in range(n - 1):
        dists = np.linalg.norm(X[i + 1:] - X[i], axis=1)
        if dists.size:
            dvals.append(dists)

    return float(np.median(np.concatenate(dvals)))


class RecursiveSurrogateBuilder:
    def __init__(
        self,
        bounds: np.ndarray,
        oracle: Callable[[np.ndarray], float],
        t0: float,
        max_depth: int,
        eps: float,
        n_samples: int,
        ridge: float = 1e-8,
        w_norm_penalty: float = 0.5,
        t_min: float = 1e-3,
        fit_max_iters: int = 100,
        fit_tol: float = 1e-6,
        fit_alpha0: float = 1.0,
        burn_in: int = 500,
        thinning: int = 10,
        min_side_points: Optional[int] = None,
        random_state: Optional[int] = None,
        fit_verbose: bool = False,
        use_optimizer: bool = True,
    ):
        self.bounds = np.asarray(bounds, dtype=float)
        self.oracle = oracle
        self.t0 = float(t0)
        self.max_depth = int(max_depth)
        self.eps = float(eps)
        self.n_samples = int(n_samples)

        self.ridge = float(ridge)
        self.w_norm_penalty = float(w_norm_penalty)
        self.t_min = float(t_min)

        self.fit_max_iters = int(fit_max_iters)
        self.fit_tol = float(fit_tol)
        self.fit_alpha0 = float(fit_alpha0)

        self.burn_in = int(burn_in)
        self.thinning = int(thinning)
        self.fit_verbose = bool(fit_verbose)
        self.use_optimizer = bool(use_optimizer)
        self.rng = np.random.default_rng(random_state)
        self.oracle_queries = 0

        self.d = self.bounds.shape[0]
        self.min_side_points = max(self.d + 1, 5) if min_side_points is None else int(min_side_points)

        self.root_region = hypercube_to_region(self.bounds, depth=0, tag="root")
        self.root_diameter = None

        self.og_loss = None

    def _next_seed(self) -> int:
        return int(self.rng.integers(0, 2**31 - 1))

    def query_oracle(self, X: np.ndarray) -> np.ndarray:
        X = np.asarray(X, dtype=float)
        y = np.array([self.oracle(x) for x in X], dtype=float)
        self.oracle_queries += X.shape[0]
        return y

    def sample_region(self, region: PolytopeRegion, n_samples: int, x0: Optional[np.ndarray] = None) -> np.ndarray:
        return hit_and_run_sample(
            region.A,
            region.b,
            n_samples=n_samples,
            burn_in=self.burn_in,
            thinning=self.thinning,
            x0=x0,
            seed=self._next_seed(),
        )

    def fit_bilinear(self, X: np.ndarray, y: np.ndarray, t_cell: float, w_reg: Optional[float] = None, use_optimizer: bool = True) -> FitResult:
        
        if w_reg is None:
            w_reg = self.w_norm_penalty

        model = biLinear_fit(
            oracle=None,
            vertices=None,
            t=t_cell,
            n_samples=X.shape[0],
            ridge=self.ridge,
            w_norm_penalty= w_reg,
            random_state=self._next_seed(),
            X=X,
            y=y,
        )
        return model.fit(
            max_iters=self.fit_max_iters,
            tol=self.fit_tol,
            alpha0=self.fit_alpha0,
            verbose=self.fit_verbose,
            regenerate_data=False,
            use_optimizer=use_optimizer,
        )

    def make_leaf(
        self,
        X: np.ndarray,
        y: np.ndarray,
        region: PolytopeRegion,
        depth: int,
        parent,
        node_id: str,
    ) -> AffineLeaf:
        beta, y_hat = fit_affine_ridge(X, y, ridge=self.ridge)
        leaf = AffineLeaf(
            beta=beta,
            parent=parent,
            region=region,
            depth=depth,
            node_id=node_id,
        )
        leaf.rel_error = relative_l2_error(y, y_hat)
        leaf.n_points = int(X.shape[0])
        return leaf

    def build(self) -> SurrogateBuildResult:
        X_root = self.sample_region(self.root_region, self.n_samples, x0=None)
        y_root = self.query_oracle(X_root)

        self.root_diameter = max(sampled_diameter(X_root), 1e-12)

        root = self._build_node(
            region=self.root_region,
            X=X_root,
            y=y_root,
            depth=0,
            t_cell=self.t0,
            w_reg=self.w_norm_penalty,
            parent=None,
            node_id="root",
        )

        tree = PiecewiseLinearTree(root=root)
        tree.oracle_queries = self.oracle_queries           
        tree.root_diameter = self.root_diameter
        tree.bounds = self.bounds.copy()

        return SurrogateBuildResult(
            tree=tree,
            oracle_queries=self.oracle_queries,
            root_diameter=self.root_diameter,
        )

    def _build_node(
        self,
        region: PolytopeRegion,
        X: np.ndarray,
        y: np.ndarray,
        depth: int,
        t_cell: float,
        w_reg: float,
        parent,
        node_id: str,
    ):
        # If we've reached the maximum allowed depth, terminate with a leaf.
        if depth >= self.max_depth:
            return self.make_leaf(X, y, region, depth, parent, node_id)

        # Fit a bilinear split on the current cell samples.
        fit_result = self.fit_bilinear(X, y, t_cell=t_cell, w_reg=w_reg, use_optimizer=self.use_optimizer)
        side = (X @ fit_result.w - fit_result.z) >= 0.0
        n_right = int(np.sum(side))
        n_left = int(X.shape[0] - n_right)

        # For root record initial loss for w_reg scaling
        if depth == 0:
            self.og_loss = fit_result.loss_history[0]

        # Guard against degenerate splits.
        if n_left < self.min_side_points or n_right < self.min_side_points:
            print("Degenerate Split!")
            return self.make_leaf(X, y, region, depth, parent, node_id)

        node = SplitNode(
            w=fit_result.w.copy(),
            z=float(fit_result.z),
            left=None,
            right=None,
            parent=parent,
            region=region,
            depth=depth,
            node_id=node_id,
            fit_result=fit_result,
        )
        node.t_cell = float(t_cell)
        node.n_points = int(X.shape[0])

        left_region, right_region = split_region(region, fit_result.w, fit_result.z, depth=depth + 1)
        left_region.tag = f"{node_id}/L"
        right_region.tag = f"{node_id}/R"

        X_left_parent = X[~side]
        y_left_parent = y[~side]
        X_right_parent = X[side]
        y_right_parent = y[side]

        node.left = self._build_child(
            child_region=left_region,
            x0=X_left_parent[0],
            fallback_X=X_left_parent,
            fallback_y=y_left_parent,
            depth=depth + 1,
            parent=node,
            node_id=f"{node_id}/L",
        )

        node.right = self._build_child(
            child_region=right_region,
            x0=X_right_parent[0],
            fallback_X=X_right_parent,
            fallback_y=y_right_parent,
            depth=depth + 1,
            parent=node,
            node_id=f"{node_id}/R",
        )

        return node

    def _build_child(
        self,
        child_region: PolytopeRegion,
        x0: np.ndarray,
        fallback_X: np.ndarray,
        fallback_y: np.ndarray,
        depth: int,
        parent,
        node_id: str,
    ):
        # Sample the child cell using a feasible point inherited from the parent.
        try:
            X_child = self.sample_region(child_region, self.n_samples, x0=x0)
            y_child = self.query_oracle(X_child)
        except Exception:
            print("H&R failed using fallback from parent")
            # If child sampling fails, fall back to a leaf built from parent-side data.
            return self.make_leaf(fallback_X, fallback_y, child_region, depth, parent, node_id)

        # First check whether a single affine model is already good enough.
        beta_child, y_hat_child = fit_affine_ridge(X_child, y_child, ridge=self.ridge)
        rel_err = relative_l2_error(y_child, y_hat_child)

        if rel_err <= self.eps or depth >= self.max_depth:
            leaf = AffineLeaf(
                beta=beta_child,
                parent=parent,
                region=child_region,
                depth=depth,
                node_id=node_id,
            )
            leaf.rel_error = rel_err
            leaf.n_points = int(X_child.shape[0])
            return leaf

        # Otherwise recurse with cell-adaptive softness.
        D_child = sampled_diameter(X_child)
        t_child = max(self.t_min, self.t0 * D_child / self.root_diameter)
        w_child = max(1e-5, self.w_norm_penalty * (parent.fit_result.loss_history[0] / self.og_loss))

        return self._build_node(
            region=child_region,
            X=X_child,
            y=y_child,
            depth=depth,
            t_cell=t_child,
            w_reg=w_child,
            parent=parent,
            node_id=node_id,
        )

# %% [markdown]
# ## Tests

# %%
from scipy.integrate import solve_ivp


def lorenz96_rhs(_, z, F):
    """
    d-dimensional Lorenz-96 with periodic indexing:
        dz_i/dt = (z_{i+1} - z_{i-2}) z_{i-1} - z_i + F
    valid for d >= 3
    """
    z = np.asarray(z, dtype=float)
    d = z.size

    if d < 3:
        raise ValueError("Lorenz-96 requires d >= 3.")

    dz = np.zeros_like(z)
    for i in range(d):
        dz[i] = (z[(i + 1) % d] - z[(i - 2) % d]) * z[(i - 1) % d] - z[i] + F
    return dz


def make_lorenz96_oracle(t, F, rtol=1e-10, atol=1e-12, method="DOP853"):
    """
    Returns an oracle f: R^d -> R
    Input: z0 in R^d, d >= 3
    Output: first component of z(t), where z solves Lorenz-96

    Parameters
    ----------
    t : float
        Final time
    F : float
        Forcing parameter in Lorenz-96
    rtol, atol : float
        ODE solver tolerances
    method : str
        High-accuracy solve_ivp method, e.g. "DOP853" or "RK45"
    """
    t = float(t)
    F = float(F)

    def oracle(z0):
        z0 = np.asarray(z0, dtype=float).reshape(-1)

        if z0.size < 3:
            raise ValueError("Lorenz-96 oracle requires input dimension d >= 3.")

        sol = solve_ivp(
            fun=lambda tau, z: lorenz96_rhs(tau, z, F),
            t_span=(0.0, t),
            y0=z0,
            method=method,
            rtol=rtol,
            atol=atol,
        )

        if not sol.success:
            raise RuntimeError(f"ODE solve failed: {sol.message}")

        return float(sol.y[0, -1])

    return oracle

# %%
# 2D square: [-1, 1] x [-1, 1]
bounds = np.array([
    [-2.0, 3.0],
    [-2.0, 3.0],
])

def f1_HRT(X):
    X = np.asarray(X, dtype=float)
    x1 = X[0]
    x2 = X[1]

    return (
        0.5 * x1**3
        - 2.0 * x1 * x2**2
        + 3.0 * np.sin(4.0 * x1) * np.cos(2.0 * x2)
        + 0.1 * np.exp(-(x1**2 + x2**2))
    )



# True partition line: w_true . x - z_true = 0
true_w = np.array([1, -1])
true_z = 0.0

# Two affine pieces
beta_left = np.array([1.5, -0.8, 0.2])   # y = 1.5 x1 - 0.8 x2 + 0.2
beta_right = np.array([-0.7, 1.2, -0.1]) # y = -0.7 x1 + 1.2 x2 - 0.1

def rosenbrock_oracle(x, a=1.0, b=100.0):
    x = np.asarray(x, dtype=float).reshape(-1)
    return np.sum((a - x[:-1])**2 + b * (x[1:] - x[:-1]**2)**2)


lorenz_oracle = make_lorenz96_oracle(t=0.1, F=1.0)

z0 = np.array([2.5, 0.5, -0.2, 0.1, 0.0])
val = lorenz_oracle(z0)
print(f"Lorenz-96 value: {val}")


def oracle(x):
    x = np.asarray(x, dtype=float)
    # x_aug = np.append(x, 1.0)
    # if true_w @ x - true_z >= 0.0:
    #     return float(x_aug @ beta_right)
    # return float(x_aug @ beta_left)
    return rosenbrock_oracle(x)
# Out:
# Lorenz-96 value: 2.3593353111303252

# %%
builder = RecursiveSurrogateBuilder(
    bounds=bounds,
    oracle=oracle,
    t0=0.1,
    t_min=1e-5,
    max_depth=9,
    eps=1e-4,
    n_samples=80,
    ridge=1e-8,
    w_norm_penalty=1e3,
    fit_max_iters=200,
    fit_tol=1e-5,
    fit_alpha0=1e-3,
    burn_in=0,
    thinning=10,
    random_state=0,
    min_side_points=1,
    fit_verbose= False,
    use_optimizer=True
)


result = builder.build()
tree = result.tree

# %%
print("oracle queries:", builder.oracle_queries)
print("median root diameter:", builder.root_diameter)
print("tree max depth:", tree.max_depth())
print("Num Leaves:", tree.num_leaves())
print("T range: ", tree.t_range())
# Out:
# oracle queries: 57040
# median root diameter: 2.5010634435722645
# tree max depth: 10
# Num Leaves: 357
# T range:  (0.0023329698424771513, 0.1)

# %%
metrics = evaluate_error(
    f_true=oracle,
    f_pred=tree.predict_one,
    bounds=bounds,
    n_samples=50000,
    random_state=1,
)

print("relative L2:", metrics["relative_l2_error"])

print("median pointwise rel err:", metrics["median_pointwise_relative_error"])
print("max pointwise rel err:", metrics["max_pointwise_relative_error"])
print("sqrt(E[f^2]) norm:", metrics["L2 norm"])
# Out:
# Data shape: (50000, 2)
# relative L2: 0.0040761769960113185
# median pointwise rel err: 0.0050434571390557854
# max pointwise rel err: 359.6940086516973
# sqrt(E[f^2]) norm: 2112.191616863148

# %%
print(norm(tree.root.w), norm(tree.root.left.w), norm(tree.root.right.w))
# Out:
# 2.103542587667206 1.4384866841989095 1.9073169541943096

# %%
import numpy as np
import matplotlib.pyplot as plt


def plot_log_contours_2d(predict_fn, bounds, n_grid=200, levels=30, title="Log-Contour Plot"):
    bounds = np.asarray(bounds, dtype=float)
    if bounds.shape != (2, 2):
        raise ValueError("bounds must have shape (2, 2) for a 2D plot.")

    x1_min, x1_max = bounds[0]
    x2_min, x2_max = bounds[1]

    x1 = np.linspace(x1_min, x1_max, n_grid)
    x2 = np.linspace(x2_min, x2_max, n_grid)
    X1, X2 = np.meshgrid(x1, x2)

    Z = np.zeros_like(X1, dtype=float)
    for i in range(n_grid):
        for j in range(n_grid):
            x = np.array([X1[i, j], X2[i, j]])
            Z[i, j] = predict_fn(x)

    # safe log transform
    Z_log = np.log10(np.maximum(np.abs(Z), 1e-12))

    plt.figure(figsize=(6, 5))
    contour = plt.contourf(X1, X2, Z_log, levels=levels, cmap="viridis")
    plt.colorbar(contour, label=r"$\log_{10}(|f(x)|)$")
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(title)
    plt.axis("equal")
    plt.show()

# %%
def collect_fit_info(tree):
    rows = []

    def _walk(node):
        if node is None or isinstance(node, AffineLeaf):
            return

        fr = node.fit_result
        rows.append({
            "node_id": node.node_id,
            "depth": node.depth,
            "t_cell": getattr(node, "t_cell", None),
            "converged": None if fr is None else fr.converged,
            "w": None if fr is None else fr.w,
            "n_iters": None if fr is None else fr.n_iters,
            "final_loss": None if fr is None or len(fr.loss_history) == 0 else fr.loss_history[-1],
            "final_grad_norm": None if fr is None or len(fr.grad_norm_history) == 0 else fr.grad_norm_history[-1],
            "loss_history": None if fr is None else fr.loss_history,
            "grad_norm_history": None if fr is None else fr.grad_norm_history,
            "w_norm_penalty": None if fr is None else fr.w_norm_penalty
        })

        _walk(node.left)
        _walk(node.right)

    _walk(tree.root)
    return rows

# %%
def print_split_fit_summary(tree):
    rows = collect_fit_info(tree)
    failed_rows = [r for r in rows if r["converged"] is False]
    succ_rows = [r for r in rows if r["converged"] is True]

    total = len(rows)
    not_converged = len(failed_rows)

    print(f"split nodes not converged: {not_converged}/{total}")

    for r in rows:
        t_cell = r["t_cell"]
        final_loss = r["final_loss"]
        final_grad = r["final_grad_norm"]
        w_norm = None if r["w"] is None else norm(r["w"])
        w_norm_penalty = r["w_norm_penalty"]

        t_str = "None" if t_cell is None else f"{t_cell:.4e}"
        w_str = "None" if w_norm is None else f"{w_norm:.4e}"
        loss_str = "None" if final_loss is None else f"{final_loss:.4e}"
        grad_str = "None" if final_grad is None else f"{final_grad:.4e}"
        w_norm_penalty_str = "None" if w_norm_penalty is None else f"{w_norm_penalty:.4e}"

        print(
            f"id={r['node_id']}, depth={r['depth']}, t={t_str}, ||w||={w_str}, "
            f"converged={r['converged']}, n_iters={r['n_iters']}, "
            f"final_loss={loss_str}, final_grad_norm={grad_str}, w_norm_penalty={w_norm_penalty_str}"
        )

# %%
from collections import defaultdict

def relative_loss_decrease_summary_by_depth(tree, only_converged=False):
    depth_to_values = defaultdict(list)

    def _walk(node):
        if node is None or isinstance(node, AffineLeaf):
            return

        fr = node.fit_result
        if fr is not None and len(fr.loss_history) >= 2:
            if (not only_converged) or fr.converged:
                loss0 = fr.loss_history[0]
                lossf = fr.loss_history[-1]

                if loss0 != 0:
                    rel_dec = (loss0 - lossf) / loss0
                    depth_to_values[node.depth].append(rel_dec)

        _walk(node.left)
        _walk(node.right)

    _walk(tree.root)

    summary = {}
    for depth, vals in sorted(depth_to_values.items()):
        vals = np.asarray(vals, dtype=float)
        summary[depth] = {
            "n_nodes": len(vals),
            "avg_rel_decrease": float(np.mean(vals)),
            "median_rel_decrease": float(np.median(vals)),
            "min_rel_decrease": float(np.min(vals)),
            "max_rel_decrease": float(np.max(vals)),
        }

    return summary

# %%
from collections import defaultdict

def plot_relative_loss_improvement_histograms_by_depth(
    tree,
    only_converged=False,
    bins=30,
    depth_range=None,
    figsize_per_row=(12, 3.5),
):
    depth_to_values = defaultdict(list)

    def _walk(node):
        if node is None or isinstance(node, AffineLeaf):
            return

        fr = node.fit_result
        if fr is not None and len(fr.loss_history) >= 2:
            if (not only_converged) or fr.converged:
                loss0 = fr.loss_history[0]
                lossf = fr.loss_history[-1]

                if loss0 != 0:
                    rel_improvement = (loss0 - lossf) / loss0
                    depth_to_values[node.depth].append(rel_improvement)

        _walk(node.left)
        _walk(node.right)

    _walk(tree.root)

    if not depth_to_values:
        print("No valid split-node loss histories found.")
        return

    depths = sorted(depth_to_values.keys())
    if depth_range is not None:
        dmin, dmax = depth_range
        depths = [d for d in depths if dmin <= d <= dmax]

    if not depths:
        print("No depths in the requested range.")
        return

    n_depths = len(depths)
    ncols = 3
    nrows = int(np.ceil(n_depths / ncols))

    fig, axes = plt.subplots(
        nrows,
        ncols,
        figsize=(figsize_per_row[0], figsize_per_row[1] * nrows),
        squeeze=False,
    )

    axes_flat = axes.ravel()

    for ax, depth in zip(axes_flat, depths):
        vals = np.asarray(depth_to_values[depth], dtype=float)

        ax.hist(vals, bins=bins, edgecolor="black", alpha=0.8)
        ax.axvline(np.mean(vals), color="red", linestyle="--", linewidth=2, label=f"mean={np.mean(vals):.3f}")
        ax.axvline(np.median(vals), color="green", linestyle=":", linewidth=2, label=f"median={np.median(vals):.3f}")

        ax.set_title(f"Depth {depth} (n={len(vals)})")
        ax.set_xlabel(r"$(L_0 - L_f)/L_0$")
        ax.set_ylabel("Count")
        ax.legend()

    for ax in axes_flat[n_depths:]:
        ax.axis("off")

    fig.suptitle("Relative Loss Improvement by Depth", fontsize=14)
    fig.tight_layout(rect=[0, 0, 1, 0.97])
    plt.show()

# %%
print_split_fit_summary(tree)

# summary = relative_loss_decrease_summary_by_depth(tree)
# for depth, stats in summary.items():
#     print(
#         f"depth={depth}, n={stats['n_nodes']}, "
#         f"avg={stats['avg_rel_decrease']:.6f}, "
#         f"median={stats['median_rel_decrease']:.6f}, "
#         f"min={stats['min_rel_decrease']:.6f}, "
#         f"max={stats['max_rel_decrease']:.6f}"
#     )


# plot_relative_loss_improvement_histograms_by_depth(tree)
# Out:
# split nodes not converged: 135/254
# id=root, depth=0, t=1.0000e-01, ||w||=2.1035e+00, converged=True, n_iters=119, final_loss=2.5606e+06, final_grad_norm=2.6581e+04, w_norm_penalty=1.0000e+04
# id=root/L, depth=1, t=1.0957e-01, ||w||=1.4385e+00, converged=True, n_iters=42, final_loss=8.2752e+05, final_grad_norm=4.3294e+03, w_norm_penalty=1.0000e+04
# id=root/L/L, depth=2, t=4.2390e-02, ||w||=2.0394e+00, converged=False, n_iters=200, final_loss=8.4908e+04, final_grad_norm=7.7703e+03, w_norm_penalty=1.0064e+03
# id=root/L/L/L, depth=3, t=2.8855e-02, ||w||=1.1824e+00, converged=False, n_iters=200, final_loss=7.1076e+03, final_grad_norm=1.6623e+03, w_norm_penalty=4.8122e+02
# id=root/L/L/L/L, depth=4, t=3.6669e-02, ||w||=1.4827e+00, converged=True, n_iters=44, final_loss=1.8298e+03, final_grad_norm=4.0902e+01, w_norm_penalty=2.0292e+01
# id=root/L/L/L/L/L, depth=5, t=1.7840e-02, ||w||=1.2739e+00, converged=False, n_iters=200, final_loss=4.7323e+02, final_grad_norm=1.8042e+02, w_norm_penalty=1.4183e+00
# id=root/L/L/L/L/L/L, depth=6, t=1.2387e-02, ||w||=1.1615e+00, converged=True, n_iters=172, final_loss=1.6011e+02, final_grad_norm=9.2899e+00, w_norm_penalty=4.7563e-01
# id=root/L/L/L/L/L/L/L, depth=7, t=9.4952e-03, ||w||=1.0367e+00, converged=False, n_iters=200, final_loss=3.5445e+01, final_grad_norm=1.5043e+01, w_norm_penalty=1.0788e-01
# id=root/L/L/L/L/L/L/R, depth=7, t=1.2190e-02, ||w||=1.0363e+00, converged=True, n_iters=86, final_loss=1.6852e+02, final_grad_norm=1.1304e+01, w_norm_penalty=1.0788e-01
# id=root/L/L/L/L/L/R, depth=6, t=9.6509e-03, ||w||=9.9756e-01, converged=True, n_iters=6, final_loss=8.2229e+01, final_grad_norm=1.2150e+00, w_norm_penalty=4.7563e-01
# id=root/L/L/L/L/L/R/L, depth=7, t=4.8758e-03, ||w||=9.9941e-01, converged=True, n_iters=18, final_loss=4.9557e+00, final_grad_norm=4.4905e-01, w_norm_penalty=4.8798e-02
# id=root/L/L/L/L/L/R/R, depth=7, t=5.0595e-03, ||w||=9.8370e-01, converged=False, n_iters=200, final_loss=2.4323e+01, final_grad_norm=2.5148e+01, w_norm_penalty=4.8798e-02
# id=root/L/L/L/L/R, depth=5, t=1.4270e-02, ||w||=8.8266e-01, converged=False, n_iters=200, final_loss=9.9437e+02, final_grad_norm=4.7530e+02, w_norm_penalty=1.4183e+00
# id=root/L/L/L/L/R/L, depth=6, t=1.2472e-02, ||w||=1.1518e+00, converged=False, n_iters=200, final_loss=3.1640e+02, final_grad_norm=8.8474e+01, w_norm_penalty=1.2088e+00
# id=root/L/L/L/L/R/L/L, depth=7, t=7.5984e-03, ||w||=1.0075e+00, converged=True, n_iters=6, final_loss=3.0928e+01, final_grad_norm=1.8747e+00, w_norm_penalty=4.8783e-01
# id=root/L/L/L/L/R/L/R, depth=7, t=1.3085e-02, ||w||=1.3131e+00, converged=False, n_iters=200, final_loss=1.1177e+02, final_grad_norm=6.7242e+00, w_norm_penalty=4.8783e-01
# id=root/L/L/L/L/R/R, depth=6, t=1.0640e-02, ||w||=9.2485e-01, converged=True, n_iters=174, final_loss=1.2098e+02, final_grad_norm=1.2262e+01, w_norm_penalty=1.2088e+00
# id=root/L/L/L/L/R/R/L, depth=7, t=4.8291e-03, ||w||=9.9763e-01, converged=True, n_iters=5, final_loss=2.9932e+02, final_grad_norm=2.0675e+01, w_norm_penalty=8.0847e-02
# id=root/L/L/L/L/R/R/R, depth=7, t=6.3608e-03, ||w||=9.8953e-01, converged=True, n_iters=6, final_loss=3.0024e+01, final_grad_norm=2.4335e-01, w_norm_penalty=8.0847e-02
# id=root/L/L/L/R, depth=4, t=2.3132e-02, ||w||=9.9273e-01, converged=True, n_iters=55, final_loss=8.9053e+03, final_grad_norm=4.2619e+02, w_norm_penalty=2.0292e+01
# id=root/L/L/L/R/L, depth=5, t=1.0439e-02, ||w||=9.1943e-01, converged=False, n_iters=200, final_loss=1.8335e+03, final_grad_norm=6.9845e+03, w_norm_penalty=5.2484e+00
# id=root/L/L/L/R/L/L, depth=6, t=9.5673e-03, ||w||=1.0095e+00, converged=False, n_iters=200, final_loss=1.0900e+03, final_grad_norm=7.2182e+02, w_norm_penalty=3.8869e+00
# id=root/L/L/L/R/L/L/L, depth=7, t=7.7376e-03, ||w||=8.7398e-01, converged=False, n_iters=200, final_loss=3.0182e+02, final_grad_norm=8.1218e+01, w_norm_penalty=7.5145e-01
# id=root/L/L/L/R/L/L/R, depth=7, t=6.2813e-03, ||w||=1.0981e+00, converged=False, n_iters=200, final_loss=1.1910e+02, final_grad_norm=3.0254e+02, w_norm_penalty=7.5145e-01
# id=root/L/L/L/R/L/R, depth=6, t=7.2821e-03, ||w||=8.6356e-01, converged=False, n_iters=200, final_loss=3.4615e+02, final_grad_norm=1.3593e+02, w_norm_penalty=3.8869e+00
# id=root/L/L/L/R/L/R/L, depth=7, t=5.6133e-03, ||w||=9.7886e-01, converged=True, n_iters=54, final_loss=7.3625e+01, final_grad_norm=3.2137e+01, w_norm_penalty=3.9453e-01
# id=root/L/L/L/R/L/R/R, depth=7, t=6.1329e-03, ||w||=1.0108e+00, converged=True, n_iters=16, final_loss=1.3022e+02, final_grad_norm=4.6638e+01, w_norm_penalty=3.9453e-01
# id=root/L/L/L/R/R, depth=5, t=1.9758e-02, ||w||=1.0029e+00, converged=True, n_iters=4, final_loss=4.2880e+03, final_grad_norm=8.9947e+01, w_norm_penalty=5.2484e+00
# id=root/L/L/L/R/R/L, depth=6, t=1.0260e-02, ||w||=8.8438e-01, converged=False, n_iters=200, final_loss=4.0357e+02, final_grad_norm=4.9299e+02, w_norm_penalty=2.4641e+00
# id=root/L/L/L/R/R/L/L, depth=7, t=1.1832e-02, ||w||=1.0055e+00, converged=True, n_iters=43, final_loss=2.1952e+02, final_grad_norm=1.9427e+01, w_norm_penalty=5.9556e-01
# id=root/L/L/L/R/R/L/R, depth=7, t=8.4430e-03, ||w||=9.9109e-01, converged=True, n_iters=5, final_loss=1.7580e+02, final_grad_norm=1.0464e+01, w_norm_penalty=5.9556e-01
# id=root/L/L/L/R/R/R, depth=6, t=1.4309e-02, ||w||=1.0386e+00, converged=False, n_iters=200, final_loss=4.1926e+02, final_grad_norm=1.2449e+02, w_norm_penalty=2.4641e+00
# id=root/L/L/L/R/R/R/L, depth=7, t=1.5072e-02, ||w||=9.8481e-01, converged=True, n_iters=4, final_loss=1.3017e+02, final_grad_norm=3.1650e+00, w_norm_penalty=3.1921e-01
# id=root/L/L/L/R/R/R/R, depth=7, t=8.1048e-03, ||w||=9.8412e-01, converged=True, n_iters=25, final_loss=1.5486e+02, final_grad_norm=2.2202e+01, w_norm_penalty=3.1921e-01
# id=root/L/L/R, depth=3, t=3.9786e-02, ||w||=1.4862e+00, converged=False, n_iters=200, final_loss=1.1841e+04, final_grad_norm=9.3430e+02, w_norm_penalty=4.8122e+02
# id=root/L/L/R/L, depth=4, t=2.2181e-02, ||w||=1.1206e+00, converged=False, n_iters=200, final_loss=5.4755e+03, final_grad_norm=1.3318e+02, w_norm_penalty=1.1893e+01
# id=root/L/L/R/L/L, depth=5, t=2.2021e-02, ||w||=1.4005e+00, converged=False, n_iters=200, final_loss=7.7659e+02, final_grad_norm=1.2490e+02, w_norm_penalty=3.1842e+00
# id=root/L/L/R/L/L/L, depth=6, t=1.5467e-02, ||w||=1.0118e+00, converged=False, n_iters=200, final_loss=8.1369e+02, final_grad_norm=2.1647e+02, w_norm_penalty=9.1770e-01
# id=root/L/L/R/L/L/L/L, depth=7, t=9.1957e-03, ||w||=8.5010e-01, converged=False, n_iters=200, final_loss=7.6990e+01, final_grad_norm=9.5383e+01, w_norm_penalty=5.5364e-01
# id=root/L/L/R/L/L/L/R, depth=7, t=1.4422e-02, ||w||=1.3086e+00, converged=False, n_iters=200, final_loss=1.2228e+02, final_grad_norm=6.6893e+01, w_norm_penalty=5.5364e-01
# id=root/L/L/R/L/L/R, depth=6, t=1.2967e-02, ||w||=1.2678e+00, converged=False, n_iters=200, final_loss=1.8030e+02, final_grad_norm=7.3538e+01, w_norm_penalty=9.1770e-01
# id=root/L/L/R/L/L/R/L, depth=7, t=8.8433e-03, ||w||=9.6725e-01, converged=False, n_iters=200, final_loss=8.1982e+01, final_grad_norm=2.0087e+01, w_norm_penalty=2.0706e-01
# id=root/L/L/R/L/L/R/R, depth=7, t=7.7383e-03, ||w||=1.0310e+00, converged=False, n_iters=200, final_loss=1.2003e+02, final_grad_norm=2.0407e+01, w_norm_penalty=2.0706e-01
# id=root/L/L/R/L/R, depth=5, t=1.3266e-02, ||w||=1.3426e+00, converged=True, n_iters=154, final_loss=3.5991e+02, final_grad_norm=4.6557e+01, w_norm_penalty=3.1842e+00
# id=root/L/L/R/L/R/L, depth=6, t=9.8412e-03, ||w||=9.8889e-01, converged=True, n_iters=49, final_loss=4.8956e+02, final_grad_norm=5.0262e+01, w_norm_penalty=2.2256e+00
# id=root/L/L/R/L/R/L/L, depth=7, t=6.7941e-03, ||w||=1.1817e+00, converged=False, n_iters=200, final_loss=5.5841e+01, final_grad_norm=8.5656e+01, w_norm_penalty=2.8930e-01
# id=root/L/L/R/L/R/L/R, depth=7, t=7.3310e-03, ||w||=9.9713e-01, converged=True, n_iters=4, final_loss=9.2225e+01, final_grad_norm=2.0601e+00, w_norm_penalty=2.8930e-01
# id=root/L/L/R/L/R/R, depth=6, t=7.7656e-03, ||w||=1.2316e+00, converged=False, n_iters=200, final_loss=1.7328e+02, final_grad_norm=6.3473e+01, w_norm_penalty=2.2256e+00
# id=root/L/L/R/L/R/R/L, depth=7, t=6.3365e-03, ||w||=1.1021e+00, converged=False, n_iters=200, final_loss=8.8311e+01, final_grad_norm=1.1455e+02, w_norm_penalty=1.8433e-01
# id=root/L/L/R/L/R/R/R, depth=7, t=4.3683e-03, ||w||=1.0669e+00, converged=False, n_iters=200, final_loss=6.6873e+01, final_grad_norm=1.2395e+02, w_norm_penalty=1.8433e-01
# id=root/L/L/R/R, depth=4, t=3.1617e-02, ||w||=1.2122e+00, converged=False, n_iters=200, final_loss=4.0604e+03, final_grad_norm=3.3112e+02, w_norm_penalty=1.1893e+01
# id=root/L/L/R/R/L, depth=5, t=3.2088e-02, ||w||=1.9007e+00, converged=False, n_iters=200, final_loss=1.1590e+03, final_grad_norm=8.8637e+01, w_norm_penalty=4.2106e+00
# id=root/L/L/R/R/L/L, depth=6, t=1.8178e-02, ||w||=1.3696e+00, converged=False, n_iters=200, final_loss=1.2678e+03, final_grad_norm=5.0620e+01, w_norm_penalty=2.3653e+00
# id=root/L/L/R/R/L/L/L, depth=7, t=1.3784e-02, ||w||=1.3046e+00, converged=False, n_iters=200, final_loss=4.8583e+02, final_grad_norm=2.6711e+01, w_norm_penalty=9.9374e-01
# id=root/L/L/R/R/L/L/R, depth=7, t=7.8486e-03, ||w||=1.0440e+00, converged=False, n_iters=200, final_loss=1.0705e+03, final_grad_norm=2.2176e+03, w_norm_penalty=9.9374e-01
# id=root/L/L/R/R/L/R, depth=6, t=1.3913e-02, ||w||=1.4558e+00, converged=False, n_iters=200, final_loss=3.9590e+02, final_grad_norm=2.6645e+02, w_norm_penalty=2.3653e+00
# id=root/L/L/R/R/L/R/L, depth=7, t=1.4391e-02, ||w||=9.8041e-01, converged=True, n_iters=6, final_loss=1.9309e+02, final_grad_norm=2.8574e+00, w_norm_penalty=9.5831e-01
# id=root/L/L/R/R/L/R/R, depth=7, t=1.0765e-02, ||w||=1.0539e+00, converged=False, n_iters=200, final_loss=1.3485e+02, final_grad_norm=2.9858e+01, w_norm_penalty=9.5831e-01
# id=root/L/L/R/R/R, depth=5, t=1.8070e-02, ||w||=1.5734e+00, converged=False, n_iters=200, final_loss=1.1608e+03, final_grad_norm=4.0018e+01, w_norm_penalty=4.2106e+00
# id=root/L/L/R/R/R/L, depth=6, t=9.3282e-03, ||w||=1.0847e+00, converged=False, n_iters=200, final_loss=2.4174e+02, final_grad_norm=7.6869e+01, w_norm_penalty=7.5392e-01
# id=root/L/L/R/R/R/L/L, depth=7, t=3.4505e-03, ||w||=9.9018e-01, converged=False, n_iters=200, final_loss=3.8713e+01, final_grad_norm=3.0450e+01, w_norm_penalty=2.0879e-01
# id=root/L/L/R/R/R/L/R, depth=7, t=9.9216e-03, ||w||=1.0542e+00, converged=True, n_iters=21, final_loss=1.0758e+02, final_grad_norm=8.0346e+00, w_norm_penalty=2.0879e-01
# id=root/L/L/R/R/R/R, depth=6, t=1.1519e-02, ||w||=1.0006e+00, converged=False, n_iters=200, final_loss=1.4199e+03, final_grad_norm=5.3265e+02, w_norm_penalty=7.5392e-01
# id=root/L/L/R/R/R/R/L, depth=7, t=4.2475e-03, ||w||=1.0214e+00, converged=False, n_iters=200, final_loss=3.9548e+01, final_grad_norm=5.1422e+01, w_norm_penalty=1.1356e+00
# id=root/L/L/R/R/R/R/R, depth=7, t=1.0534e-02, ||w||=9.1969e-01, converged=False, n_iters=200, final_loss=2.4806e+02, final_grad_norm=4.6531e+02, w_norm_penalty=1.1356e+00
# id=root/L/R, depth=2, t=9.5940e-02, ||w||=1.7945e+00, converged=True, n_iters=71, final_loss=3.3988e+05, final_grad_norm=2.1779e+03, w_norm_penalty=1.0064e+03
# id=root/L/R/L, depth=3, t=7.0998e-02, ||w||=1.9134e+00, converged=True, n_iters=32, final_loss=1.5895e+05, final_grad_norm=6.0911e+02, w_norm_penalty=2.0880e+02
# id=root/L/R/L/L, depth=4, t=3.5085e-02, ||w||=1.4168e+00, converged=False, n_iters=200, final_loss=1.4630e+04, final_grad_norm=3.9021e+03, w_norm_penalty=1.3284e+02
# id=root/L/R/L/L/L, depth=5, t=2.4593e-02, ||w||=1.7851e+00, converged=False, n_iters=200, final_loss=2.2981e+03, final_grad_norm=2.0709e+02, w_norm_penalty=1.6151e+01
# id=root/L/R/L/L/L/L, depth=6, t=1.4918e-02, ||w||=1.1803e+00, converged=True, n_iters=172, final_loss=6.3757e+02, final_grad_norm=5.5044e+01, w_norm_penalty=5.5670e+00
# id=root/L/R/L/L/L/L/L, depth=7, t=1.1597e-02, ||w||=1.1877e+00, converged=True, n_iters=157, final_loss=1.2916e+02, final_grad_norm=9.2809e+00, w_norm_penalty=4.1854e-01
# id=root/L/R/L/L/L/L/R, depth=7, t=9.3004e-03, ||w||=9.4094e-01, converged=False, n_iters=200, final_loss=1.2371e+02, final_grad_norm=7.2586e+00, w_norm_penalty=4.1854e-01
# id=root/L/R/L/L/L/R, depth=6, t=2.1949e-02, ||w||=1.3742e+00, converged=True, n_iters=170, final_loss=2.7246e+03, final_grad_norm=1.1857e+02, w_norm_penalty=5.5670e+00
# id=root/L/R/L/L/L/R/L, depth=7, t=1.4283e-02, ||w||=8.9117e-01, converged=True, n_iters=101, final_loss=1.9504e+03, final_grad_norm=1.1107e+02, w_norm_penalty=1.7959e+00
# id=root/L/R/L/L/L/R/R, depth=7, t=1.2465e-02, ||w||=1.3400e+00, converged=False, n_iters=200, final_loss=2.2945e+02, final_grad_norm=2.7858e+01, w_norm_penalty=1.7959e+00
# id=root/L/R/L/L/R, depth=5, t=2.8877e-02, ||w||=1.4328e+00, converged=True, n_iters=13, final_loss=7.6280e+03, final_grad_norm=5.5054e+01, w_norm_penalty=1.6151e+01
# id=root/L/R/L/L/R/L, depth=6, t=1.7549e-02, ||w||=8.2139e-01, converged=False, n_iters=200, final_loss=1.4873e+03, final_grad_norm=5.2158e+02, w_norm_penalty=4.7250e+00
# id=root/L/R/L/L/R/L/L, depth=7, t=1.3361e-02, ||w||=1.4173e+00, converged=False, n_iters=200, final_loss=9.8455e+01, final_grad_norm=9.2237e+00, w_norm_penalty=3.2112e+00
# id=root/L/R/L/L/R/L/R, depth=7, t=1.8305e-02, ||w||=9.6042e-01, converged=True, n_iters=8, final_loss=5.2214e+02, final_grad_norm=4.7599e+00, w_norm_penalty=3.2112e+00
# id=root/L/R/L/L/R/R, depth=6, t=2.0356e-02, ||w||=9.2103e-01, converged=False, n_iters=200, final_loss=6.4404e+03, final_grad_norm=1.2520e+03, w_norm_penalty=4.7250e+00
# id=root/L/R/L/L/R/R/L, depth=7, t=1.3005e-02, ||w||=1.1991e+00, converged=False, n_iters=200, final_loss=5.0654e+02, final_grad_norm=2.9381e+02, w_norm_penalty=6.3274e+00
# id=root/L/R/L/L/R/R/R, depth=7, t=1.2872e-02, ||w||=1.0341e+00, converged=False, n_iters=200, final_loss=3.6965e+02, final_grad_norm=3.0501e+02, w_norm_penalty=6.3274e+00
# id=root/L/R/L/R, depth=4, t=5.7161e-02, ||w||=1.9147e+00, converged=True, n_iters=81, final_loss=5.0783e+04, final_grad_norm=6.2609e+02, w_norm_penalty=1.3284e+02
# id=root/L/R/L/R/L, depth=5, t=4.1269e-02, ||w||=1.2691e+00, converged=False, n_iters=200, final_loss=1.0388e+04, final_grad_norm=5.2107e+03, w_norm_penalty=1.2568e+02
# id=root/L/R/L/R/L/L, depth=6, t=3.6244e-02, ||w||=1.1366e+00, converged=True, n_iters=7, final_loss=1.8781e+03, final_grad_norm=4.0375e+00, w_norm_penalty=1.2796e+01
# id=root/L/R/L/R/L/L/L, depth=7, t=2.6966e-02, ||w||=1.1054e+00, converged=False, n_iters=200, final_loss=1.5478e+03, final_grad_norm=1.6126e+02, w_norm_penalty=1.1366e+00
# id=root/L/R/L/R/L/L/R, depth=7, t=1.7206e-02, ||w||=1.0669e+00, converged=True, n_iters=57, final_loss=1.8999e+03, final_grad_norm=1.1944e+02, w_norm_penalty=1.1366e+00
# id=root/L/R/L/R/L/R, depth=6, t=3.8396e-02, ||w||=9.3321e-01, converged=True, n_iters=77, final_loss=1.4045e+04, final_grad_norm=4.0028e+02, w_norm_penalty=1.2796e+01
# id=root/L/R/L/R/L/R/L, depth=7, t=1.4048e-02, ||w||=9.2261e-01, converged=False, n_iters=200, final_loss=1.5668e+04, final_grad_norm=5.5436e+03, w_norm_penalty=8.2967e+00
# id=root/L/R/L/R/L/R/R, depth=7, t=2.0285e-02, ||w||=2.4893e+00, converged=False, n_iters=200, final_loss=2.1065e+03, final_grad_norm=6.2295e+02, w_norm_penalty=8.2967e+00
# id=root/L/R/L/R/R, depth=5, t=5.2239e-02, ||w||=1.4351e+00, converged=True, n_iters=57, final_loss=1.9821e+04, final_grad_norm=3.4634e+02, w_norm_penalty=1.2568e+02
# id=root/L/R/L/R/R/L, depth=6, t=3.5354e-02, ||w||=1.9695e+00, converged=True, n_iters=99, final_loss=6.1583e+03, final_grad_norm=2.0424e+02, w_norm_penalty=2.0635e+01
# id=root/L/R/L/R/R/L/L, depth=7, t=2.8926e-02, ||w||=1.3758e+00, converged=True, n_iters=139, final_loss=3.1891e+03, final_grad_norm=5.5205e+01, w_norm_penalty=2.9236e+01
# id=root/L/R/L/R/R/L/R, depth=7, t=2.7016e-02, ||w||=1.6192e+00, converged=True, n_iters=81, final_loss=7.4885e+02, final_grad_norm=4.6817e+01, w_norm_penalty=2.9236e+01
# id=root/L/R/L/R/R/R, depth=6, t=3.5486e-02, ||w||=1.3526e+00, converged=True, n_iters=15, final_loss=1.0396e+04, final_grad_norm=1.0181e+02, w_norm_penalty=2.0635e+01
# id=root/L/R/L/R/R/R/L, depth=7, t=1.9717e-02, ||w||=1.3919e+00, converged=True, n_iters=132, final_loss=4.4858e+02, final_grad_norm=2.4322e+01, w_norm_penalty=9.2442e+00
# id=root/L/R/L/R/R/R/R, depth=7, t=2.7580e-02, ||w||=1.6167e+00, converged=True, n_iters=48, final_loss=2.0173e+03, final_grad_norm=2.4604e+01, w_norm_penalty=9.2442e+00
# id=root/L/R/R, depth=3, t=6.2164e-02, ||w||=1.1205e+00, converged=False, n_iters=200, final_loss=3.1440e+05, final_grad_norm=2.2305e+04, w_norm_penalty=2.0880e+02
# id=root/L/R/R/L, depth=4, t=4.9958e-02, ||w||=1.5160e+00, converged=True, n_iters=23, final_loss=2.4520e+04, final_grad_norm=3.6645e+02, w_norm_penalty=2.3000e+02
# id=root/L/R/R/L/L, depth=5, t=3.9939e-02, ||w||=1.7574e+00, converged=True, n_iters=40, final_loss=1.7412e+04, final_grad_norm=1.9169e+02, w_norm_penalty=2.6702e+01
# id=root/L/R/R/L/L/L, depth=6, t=2.8170e-02, ||w||=1.3559e+00, converged=False, n_iters=200, final_loss=2.2163e+03, final_grad_norm=6.8225e+02, w_norm_penalty=5.9155e+01
# id=root/L/R/R/L/L/L/L, depth=7, t=2.5594e-02, ||w||=1.1017e+00, converged=True, n_iters=89, final_loss=2.3714e+03, final_grad_norm=3.2133e+01, w_norm_penalty=4.0940e+00
# id=root/L/R/R/L/L/L/R, depth=7, t=1.8500e-02, ||w||=1.3011e+00, converged=False, n_iters=200, final_loss=4.8355e+02, final_grad_norm=9.2114e+01, w_norm_penalty=4.0940e+00
# id=root/L/R/R/L/L/R, depth=6, t=2.7021e-02, ||w||=2.0021e+00, converged=False, n_iters=200, final_loss=5.6430e+03, final_grad_norm=5.9191e+02, w_norm_penalty=5.9155e+01
# id=root/L/R/R/L/L/R/L, depth=7, t=1.4794e-02, ||w||=9.6408e-01, converged=False, n_iters=200, final_loss=6.9797e+02, final_grad_norm=9.9213e+01, w_norm_penalty=2.6986e+01
# id=root/L/R/R/L/L/R/R, depth=7, t=2.0895e-02, ||w||=1.5168e+00, converged=False, n_iters=200, final_loss=2.8834e+03, final_grad_norm=1.8047e+02, w_norm_penalty=2.6986e+01
# id=root/L/R/R/L/R, depth=5, t=3.6994e-02, ||w||=2.2399e+00, converged=True, n_iters=111, final_loss=1.6898e+04, final_grad_norm=4.6188e+02, w_norm_penalty=2.6702e+01
# id=root/L/R/R/L/R/L, depth=6, t=2.2260e-02, ||w||=1.3768e+00, converged=False, n_iters=200, final_loss=7.0495e+02, final_grad_norm=4.4117e+01, w_norm_penalty=3.1626e+01
# id=root/L/R/R/L/R/L/L, depth=7, t=2.3265e-02, ||w||=1.7228e+00, converged=False, n_iters=200, final_loss=1.3772e+02, final_grad_norm=2.1236e+01, w_norm_penalty=7.7466e-01
# id=root/L/R/R/L/R/L/R, depth=7, t=1.8019e-02, ||w||=1.2992e+00, converged=True, n_iters=39, final_loss=9.7614e+02, final_grad_norm=3.7219e+01, w_norm_penalty=7.7466e-01
# id=root/L/R/R/L/R/R, depth=6, t=2.6327e-02, ||w||=1.2144e+00, converged=True, n_iters=18, final_loss=1.6555e+04, final_grad_norm=3.6531e+02, w_norm_penalty=3.1626e+01
# id=root/L/R/R/L/R/R/L, depth=7, t=1.8136e-02, ||w||=1.1561e+00, converged=False, n_iters=200, final_loss=2.8638e+03, final_grad_norm=9.1596e+02, w_norm_penalty=1.4455e+01
# id=root/L/R/R/L/R/R/R, depth=7, t=1.8602e-02, ||w||=1.1805e+00, converged=False, n_iters=200, final_loss=7.5424e+02, final_grad_norm=2.4940e+02, w_norm_penalty=1.4455e+01
# id=root/L/R/R/R, depth=4, t=4.2125e-02, ||w||=2.0098e+00, converged=True, n_iters=119, final_loss=2.2881e+05, final_grad_norm=2.9301e+03, w_norm_penalty=2.3000e+02
# id=root/L/R/R/R/L, depth=5, t=2.8644e-02, ||w||=2.0128e+00, converged=True, n_iters=59, final_loss=2.0727e+04, final_grad_norm=2.6560e+03, w_norm_penalty=1.7252e+02
# id=root/L/R/R/R/L/L, depth=6, t=1.6810e-02, ||w||=2.1965e+00, converged=False, n_iters=200, final_loss=1.7053e+03, final_grad_norm=1.3639e+03, w_norm_penalty=4.3324e+01
# id=root/L/R/R/R/L/L/L, depth=7, t=1.2289e-02, ||w||=1.0913e+00, converged=False, n_iters=200, final_loss=3.1112e+02, final_grad_norm=5.2701e+02, w_norm_penalty=8.9397e+00
# id=root/L/R/R/R/L/L/R, depth=7, t=9.5566e-03, ||w||=1.1459e+00, converged=False, n_iters=200, final_loss=1.3011e+02, final_grad_norm=1.1171e+02, w_norm_penalty=8.9397e+00
# id=root/L/R/R/R/L/R, depth=6, t=1.7190e-02, ||w||=1.0408e+00, converged=True, n_iters=51, final_loss=3.5314e+03, final_grad_norm=3.9332e+02, w_norm_penalty=4.3324e+01
# id=root/L/R/R/R/L/R/L, depth=7, t=1.5048e-02, ||w||=1.6845e+00, converged=True, n_iters=37, final_loss=5.1884e+02, final_grad_norm=2.4164e+01, w_norm_penalty=3.2636e+00
# id=root/L/R/R/R/L/R/R, depth=7, t=1.3832e-02, ||w||=1.3248e+00, converged=False, n_iters=200, final_loss=5.8935e+02, final_grad_norm=7.5356e+01, w_norm_penalty=3.2636e+00
# id=root/L/R/R/R/R, depth=5, t=2.3894e-02, ||w||=2.1219e+00, converged=False, n_iters=200, final_loss=9.4858e+03, final_grad_norm=3.1446e+03, w_norm_penalty=1.7252e+02
# id=root/L/R/R/R/R/L, depth=6, t=1.6378e-02, ||w||=1.8377e+00, converged=False, n_iters=200, final_loss=3.4119e+03, final_grad_norm=1.8817e+03, w_norm_penalty=1.7747e+01
# id=root/L/R/R/R/R/L/L, depth=7, t=1.4458e-02, ||w||=1.0884e+00, converged=True, n_iters=8, final_loss=1.0672e+03, final_grad_norm=5.4882e+01, w_norm_penalty=4.6777e+00
# id=root/L/R/R/R/R/L/R, depth=7, t=1.2395e-02, ||w||=1.6061e+00, converged=False, n_iters=200, final_loss=2.1431e+02, final_grad_norm=7.7698e+01, w_norm_penalty=4.6777e+00
# id=root/L/R/R/R/R/R, depth=6, t=1.5201e-02, ||w||=1.3376e+00, converged=False, n_iters=200, final_loss=2.0636e+03, final_grad_norm=1.8930e+03, w_norm_penalty=1.7747e+01
# id=root/L/R/R/R/R/R/L, depth=7, t=7.1045e-03, ||w||=1.1384e+00, converged=True, n_iters=176, final_loss=5.9300e+02, final_grad_norm=1.1779e+02, w_norm_penalty=2.5160e+00
# id=root/L/R/R/R/R/R/R, depth=7, t=1.1483e-02, ||w||=1.5237e+00, converged=True, n_iters=111, final_loss=2.8069e+02, final_grad_norm=4.2784e+01, w_norm_penalty=2.5160e+00
# id=root/R, depth=1, t=6.2947e-02, ||w||=1.9073e+00, converged=True, n_iters=180, final_loss=3.8211e+05, final_grad_norm=2.1388e+04, w_norm_penalty=1.0000e+04
# id=root/R/L, depth=2, t=4.3201e-02, ||w||=1.2995e+00, converged=False, n_iters=200, final_loss=1.1630e+05, final_grad_norm=4.7040e+04, w_norm_penalty=1.7958e+03
# id=root/R/L/L, depth=3, t=4.7203e-02, ||w||=1.2012e+00, converged=True, n_iters=24, final_loss=2.3942e+04, final_grad_norm=6.4948e+01, w_norm_penalty=1.0120e+02
# id=root/R/L/L/L, depth=4, t=2.5049e-02, ||w||=8.9178e-01, converged=False, n_iters=200, final_loss=9.6903e+03, final_grad_norm=4.3087e+03, w_norm_penalty=1.4527e+01
# id=root/R/L/L/L/L, depth=5, t=2.9958e-02, ||w||=1.1567e+00, converged=False, n_iters=200, final_loss=2.7243e+03, final_grad_norm=1.5236e+02, w_norm_penalty=1.4698e+01
# id=root/R/L/L/L/L/L, depth=6, t=2.2321e-02, ||w||=1.0058e+00, converged=True, n_iters=4, final_loss=4.9301e+03, final_grad_norm=4.9893e+01, w_norm_penalty=1.6086e+00
# id=root/R/L/L/L/L/L/L, depth=7, t=1.5638e-02, ||w||=1.0001e+00, converged=False, n_iters=200, final_loss=3.9704e+02, final_grad_norm=2.1599e+02, w_norm_penalty=2.9134e+00
# id=root/R/L/L/L/L/L/R, depth=7, t=1.0973e-02, ||w||=1.0000e+00, converged=True, n_iters=3, final_loss=5.5815e+03, final_grad_norm=2.1115e+02, w_norm_penalty=2.9134e+00
# id=root/R/L/L/L/L/R, depth=6, t=1.0700e-02, ||w||=9.9004e-01, converged=True, n_iters=8, final_loss=1.3928e+03, final_grad_norm=1.4373e+02, w_norm_penalty=1.6086e+00
# id=root/R/L/L/L/L/R/L, depth=7, t=7.6128e-03, ||w||=9.9077e-01, converged=True, n_iters=5, final_loss=1.1036e+03, final_grad_norm=2.3892e+01, w_norm_penalty=9.5642e-01
# id=root/R/L/L/L/L/R/R, depth=7, t=5.1155e-03, ||w||=9.9645e-01, converged=True, n_iters=3, final_loss=1.5002e+03, final_grad_norm=8.6330e+01, w_norm_penalty=9.5642e-01
# id=root/R/L/L/L/R, depth=5, t=2.0617e-02, ||w||=1.1155e+00, converged=True, n_iters=19, final_loss=6.5240e+02, final_grad_norm=4.3171e+01, w_norm_penalty=1.4698e+01
# id=root/R/L/L/L/R/L, depth=6, t=1.6049e-02, ||w||=9.6259e-01, converged=True, n_iters=15, final_loss=2.8911e+02, final_grad_norm=2.8605e+01, w_norm_penalty=4.8560e-01
# id=root/R/L/L/L/R/L/L, depth=7, t=7.2242e-03, ||w||=1.0005e+00, converged=True, n_iters=3, final_loss=5.3675e+02, final_grad_norm=1.4374e+01, w_norm_penalty=2.4573e-01
# id=root/R/L/L/L/R/L/R, depth=7, t=6.8217e-03, ||w||=9.9257e-01, converged=True, n_iters=5, final_loss=4.0907e+01, final_grad_norm=8.9045e+00, w_norm_penalty=2.4573e-01
# id=root/R/L/L/L/R/R, depth=6, t=8.8086e-03, ||w||=1.0001e+00, converged=True, n_iters=2, final_loss=2.6178e+03, final_grad_norm=1.4740e+02, w_norm_penalty=4.8560e-01
# id=root/R/L/L/L/R/R/L, depth=7, t=5.6955e-03, ||w||=9.9256e-01, converged=True, n_iters=4, final_loss=8.1037e+02, final_grad_norm=2.0924e+02, w_norm_penalty=1.5040e+00
# id=root/R/L/L/L/R/R/R, depth=7, t=4.7837e-03, ||w||=8.1312e-01, converged=True, n_iters=109, final_loss=2.6751e+02, final_grad_norm=1.8150e+02, w_norm_penalty=1.5040e+00
# id=root/R/L/L/R, depth=4, t=1.9741e-02, ||w||=1.0566e+00, converged=False, n_iters=200, final_loss=1.6775e+04, final_grad_norm=2.8200e+03, w_norm_penalty=1.4527e+01
# id=root/R/L/L/R/L, depth=5, t=9.9638e-03, ||w||=9.9445e-01, converged=True, n_iters=4, final_loss=1.6117e+04, final_grad_norm=6.6331e+02, w_norm_penalty=1.2342e+01
# id=root/R/L/L/R/L/L, depth=6, t=2.9087e-03, ||w||=1.0114e+00, converged=False, n_iters=200, final_loss=8.0577e+02, final_grad_norm=1.4184e+03, w_norm_penalty=1.1735e+01
# id=root/R/L/L/R/L/L/L, depth=7, t=2.0885e-03, ||w||=9.7243e-01, converged=False, n_iters=200, final_loss=1.1029e+02, final_grad_norm=3.1304e+02, w_norm_penalty=6.7030e-01
# id=root/R/L/L/R/L/L/R, depth=7, t=2.3716e-03, ||w||=9.9807e-01, converged=True, n_iters=8, final_loss=5.2891e+01, final_grad_norm=6.9972e+01, w_norm_penalty=6.7030e-01
# id=root/R/L/L/R/L/R, depth=6, t=9.4754e-03, ||w||=1.0183e+00, converged=True, n_iters=5, final_loss=1.0690e+04, final_grad_norm=4.2392e+02, w_norm_penalty=1.1735e+01
# id=root/R/L/L/R/L/R/L, depth=7, t=5.5601e-03, ||w||=1.0316e+00, converged=False, n_iters=200, final_loss=3.1964e+02, final_grad_norm=4.1738e+02, w_norm_penalty=7.2354e+00
# id=root/R/L/L/R/L/R/R, depth=7, t=8.0761e-03, ||w||=1.1388e+00, converged=False, n_iters=200, final_loss=1.2254e+03, final_grad_norm=2.1061e+03, w_norm_penalty=7.2354e+00
# id=root/R/L/L/R/R, depth=5, t=1.7253e-02, ||w||=1.0016e+00, converged=True, n_iters=22, final_loss=2.0294e+04, final_grad_norm=8.8226e+02, w_norm_penalty=1.2342e+01
# id=root/R/L/L/R/R/L, depth=6, t=9.3770e-03, ||w||=9.7401e-01, converged=False, n_iters=200, final_loss=1.8291e+04, final_grad_norm=6.8279e+03, w_norm_penalty=1.1953e+01
# id=root/R/L/L/R/R/L/L, depth=7, t=7.5439e-03, ||w||=9.8977e-01, converged=False, n_iters=200, final_loss=2.2119e+03, final_grad_norm=4.8973e+03, w_norm_penalty=1.1582e+01
# id=root/R/L/L/R/R/L/R, depth=7, t=6.8961e-03, ||w||=6.8406e-01, converged=False, n_iters=200, final_loss=1.3154e+03, final_grad_norm=8.1604e+02, w_norm_penalty=1.1582e+01
# id=root/R/L/L/R/R/R, depth=6, t=9.7815e-03, ||w||=9.4995e-01, converged=False, n_iters=200, final_loss=1.9573e+03, final_grad_norm=7.2332e+02, w_norm_penalty=1.1953e+01
# id=root/R/L/L/R/R/R/L, depth=7, t=7.7412e-03, ||w||=1.0352e+00, converged=False, n_iters=200, final_loss=1.8841e+03, final_grad_norm=2.5432e+03, w_norm_penalty=2.7631e+00
# id=root/R/L/L/R/R/R/R, depth=7, t=6.1239e-03, ||w||=1.0124e+00, converged=True, n_iters=8, final_loss=9.2659e+02, final_grad_norm=2.1019e+02, w_norm_penalty=2.7631e+00
# id=root/R/L/R, depth=3, t=2.9800e-02, ||w||=9.5004e-01, converged=False, n_iters=200, final_loss=1.6044e+04, final_grad_norm=8.6322e+03, w_norm_penalty=1.0120e+02
# id=root/R/L/R/L, depth=4, t=1.1967e-02, ||w||=1.0156e+00, converged=False, n_iters=200, final_loss=5.3300e+02, final_grad_norm=1.7211e+02, w_norm_penalty=4.9284e+01
# id=root/R/L/R/L/L, depth=5, t=1.3479e-02, ||w||=1.0021e+00, converged=True, n_iters=20, final_loss=1.0954e+02, final_grad_norm=1.9641e+01, w_norm_penalty=3.4326e-01
# id=root/R/L/R/L/L/L, depth=6, t=5.0901e-03, ||w||=1.0143e+00, converged=True, n_iters=6, final_loss=3.7200e+02, final_grad_norm=4.1602e+01, w_norm_penalty=6.3004e-02
# id=root/R/L/R/L/L/L/L, depth=7, t=3.7702e-03, ||w||=9.8363e-01, converged=False, n_iters=200, final_loss=4.4428e+01, final_grad_norm=2.8115e+02, w_norm_penalty=2.3383e-01
# id=root/R/L/R/L/L/L/R, depth=7, t=2.1665e-03, ||w||=1.0000e+00, converged=True, n_iters=4, final_loss=4.0487e+01, final_grad_norm=4.5113e+01, w_norm_penalty=2.3383e-01
# id=root/R/L/R/L/L/R, depth=6, t=6.7312e-03, ||w||=1.0091e+00, converged=True, n_iters=5, final_loss=2.3401e+01, final_grad_norm=4.4955e+00, w_norm_penalty=6.3004e-02
# id=root/R/L/R/L/L/R/L, depth=7, t=3.7678e-03, ||w||=1.0098e+00, converged=False, n_iters=200, final_loss=2.5780e+01, final_grad_norm=2.7384e+02, w_norm_penalty=2.1980e-02
# id=root/R/L/R/L/R, depth=5, t=6.5243e-03, ||w||=1.1420e+00, converged=False, n_iters=200, final_loss=1.1836e+02, final_grad_norm=2.1833e+02, w_norm_penalty=3.4326e-01
# id=root/R/L/R/L/R/L, depth=6, t=5.6357e-03, ||w||=8.9880e-01, converged=False, n_iters=200, final_loss=2.8246e+01, final_grad_norm=3.6841e+01, w_norm_penalty=5.2491e-01
# id=root/R/L/R/L/R/L/L, depth=7, t=2.2208e-03, ||w||=1.0005e+00, converged=True, n_iters=4, final_loss=2.6350e+01, final_grad_norm=7.9542e-01, w_norm_penalty=3.8226e-02
# id=root/R/L/R/L/R/L/R, depth=7, t=4.2380e-03, ||w||=1.0032e+00, converged=True, n_iters=7, final_loss=2.5743e+01, final_grad_norm=7.1373e+00, w_norm_penalty=3.8226e-02
# id=root/R/L/R/L/R/R, depth=6, t=8.1713e-03, ||w||=1.0194e+00, converged=False, n_iters=200, final_loss=7.6924e+01, final_grad_norm=1.1633e+01, w_norm_penalty=5.2491e-01
# id=root/R/L/R/L/R/R/L, depth=7, t=3.7797e-03, ||w||=1.0126e+00, converged=False, n_iters=200, final_loss=3.7651e+01, final_grad_norm=2.9897e+02, w_norm_penalty=4.9898e-02
# id=root/R/L/R/L/R/R/R, depth=7, t=5.3543e-03, ||w||=1.0041e+00, converged=True, n_iters=5, final_loss=9.4637e+01, final_grad_norm=1.7252e+01, w_norm_penalty=4.9898e-02
# id=root/R/L/R/R, depth=4, t=2.8312e-02, ||w||=2.1112e+00, converged=True, n_iters=125, final_loss=1.6315e+04, final_grad_norm=8.8984e+02, w_norm_penalty=4.9284e+01
# id=root/R/L/R/R/L, depth=5, t=9.0714e-03, ||w||=6.6969e-01, converged=False, n_iters=200, final_loss=5.8883e+03, final_grad_norm=9.0183e+04, w_norm_penalty=2.3742e+01
# id=root/R/L/R/R/L/L, depth=6, t=6.9299e-03, ||w||=9.8731e-01, converged=False, n_iters=200, final_loss=1.0148e+03, final_grad_norm=5.4609e+02, w_norm_penalty=5.7089e+00
# id=root/R/L/R/R/L/L/L, depth=7, t=2.9967e-03, ||w||=9.4503e-01, converged=False, n_iters=200, final_loss=2.6704e+02, final_grad_norm=1.6141e+03, w_norm_penalty=8.6130e-01
# id=root/R/L/R/R/L/L/R, depth=7, t=4.8580e-03, ||w||=9.9830e-01, converged=True, n_iters=8, final_loss=6.2296e+02, final_grad_norm=3.3631e+01, w_norm_penalty=8.6130e-01
# id=root/R/L/R/R/L/R, depth=6, t=8.9796e-03, ||w||=1.0054e+00, converged=False, n_iters=200, final_loss=7.2036e+02, final_grad_norm=1.2209e+03, w_norm_penalty=5.7089e+00
# id=root/R/L/R/R/L/R/L, depth=7, t=6.3006e-03, ||w||=9.6896e-01, converged=True, n_iters=15, final_loss=2.9879e+02, final_grad_norm=5.0972e+01, w_norm_penalty=7.4402e-01
# id=root/R/L/R/R/L/R/R, depth=7, t=7.4425e-03, ||w||=1.0132e+00, converged=True, n_iters=7, final_loss=4.6102e+02, final_grad_norm=4.2851e+01, w_norm_penalty=7.4402e-01
# id=root/R/L/R/R/R, depth=5, t=1.9822e-02, ||w||=1.4620e+00, converged=True, n_iters=93, final_loss=1.3321e+04, final_grad_norm=9.1147e+02, w_norm_penalty=2.3742e+01
# id=root/R/L/R/R/R/L, depth=6, t=1.5977e-02, ||w||=1.0177e+00, converged=True, n_iters=121, final_loss=3.6701e+03, final_grad_norm=5.3608e+02, w_norm_penalty=8.3183e+00
# id=root/R/L/R/R/R/L/L, depth=7, t=1.1643e-02, ||w||=1.0001e+00, converged=False, n_iters=200, final_loss=1.2132e+03, final_grad_norm=2.6738e+02, w_norm_penalty=2.4147e+00
# id=root/R/L/R/R/R/L/R, depth=7, t=5.2947e-03, ||w||=9.4998e-01, converged=False, n_iters=200, final_loss=2.2517e+02, final_grad_norm=1.2736e+02, w_norm_penalty=2.4147e+00
# id=root/R/L/R/R/R/R, depth=6, t=1.0035e-02, ||w||=9.9424e-01, converged=False, n_iters=200, final_loss=2.6268e+03, final_grad_norm=2.0302e+03, w_norm_penalty=8.3183e+00
# id=root/R/L/R/R/R/R/L, depth=7, t=7.6412e-03, ||w||=9.7736e-01, converged=True, n_iters=5, final_loss=2.7163e+03, final_grad_norm=2.2670e+02, w_norm_penalty=1.1982e+01
# id=root/R/L/R/R/R/R/R, depth=7, t=7.6937e-03, ||w||=1.0001e+00, converged=True, n_iters=3, final_loss=2.3170e+03, final_grad_norm=7.1716e+01, w_norm_penalty=1.1982e+01
# id=root/R/R, depth=2, t=6.8322e-02, ||w||=1.1684e+00, converged=False, n_iters=200, final_loss=3.5106e+05, final_grad_norm=1.8247e+04, w_norm_penalty=1.7958e+03
# id=root/R/R/L, depth=3, t=4.6042e-02, ||w||=2.1653e+00, converged=True, n_iters=55, final_loss=3.0689e+05, final_grad_norm=8.6126e+03, w_norm_penalty=2.5301e+02
# id=root/R/R/L/L, depth=4, t=2.9232e-02, ||w||=1.0867e+00, converged=False, n_iters=200, final_loss=3.3572e+04, final_grad_norm=8.3829e+03, w_norm_penalty=2.1143e+02
# id=root/R/R/L/L/L, depth=5, t=2.4751e-02, ||w||=1.0380e+00, converged=True, n_iters=14, final_loss=1.7433e+04, final_grad_norm=6.0064e+02, w_norm_penalty=2.3981e+01
# id=root/R/R/L/L/L/L, depth=6, t=1.0281e-02, ||w||=9.9748e-01, converged=False, n_iters=200, final_loss=9.9308e+03, final_grad_norm=9.9236e+03, w_norm_penalty=1.0630e+01
# id=root/R/R/L/L/L/L/L, depth=7, t=6.3848e-03, ||w||=8.3040e-01, converged=False, n_iters=200, final_loss=6.6800e+02, final_grad_norm=1.3254e+03, w_norm_penalty=8.3582e+00
# id=root/R/R/L/L/L/L/R, depth=7, t=7.6299e-03, ||w||=1.0636e+00, converged=False, n_iters=200, final_loss=1.0283e+03, final_grad_norm=4.4266e+02, w_norm_penalty=8.3582e+00
# id=root/R/R/L/L/L/R, depth=6, t=2.0520e-02, ||w||=2.7887e+00, converged=True, n_iters=172, final_loss=1.0429e+04, final_grad_norm=1.6176e+03, w_norm_penalty=1.0630e+01
# id=root/R/R/L/L/L/R/L, depth=7, t=9.2982e-03, ||w||=1.0118e+00, converged=True, n_iters=62, final_loss=2.2720e+03, final_grad_norm=4.5717e+02, w_norm_penalty=1.4544e+01
# id=root/R/R/L/L/L/R/R, depth=7, t=1.6444e-02, ||w||=7.9992e-01, converged=False, n_iters=200, final_loss=2.1578e+03, final_grad_norm=1.9802e+03, w_norm_penalty=1.4544e+01
# id=root/R/R/L/L/R, depth=5, t=2.2086e-02, ||w||=1.4983e+00, converged=False, n_iters=200, final_loss=2.7336e+03, final_grad_norm=3.6124e+02, w_norm_penalty=2.3981e+01
# id=root/R/R/L/L/R/L, depth=6, t=1.6165e-02, ||w||=1.0042e+00, converged=True, n_iters=5, final_loss=1.1106e+03, final_grad_norm=1.7945e+01, w_norm_penalty=2.1122e+00
# id=root/R/R/L/L/R/L/L, depth=7, t=9.4936e-03, ||w||=1.4392e+00, converged=False, n_iters=200, final_loss=1.4570e+02, final_grad_norm=9.9576e+01, w_norm_penalty=6.3868e-01
# id=root/R/R/L/L/R/L/R, depth=7, t=1.3650e-02, ||w||=1.1574e+00, converged=False, n_iters=200, final_loss=2.8258e+02, final_grad_norm=8.3646e+01, w_norm_penalty=6.3868e-01
# id=root/R/R/L/L/R/R, depth=6, t=2.4100e-02, ||w||=1.0146e+00, converged=True, n_iters=4, final_loss=1.1971e+03, final_grad_norm=4.0957e+01, w_norm_penalty=2.1122e+00
# id=root/R/R/L/L/R/R/L, depth=7, t=1.3710e-02, ||w||=9.0952e-01, converged=True, n_iters=96, final_loss=1.6313e+03, final_grad_norm=9.6374e+01, w_norm_penalty=6.9740e-01
# id=root/R/R/L/L/R/R/R, depth=7, t=1.2118e-02, ||w||=1.0332e+00, converged=True, n_iters=12, final_loss=2.4054e+03, final_grad_norm=1.2475e+02, w_norm_penalty=6.9740e-01
# id=root/R/R/L/R, depth=4, t=2.6992e-02, ||w||=1.0935e+00, converged=False, n_iters=200, final_loss=3.9993e+04, final_grad_norm=9.3149e+03, w_norm_penalty=2.1143e+02
# id=root/R/R/L/R/L, depth=5, t=2.4757e-02, ||w||=1.6765e+00, converged=False, n_iters=200, final_loss=4.3190e+03, final_grad_norm=1.3512e+02, w_norm_penalty=2.5335e+01
# id=root/R/R/L/R/L/L, depth=6, t=9.7563e-03, ||w||=1.0028e+00, converged=True, n_iters=9, final_loss=1.4094e+04, final_grad_norm=9.7860e+02, w_norm_penalty=3.1108e+00
# id=root/R/R/L/R/L/L/L, depth=7, t=5.9875e-03, ||w||=1.0080e+00, converged=True, n_iters=64, final_loss=9.2569e+02, final_grad_norm=2.2233e+02, w_norm_penalty=8.1773e+00
# id=root/R/R/L/R/L/L/R, depth=7, t=7.8882e-03, ||w||=9.7695e-01, converged=False, n_iters=200, final_loss=1.0710e+03, final_grad_norm=6.6512e+02, w_norm_penalty=8.1773e+00
# id=root/R/R/L/R/L/R, depth=6, t=1.5284e-02, ||w||=9.9366e-01, converged=False, n_iters=200, final_loss=2.3567e+03, final_grad_norm=2.0917e+03, w_norm_penalty=3.1108e+00
# id=root/R/R/L/R/L/R/L, depth=7, t=8.0358e-03, ||w||=9.1372e-01, converged=False, n_iters=200, final_loss=1.0795e+03, final_grad_norm=2.6303e+03, w_norm_penalty=1.8925e+00
# id=root/R/R/L/R/L/R/R, depth=7, t=1.2933e-02, ||w||=1.2749e+00, converged=False, n_iters=200, final_loss=4.6551e+02, final_grad_norm=3.2340e+02, w_norm_penalty=1.8925e+00
# id=root/R/R/L/R/R, depth=5, t=1.8935e-02, ||w||=8.9232e-01, converged=False, n_iters=200, final_loss=8.4043e+03, final_grad_norm=6.0554e+03, w_norm_penalty=2.5335e+01
# id=root/R/R/L/R/R/L, depth=6, t=8.7388e-03, ||w||=1.0773e+00, converged=False, n_iters=200, final_loss=2.8146e+03, final_grad_norm=2.0146e+03, w_norm_penalty=6.6395e+00
# id=root/R/R/L/R/R/L/L, depth=7, t=6.8625e-03, ||w||=1.0334e+00, converged=False, n_iters=200, final_loss=1.5033e+03, final_grad_norm=1.6744e+02, w_norm_penalty=2.4454e+00
# id=root/R/R/L/R/R/L/R, depth=7, t=6.2329e-03, ||w||=2.5621e+00, converged=True, n_iters=15, final_loss=5.4992e+02, final_grad_norm=1.2469e+02, w_norm_penalty=2.4454e+00
# id=root/R/R/L/R/R/R, depth=6, t=1.7911e-02, ||w||=2.6867e+00, converged=True, n_iters=10, final_loss=1.7654e+04, final_grad_norm=2.4509e+02, w_norm_penalty=6.6395e+00
# id=root/R/R/L/R/R/R/L, depth=7, t=7.2999e-03, ||w||=1.1160e+00, converged=False, n_iters=200, final_loss=1.8447e+03, final_grad_norm=9.4080e+02, w_norm_penalty=1.6082e+01
# id=root/R/R/L/R/R/R/R, depth=7, t=1.3454e-02, ||w||=2.7249e+00, converged=True, n_iters=22, final_loss=1.3455e+04, final_grad_norm=9.3898e+02, w_norm_penalty=1.6082e+01
# id=root/R/R/R, depth=3, t=2.4705e-02, ||w||=1.2161e+00, converged=False, n_iters=200, final_loss=9.4372e+03, final_grad_norm=9.8265e+03, w_norm_penalty=2.5301e+02
# id=root/R/R/R/L, depth=4, t=2.0448e-02, ||w||=9.7177e-01, converged=True, n_iters=3, final_loss=1.5407e+04, final_grad_norm=4.2416e+02, w_norm_penalty=9.0491e+00
# id=root/R/R/R/L/L, depth=5, t=1.1525e-02, ||w||=8.5740e-01, converged=False, n_iters=200, final_loss=3.9273e+03, final_grad_norm=7.3005e+03, w_norm_penalty=9.6671e+00
# id=root/R/R/R/L/L/L, depth=6, t=9.6911e-03, ||w||=1.0930e+00, converged=True, n_iters=52, final_loss=1.1202e+03, final_grad_norm=3.4693e+02, w_norm_penalty=5.0810e+00
# id=root/R/R/R/L/L/L/L, depth=7, t=4.7947e-03, ||w||=1.3179e+00, converged=False, n_iters=200, final_loss=4.8170e+01, final_grad_norm=1.2495e+02, w_norm_penalty=9.8982e-01
# id=root/R/R/R/L/L/L/R, depth=7, t=8.7760e-03, ||w||=1.0027e+00, converged=True, n_iters=38, final_loss=6.8347e+02, final_grad_norm=1.1582e+02, w_norm_penalty=9.8982e-01
# id=root/R/R/R/L/L/R, depth=6, t=7.1557e-03, ||w||=1.1632e+00, converged=False, n_iters=200, final_loss=2.3959e+02, final_grad_norm=3.4660e+02, w_norm_penalty=5.0810e+00
# id=root/R/R/R/L/L/R/L, depth=7, t=7.1255e-03, ||w||=7.1828e-01, converged=False, n_iters=200, final_loss=9.1737e+01, final_grad_norm=1.6008e+02, w_norm_penalty=4.2429e-01
# id=root/R/R/R/L/L/R/R, depth=7, t=4.1852e-03, ||w||=1.0150e+00, converged=False, n_iters=200, final_loss=5.2744e+01, final_grad_norm=1.1054e+02, w_norm_penalty=4.2429e-01
# id=root/R/R/R/L/R, depth=5, t=1.2700e-02, ||w||=9.8681e-01, converged=True, n_iters=10, final_loss=6.0266e+03, final_grad_norm=4.6818e+02, w_norm_penalty=9.6671e+00
# id=root/R/R/R/L/R/L, depth=6, t=5.8452e-03, ||w||=9.8888e-01, converged=True, n_iters=123, final_loss=2.2637e+03, final_grad_norm=2.3466e+03, w_norm_penalty=3.8331e+00
# id=root/R/R/R/L/R/L/L, depth=7, t=4.1711e-03, ||w||=1.0016e+00, converged=True, n_iters=8, final_loss=1.9787e+02, final_grad_norm=1.4928e+02, w_norm_penalty=1.8480e+00
# id=root/R/R/R/L/R/L/R, depth=7, t=4.7219e-03, ||w||=9.9811e-01, converged=True, n_iters=14, final_loss=2.2060e+02, final_grad_norm=1.5976e+02, w_norm_penalty=1.8480e+00
# id=root/R/R/R/L/R/R, depth=6, t=9.1795e-03, ||w||=1.5661e+00, converged=False, n_iters=200, final_loss=6.9766e+02, final_grad_norm=2.7789e+03, w_norm_penalty=3.8331e+00
# id=root/R/R/R/L/R/R/L, depth=7, t=7.5742e-03, ||w||=1.0558e+00, converged=True, n_iters=86, final_loss=4.0123e+02, final_grad_norm=1.5161e+02, w_norm_penalty=2.6267e+00
# id=root/R/R/R/L/R/R/R, depth=7, t=5.6963e-03, ||w||=1.0012e+00, converged=False, n_iters=200, final_loss=1.3203e+02, final_grad_norm=1.0910e+02, w_norm_penalty=2.6267e+00
# id=root/R/R/R/R, depth=4, t=2.2440e-02, ||w||=1.0193e+00, converged=True, n_iters=7, final_loss=2.8084e+03, final_grad_norm=9.3321e+01, w_norm_penalty=9.0491e+00
# id=root/R/R/R/R/L, depth=5, t=1.1031e-02, ||w||=1.0733e+00, converged=True, n_iters=8, final_loss=4.9186e+03, final_grad_norm=7.3869e+01, w_norm_penalty=1.9289e+00
# id=root/R/R/R/R/L/L, depth=6, t=8.5104e-03, ||w||=7.0351e-01, converged=False, n_iters=200, final_loss=9.3953e+02, final_grad_norm=2.9083e+03, w_norm_penalty=3.5166e+00
# id=root/R/R/R/R/L/L/L, depth=7, t=7.9517e-03, ||w||=1.0216e+00, converged=False, n_iters=200, final_loss=7.9008e+01, final_grad_norm=1.7931e+02, w_norm_penalty=2.4511e+00
# id=root/R/R/R/R/L/L/R, depth=7, t=7.2618e-03, ||w||=1.0010e+00, converged=True, n_iters=8, final_loss=3.0761e+02, final_grad_norm=5.2414e+01, w_norm_penalty=2.4511e+00
# id=root/R/R/R/R/L/R, depth=6, t=5.0332e-03, ||w||=9.8979e-01, converged=True, n_iters=6, final_loss=4.7863e+02, final_grad_norm=3.1666e+02, w_norm_penalty=3.5166e+00
# id=root/R/R/R/R/L/R/L, depth=7, t=3.0280e-03, ||w||=1.0054e+00, converged=False, n_iters=200, final_loss=9.2659e+01, final_grad_norm=1.9364e+02, w_norm_penalty=8.2433e-01
# id=root/R/R/R/R/L/R/R, depth=7, t=3.0431e-03, ||w||=9.9217e-01, converged=False, n_iters=200, final_loss=3.5287e+01, final_grad_norm=6.7594e+01, w_norm_penalty=8.2433e-01
# id=root/R/R/R/R/R, depth=5, t=1.3493e-02, ||w||=1.0277e+00, converged=False, n_iters=200, final_loss=1.1546e+03, final_grad_norm=1.1113e+03, w_norm_penalty=1.9289e+00
# id=root/R/R/R/R/R/L, depth=6, t=1.0537e-02, ||w||=9.9348e-01, converged=True, n_iters=49, final_loss=2.1343e+02, final_grad_norm=1.1854e+01, w_norm_penalty=6.9993e-01
# id=root/R/R/R/R/R/L/L, depth=7, t=4.9526e-03, ||w||=9.7440e-01, converged=True, n_iters=10, final_loss=2.3471e+02, final_grad_norm=2.7127e+01, w_norm_penalty=1.2554e-01
# id=root/R/R/R/R/R/L/R, depth=7, t=8.8924e-03, ||w||=1.0958e+00, converged=False, n_iters=200, final_loss=9.0839e+01, final_grad_norm=1.9814e+02, w_norm_penalty=1.2554e-01
# id=root/R/R/R/R/R/R, depth=6, t=1.1280e-02, ||w||=1.0112e+00, converged=True, n_iters=91, final_loss=2.0237e+02, final_grad_norm=5.6439e+01, w_norm_penalty=6.9993e-01
# id=root/R/R/R/R/R/R/L, depth=7, t=1.3053e-02, ||w||=1.0635e+00, converged=False, n_iters=200, final_loss=7.3991e+01, final_grad_norm=1.3138e+01, w_norm_penalty=1.3675e-01
# id=root/R/R/R/R/R/R/R, depth=7, t=1.0386e-02, ||w||=1.0047e+00, converged=True, n_iters=5, final_loss=1.2810e+01, final_grad_norm=7.0374e-01, w_norm_penalty=1.3675e-01

# %%
# /L/L/L/L/L/R/R
v = tree.get_node("root")
plt.plot(v.fit_result.loss_history)
# plt.plot(v.fit_result.grad_norm_history)
# plt.plot(tree.root.right.right.right.right.right.right.right.right.right.fit_result))
print(v.fit_result.w_norm_penalty)
# Out:
# 10000.0

# %%
nood = tree.root.right.right.right.right.right.right.left.right.right.left.left
plt.plot(nood.fit_result.loss_history)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [24], in <module>
# ----> 1 nood = tree.root.right.right.right.right.right.right.left.right.right.left.left
#       2 plt.plot(nood.fit_result.loss_history)
#
# AttributeError: 'AffineLeaf' object has no attribute 'left'

# %%
print(norm(nood.w))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [81], in <module>
# ----> 1 print(norm(nood.w))
#
# NameError: name 'nood' is not defined

# %%
from matplotlib.colors import ListedColormap


def plot_leaf_regions_with_contours_2d(tree, bounds, oracle, n_grid=300, n_contours=20,
                                       title="Leaf Regions with Oracle Contours"):
    bounds = np.asarray(bounds, dtype=float)
    if bounds.shape != (2, 2):
        raise ValueError("bounds must have shape (2, 2)")

    x1_min, x1_max = bounds[0]
    x2_min, x2_max = bounds[1]

    x1 = np.linspace(x1_min, x1_max, n_grid)
    x2 = np.linspace(x2_min, x2_max, n_grid)
    X1, X2 = np.meshgrid(x1, x2)
    Xg = np.column_stack([X1.ravel(), X2.ravel()])

    # Leaf assignment
    leaf_objs = [tree.leaf_for_point(x) for x in Xg]
    leaf_ids = [id(leaf) for leaf in leaf_objs]
    unique_leaf_ids = sorted(set(leaf_ids))
    leaf_to_label = {leaf_id: k for k, leaf_id in enumerate(unique_leaf_ids)}
    Z = np.array([leaf_to_label[leaf_id] for leaf_id in leaf_ids], dtype=int).reshape(n_grid, n_grid)

    n_leaves = len(unique_leaf_ids)

    # Adjacency graph for contrasting colors
    adjacency = {k: set() for k in range(n_leaves)}

    for i in range(n_grid - 1):
        for j in range(n_grid):
            a, b = Z[i, j], Z[i + 1, j]
            if a != b:
                adjacency[a].add(b)
                adjacency[b].add(a)

    for i in range(n_grid):
        for j in range(n_grid - 1):
            a, b = Z[i, j], Z[i, j + 1]
            if a != b:
                adjacency[a].add(b)
                adjacency[b].add(a)

    palette = [
        "#e41a1c", "#377eb8", "#4daf4a", "#984ea3", "#ff7f00",
        "#ffff33", "#a65628", "#f781bf", "#17becf", "#7f7f7f",
        "#1b9e77", "#d95f02", "#7570b3", "#66a61e", "#e6ab02",
        "#a6761d", "#666666"
    ]

    order = sorted(range(n_leaves), key=lambda k: len(adjacency[k]), reverse=True)
    color_idx = {}

    for node in order:
        used = {color_idx[nbr] for nbr in adjacency[node] if nbr in color_idx}
        for c in range(len(palette)):
            if c not in used:
                color_idx[node] = c
                break
        else:
            color_idx[node] = node % len(palette)

    Z_color = np.vectorize(lambda z: color_idx[z])(Z)
    cmap = ListedColormap(palette)

    # Oracle values and log contours
    # F = np.array([oracle(x) for x in Xg], dtype=float).reshape(n_grid, n_grid)
    # F_log = np.log10(np.maximum(np.abs(F), 1e-12))

    plt.figure(figsize=(6, 6))
    plt.pcolormesh(X1, X2, Z_color, shading="auto", cmap=cmap, alpha=1.0)

    # cs = plt.contour(X1, X2, F_log, levels=n_contours, colors="black", linewidths=1.0)
    # plt.clabel(cs, inline=True, fontsize=8, fmt="%.2f")

    rect = np.array([
        [x1_min, x2_min],
        [x1_max, x2_min],
        [x1_max, x2_max],
        [x1_min, x2_max],
        [x1_min, x2_min],
    ])
    plt.plot(rect[:, 0], rect[:, 1], color="black", lw=2)

    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(title)
    plt.gca().set_aspect("equal")
    plt.show()

# %%
plot_leaf_regions_with_contours_2d(
    tree=tree,
    bounds=bounds,
    oracle=oracle,
    n_grid=300,
    n_contours=20,
    title="Leaf Regions - Rosenbrock"
)

# %%
plot_log_contours_2d(
    predict_fn=tree.predict_one,
    bounds=bounds,
    n_grid=250,
    title="Tree Surrogate Log-Contours"
)
